# %%
# !pip install wandb
# !pip install fairlearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.14.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.3 MB/s eta 0:00:00
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (2.27.1)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (5.9.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from wandb) (4.5.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 3.8 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.18.0-py2.py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 KB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb) (67.6.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from wandb) (6.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (8.1.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=ceef0ca9954fe578ec4c7e580d3350c35c9c4eca454199517c34e4118067bcf8
#   Stored in directory: /root/.cache/pip/wheels/b7/0a/67/ada2a22079218c75a88361c0782855cc72aebc4d18d0289d05
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.31 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.18.0 setproctitle-1.3.2 smmap-5.0.0 wandb-0.14.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fairlearn
#   Downloading fairlearn-0.8.0-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.0/235.0 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.4.4)
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.2.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.10.1)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25.1->fairlearn) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25.1->fairlearn) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.1->fairlearn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.1->fairlearn) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=0.25.1->fairlearn) (1.16.0)
# Installing collected packages: fairlearn
# Successfully installed fairlearn-0.8.0

# %%
import pandas as pd
import plotly
import plotly.express as px
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model, metrics, preprocessing
from datetime import datetime, timedelta

import wandb
import random

from fairlearn.postprocessing import ThresholdOptimizer, plot_threshold_optimizer
from fairlearn.metrics import demographic_parity_ratio, equalized_odds_ratio, demographic_parity_difference, equalized_odds_difference
from fairlearn.reductions import DemographicParity


from google.colab import drive

from sklearn.model_selection import KFold, cross_val_score



drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %%
import torch
from torch import nn
from torch.nn import functional as F


class ConstraintLoss(nn.Module):
    def __init__(self, n_class=2, alpha=1, p_norm=2):
        super(ConstraintLoss, self).__init__()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.alpha = alpha
        self.p_norm = p_norm
        self.n_class = n_class
        self.n_constraints = 2
        self.dim_condition = self.n_class + 1
        self.M = torch.zeros((self.n_constraints, self.dim_condition))
        self.c = torch.zeros(self.n_constraints)

    def mu_f(self, X=None, y=None, sensitive=None):
        return torch.zeros(self.n_constraints)

    def forward(self, X, out, sensitive, y=None):
        # Reshapes sensitive attribute tensor to the same shape as the output 
        sensitive = sensitive.view(out.shape)
        # Reshapes y (label) tensor to the same shape as the output 
        if isinstance(y, torch.Tensor):
            y = y.view(out.shape)
        # Get probability output by applying sigmoid (like logistic regression?)
        out = torch.sigmoid(out)
        # Get the mu_f value given these tensors 
        mu = self.mu_f(X=X, out=out, sensitive=sensitive, y=y)
        # Gap constraint???
        # Apply relu to matrix vector product of M compared to mu-c 
        # Using cuda if applicable (self.device references)
        gap_constraint = F.relu(
            torch.mv(self.M.to(self.device), mu.to(self.device)) - self.c.to(self.device)
        )
        # Using the L2 Norm of the gap constraint as regularizer with alpha parameter. 
        if self.p_norm == 2:
            cons = self.alpha * torch.dot(gap_constraint, gap_constraint)
        else:
            cons = self.alpha * torch.dot(gap_constraint.detach(), gap_constraint)
        return cons


class DemographicParityLoss(ConstraintLoss):
    def __init__(self, sensitive_classes=[0, 1], alpha=1, p_norm=2):
        """loss of demograpfhic parity

        Args:
            sensitive_classes (list, optional): list of unique values of sensitive attribute. Defaults to [0, 1].
            alpha (int, optional): [description]. Defaults to 1.
            p_norm (int, optional): [description]. Defaults to 2.
        """
        self.sensitive_classes = sensitive_classes
        self.n_class = len(sensitive_classes)
        super(DemographicParityLoss, self).__init__(
            n_class=self.n_class, alpha=alpha, p_norm=p_norm
        )
        self.n_constraints = self.n_class
        self.dim_condition = self.n_class
        self.M = torch.zeros((self.n_constraints, self.dim_condition))
        for i in range(self.n_constraints):
            j = i % 2
            if j == 0:
                self.M[i, j] = 1.0
                self.M[i, 1] = -1.0
            else:
                self.M[i, j - 1] = -1.0
                self.M[i, 1] = 1.0
        # print("DP_init -> M defined")

    def mu_f(self, X, out, sensitive, y=None):
        # print("sub-class mu_f -> return exp vals")
        expected_values_list = []
        for v in self.sensitive_classes:
            # Get the index for each of the senstive classes 
            idx_true = sensitive == v  # torch.bool
            # Get the average prediction for that sensitive class
            expected_values_list.append(out[idx_true].mean())

        #expected_values_list will have two values, one for each sensitive class representing it's average prediction
        #if you look at forward you'll see we take the dot product of these two values with M
        return torch.stack(expected_values_list)

    def forward(self, X, out, sensitive, y=None):
        #Calls parent class forward function
        # print("sub-class forward -> call super forward")
        return super(DemographicParityLoss, self).forward(X, out, sensitive)


# Convex 
class EqualizedOddsLoss(ConstraintLoss):
    def __init__(self, sensitive_classes=[0, 1], alpha=1, p_norm=2):
        """loss of demograpfhic parity
        Args:
            sensitive_classes (list, optional): list of unique values of sensitive attribute. Defaults to [0, 1].
            alpha (int, optional): [description]. Defaults to 1.
            p_norm (int, optional): [description]. Defaults to 2.

            equalized odds: pr(y_hat | A=a, Y=y) = pr(y_hat | Y=y) for all a in A, y in Y.
            pr(y_hat =1 | A=a1, Y=y) = pr(y_hat =1 | A=a2, Y=y) for all y
        """
        self.sensitive_classes = sensitive_classes
        self.y_classes = [0, 1] # binary classification
        self.n_class = len(sensitive_classes)
        self.n_y_class = len(self.y_classes)
        super(EqualizedOddsLoss, self).__init__(n_class=self.n_class, alpha=alpha, p_norm=p_norm)
        # K:  number of constraint : (|A| x |Y| x {+, -})
        self.n_constraints = self.n_class * self.n_y_class * 2 
        # J : dim of conditions  : ((|A|+1) x |Y|)
        self.dim_condition = self.n_y_class * (self.n_class + 1)
        self.M = torch.zeros((self.n_constraints, self.dim_condition))
        # make M (K * J): (|A| x |Y| x {+, -})  *   (|A|+1) x |Y|) )
        self.c = torch.zeros(self.n_constraints)
        element_K_A = self.sensitive_classes + [None]
        for i_a, a_0 in enumerate(self.sensitive_classes):
            for i_y, y_0 in enumerate(self.y_classes):
                for i_s, s in enumerate([-1, 1]):
                    for j_y, y_1 in enumerate(self.y_classes):
                        for j_a, a_1 in enumerate(element_K_A):
                            i = i_a * (2 * self.n_y_class) + i_y * 2 + i_s
                            j = j_y + self.n_y_class * j_a
                            self.M[i, j] = self.__element_M(a_0, a_1, y_1, y_1, s)
    def __element_M(self, a0, a1, y0, y1, s):
        if a0 is None or a1 is None:
            x = y0 == y1
            return -1 * s * x
        else:
            x = (a0 == a1) & (y0 == y1)
            return s * float(x)

    def mu_f(self, X, out, sensitive, y):
        expected_values_list = []
        for u in self.sensitive_classes:
            for v in self.y_classes:
                idx_true = (y == v) * (sensitive == u)  # torch.bool
                expected_values_list.append(out[idx_true].mean())
        # sensitive is star
        for v in self.y_classes:
            idx_true = y == v
            expected_values_list.append(out[idx_true].mean())
        return torch.stack(expected_values_list)

    def forward(self, X, out, sensitive, y):
        return super(EqualizedOddsLoss, self).forward(X, out, sensitive, y=y)

# %%
# https://towardsdatascience.com/logistic-regression-with-pytorch-3c8bbea594be
class LogisticRegression(torch.nn.Module):
     def __init__(self, input_dim, output_dim):
         super(LogisticRegression, self).__init__()
         self.linear = torch.nn.Linear(input_dim, output_dim)
     def forward(self, x):
         (self.linear) 

         outputs = torch.sigmoid(self.linear(x))
         return outputs

# %%
def load_compas(target_name = 'two_year_recid', sensitive_name = 'race'): 

  # Load Data 
  compas_link ='https://raw.githubusercontent.com/propublica/compas-analysis/master/compas-scores-two-years.csv'
  compas_data = pd.read_csv(compas_link, on_bad_lines='skip')

  # Trim Undesired Columns 
  compas_data = compas_data[['age' , 'juv_fel_count', 'decile_score', 'juv_misd_count', 'juv_other_count', 'priors_count','sex','c_charge_degree','race','two_year_recid']]
  compas_to_oh = ['sex','c_charge_degree']

  # Fix Race 
  compas_data.loc[compas_data.race != 'Caucasian', 'race'] = 1
  compas_data.loc[compas_data.race == 'Caucasian', 'race'] = 0

  # # Fix Race 
  # compas_data.loc[compas_data.race != 'Caucasian', 'two_year_recid'] = 1
  # compas_data.loc[compas_data.race == 'Caucasian', 'two_year_recid'] = 0

  # Get Target and Sensitive 
  target = compas_data[target_name]
  sensitive = compas_data[[sensitive_name]]

  # Remove target and one-hot-encode sex & c_charge_degree
  # compas_data = compas_data[['age' , 'juv_fel_count', 'decile_score', 'juv_misd_count', 'juv_other_count', 'priors_count','sex','c_charge_degree','race']]
  compas_data = pd.get_dummies(compas_data, columns = compas_to_oh)

  # Returns x, y, sensitive (with sensitive still included in x )
  return compas_data, sensitive_name

# %%
def label_encode(df):

  for i in df.columns:
    tmp = df[i].iloc[0]
    
    if type(tmp) != int or type(tmp) != float:
      le = preprocessing.LabelEncoder()
      df[i] = le.fit_transform(df[i].values)

  return df

def one_hot(df):
  
  for i in df.columns:
    tmp = df[i].iloc[0]

    if i == 'Loan_Status':
      pass
    elif type(tmp) == str:
      df = pd.get_dummies(df, columns = [i])
      # ohe = preprocessing.OneHotEncoder()
      # df[i] =  ohe.fit_transform(df[i].values.reshape(-1, 1)) # double check the shape

  return df


def get_dataset(name, target = None, sensitive = None):
  if name == 'compas':
    df, sensitive_name = load_compas()

  else: 
    df = pd.read_csv("/content/drive/MyDrive/Project/Data/adult.csv")
    df = label_encode(df)

  return df, sensitive_name

def split(x, y, sensitive_features,  train_ratio, test_ratio):
  validation_ratio = 100 - train_ratio - test_ratio

  if validation_ratio < 0:
    print ("Incorrect Ratios")
    return -1

  # train is now 75% of the entire data set
  x_train, x_test, y_train, y_test, a_train, a_test = train_test_split(x, y, sensitive_features, test_size=1 - train_ratio, random_state=32)

  # test is now 10% of the initial data set
  # validation is now 15% of the initial data set
  x_val, x_test, y_val, y_test, a_val, a_test = train_test_split(x_test, y_test, a_test, test_size=test_ratio, random_state=32) 

  return  x_train, x_test, x_val, y_train, y_test, y_val, a_train, a_test, a_val

def mae(prediction, true):
  return metrics.mean_absolute_error(prediction, true)

def accuracy(prediction, true):
  true = true.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)

  return (metrics.accuracy_score(prediction, true))

def precision(prediction, true):
  true = true.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return (metrics.precision_score(prediction, true))

def recall(prediction, true):
  true = true.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return (metrics.recall_score(prediction, true))

def tpr(prediction, true):
  return np.logical_and(prediction == 1, true== 1).sum()/prediction.shape[0]

def fpr(prediction, true):
  return np.logical_and(prediction == 1, true== 0).sum()/prediction.shape[0]

def tnr(prediction, true):
  return np.logical_and(prediction == 0, true== 0).sum()/prediction.shape[0]

def fnr(prediction, true):
  return np.logical_and(prediction == 0, true== 1).sum()/prediction.shape[0]


def dpr(prediction, true, sensitive_features):
  true = true.detach().numpy()
  sensitive_features = sensitive_features.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return demographic_parity_ratio(true,prediction, sensitive_features=sensitive_features)

def dpd(prediction, true, sensitive_features):
  true = true.detach().numpy()
  sensitive_features = sensitive_features.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return demographic_parity_difference(true,prediction, sensitive_features=sensitive_features)

def eor(prediction, true, sensitive_features):
  true = true.detach().numpy()
  sensitive_features = sensitive_features.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return equalized_odds_ratio(true, prediction, sensitive_features=sensitive_features)

def eod(prediction, true, sensitive_features):
  true = true.detach().numpy()
  sensitive_features = sensitive_features.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return equalized_odds_difference(true,prediction, sensitive_features=sensitive_features)
  

def test(model, x_test, y_test):
  x_test, y_test = torch.tensor(x_test), torch.tensor(y_test)
  outputs = model(x_test.float()) 
  loss = criterion(outputs, y_test.float())

  # log model results
  wandb.log({"test_loss": loss.item(), 
          "test_accuracy": accuracy(outputs, y_test), 
          "test_precision": precision(outputs, y_test), 
          "test_recall": recall(outputs, y_test)})
  wandb.watch(model)
  print ('Test Results, Loss: {:.4f},  Accuracy: {:.4f},  Precision: {:.4f},  Recall: {:.4f}' 
                  .format(loss.item(), 100 * accuracy(outputs, y_test),precision(outputs, y_test), recall(outputs, y_test)))



def train( model, criterion, optimizer, name,   lr,   x_train, x_val, y_train, y_val, a_train, a_val,sensitive,  alpha = None, regularizers = None, num_epochs = None):
  x_train, x_val, y_train, y_val, a_train, a_val = torch.from_numpy(x_train), torch.from_numpy(x_val), torch.from_numpy(y_train), torch.from_numpy(y_val), torch.from_numpy(a_train), torch.from_numpy(a_val)

  config= {
      "learning_rate":lr,
      "epochs": num_epochs,
      "model":model.__class__.__name__,
      "criterion":criterion.__class__.__name__,
      "optimizer":optimizer.__class__.__name__,
      "train_ratio":train_ratio, 
      "test_ratio":test_ratio,
      "data":name,
      "sensitive_race":sensitive
    }
  
  if regularizers != None:
    for i in range(len(regularizers)):
      config['regularizer_'+str(i)] = regularizers[i]
      config['alpha_'+str(i)] = alpha[i]

  # # store the hyperparameters in weights and bias
  wandb.init(project=name, entity="mie424",config = config)

  epoch_loss_train = []
  epoch_accuracy_train = []
  epoch_precision_train = []
  epoch_recall_train = []
  epoch_recall_dpr = []
  epoch_recall_dpd = []
  epoch_recall_eoo = []
  epoch_recall_eod = []
  
  epoch_loss_val = []
  epoch_accuracy_val = []
  epoch_precision_val = []
  epoch_recall_val = []

  # train loop
  for epoch in range(num_epochs):

    outputs = []
    # for i in range(0, x_train.shape[0], 10):
    optimizer.zero_grad()
  
    # x_i = x_train[i].float()

    # Forward pass
    outputs   = model(x_train.float()) 

      
        
    # outside of lop
    loss = criterion(outputs, y_train.float())
    if regularizers != None:
      # loss function
      for i in range(len(regularizers)):
        loss += regularizers[i](x_train.float(), outputs, a_train.float(), y_train.float()) #*alpha[i]
    # Backward and optimize
    
    loss.backward()
    optimizer.step()

    
    # store the epoch
    epoch_loss_train += [loss.item()]
    epoch_accuracy_train += [accuracy(outputs, y_train)]
    epoch_precision_train += [precision(outputs, y_train)]
    epoch_recall_train += [recall(outputs, y_train)]
    epoch_recall_dpr += [dpr(outputs, y_train.float(),a_train )]
    epoch_recall_dpd += [dpd(outputs, y_train.float(),a_train )]
    epoch_recall_eoo += [eor(outputs, y_train.float(),a_train )]
    epoch_recall_eod += [eod(outputs, y_train.float(),a_train )]

    # log model results
    wandb.log({"train_loss": epoch_loss_train[-1], 
              "train_accuracy": epoch_accuracy_train[-1], 
              "train_precision": epoch_precision_train[-1], 
              "train_recall": epoch_recall_train[-1],
              "train_dpr": epoch_recall_dpr[-1],
              "train_dpd": epoch_recall_dpd[-1],
              "train_eoo": epoch_recall_eoo[-1],
              "train_edd": epoch_recall_eod[-1]})
    
    wandb.watch(model)

    # print results
    print ('Epoch [{}/{}], Loss: {:.4f},  Accuracy: {:.4f},  Precision: {:.4f},  Recall: {:.4f}' 
                  .format(epoch+1, num_epochs, epoch_loss_train[-1], 100 * epoch_accuracy_train[-1],epoch_precision_train[-1],epoch_recall_train[-1]))
    
    # Validation loop
    with torch.no_grad():
      
      # model results
      outputs_v =  model(x_val.float()) 

      loss_v = criterion(outputs_v, y_val.float())
      if regularizers != None:
        # loss function
        for i in range(len(regularizers)):
          loss_v += regularizers[i](x_val.float(), outputs_v, a_val.float(), y_val.float()) #* alpha[i]
      

    
      # store resulst for the pass through
      epoch_loss_val += [loss_v.item()]
      epoch_accuracy_val += [accuracy(outputs_v, y_val)]
      epoch_precision_val += [precision(outputs_v, y_val)]
      epoch_recall_val += [recall(outputs_v, y_val)]
      
      # log and print model results
      wandb.log({"val_loss": epoch_loss_val[-1], 
                  "val_accuracy": epoch_accuracy_val[-1], 
                  "val_precision": epoch_precision_val[-1], 
                  "val_recall": epoch_recall_val[-1], })
      wandb.watch(model)

      print('Accuracy of validation : {} % ,  Loss: {:.4f},  Precision: {:.4f},  Recall: {:.4f}'.format(100 * epoch_accuracy_val[-1], epoch_loss_val[-1],epoch_precision_val[-1], epoch_recall_val[-1])) 

  # print ()

# %%
wandb.login()
# get df
name = "compas"

df, sensitive_name = get_dataset(name)

if name == "compas":
   x_var, y_var, sensitive = ['age', 'juv_fel_count', 'decile_score', 'juv_misd_count',
       'juv_other_count', 'priors_count', 'race', 'sex_Female', 'sex_Male',
       'c_charge_degree_F', 'c_charge_degree_M'], ['two_year_recid'], ['race']
else:

  x_var, y_var, sensitive = ['age', 'work_class', 'education', 'education_num',
        'marital-status', 'occupation', 'relationship', 'race', 'sex','capital_gain', 'capital_loss',
        
          'hours_per_week', 
        ]       , ['income'], ['race']
  # 'Loan_Amount_Term','LoanAmount',
name = "compas_2"

train_ratio, test_ratio = 0.7, 0.66

# select x, y, and sensitive features
x = df[x_var].values.astype(float)
y = df[y_var].values
sensitive_features = df[sensitive].values.astype(float)


# split 
x_train, x_test, x_val, y_train, y_test, y_val, a_train, a_test, a_val = split(x, y, sensitive_features, train_ratio, test_ratio)


num_epochs = 600

alpha_dp = 2000 # needs to be really high to work
DemographicParity = DemographicParityLoss(sensitive_classes=[0, 1], alpha=alpha_dp) # constraint 
alpha_eo = 0
EqualizedOdds = EqualizedOddsLoss(sensitive_classes=[0, 1], alpha=alpha_eo) # constraint 


alphas = [alpha_dp,alpha_eo]
regularizers = [DemographicParity,EqualizedOdds]
input_dim =  x_train.shape[1]# Two inputs x1 and x2 
output_dim = 1 # Single binary output 
lr = 0.0015

model = LogisticRegression(input_dim,output_dim)
criterion = torch.nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

train( model, 
      criterion=criterion, 
      optimizer=optimizer, 
      name=name, 
      lr=lr, 
      x_train=x_train, 
      x_val=x_val, 
      y_train=y_train, 
      y_val=y_val, 
      a_train=a_train, 
      a_val=a_val,  
      alpha = alphas,
      sensitive =  sensitive_name,
      regularizers = None, 
      num_epochs = num_epochs)

test(model, x_test, y_test)
wandb.finish()
# Out:
# wandb: WARNING Serializing object of type DataFrame that is 250032 bytes
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/content/wandb/run-20230401_224725-3vhear9w</code>
# Syncing run <strong><a href='https://wandb.ai/mie424/compas_2/runs/3vhear9w' target="_blank">jumping-music-9</a></strong> to <a href='https://wandb.ai/mie424/compas_2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mie424/compas_2' target="_blank">https://wandb.ai/mie424/compas_2</a>
#  View run at <a href='https://wandb.ai/mie424/compas_2/runs/3vhear9w' target="_blank">https://wandb.ai/mie424/compas_2/runs/3vhear9w</a>
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch [1/600], Loss: 4.0622,  Accuracy: 55.0208,  Precision: 0.0000,  Recall: 0.0000
# Accuracy of validation : 55.84239130434783 % ,  Loss: 3.6677,  Precision: 0.0000,  Recall: 0.0000
# Epoch [2/600], Loss: 3.7288,  Accuracy: 55.0208,  Precision: 0.0000,  Recall: 0.0000
# Accuracy of validation : 55.84239130434783 % ,  Loss: 3.3358,  Precision: 0.0000,  Recall: 0.0000
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch [3/600], Loss: 3.3960,  Accuracy: 55.0208,  Precision: 0.0000,  Recall: 0.0000
# Accuracy of validation : 55.84239130434783 % ,  Loss: 3.0053,  Precision: 0.0000,  Recall: 0.0000
# Epoch [4/600], Loss: 3.0646,  Accuracy: 55.0406,  Precision: 0.0004,  Recall: 1.0000
# Accuracy of validation : 56.1141304347826 % ,  Loss: 2.6776,  Precision: 0.0062,  Recall: 1.0000
# Epoch [5/600], Loss: 2.7359,  Accuracy: 55.1000,  Precision: 0.0018,  Recall: 1.0000
# Accuracy of validation : 56.25 % ,  Loss: 2.3545,  Precision: 0.0092,  Recall: 1.0000
# Epoch [6/600], Loss: 2.4119,  Accuracy: 55.1198,  Precision: 0.0031,  Recall: 0.7778
# Accuracy of validation : 56.25 % ,  Loss: 2.0399,  Precision: 0.0092,  Recall: 1.0000
# Epoch [7/600], Loss: 2.0965,  Accuracy: 55.2783,  Precision: 0.0070,  Recall: 0.8421
# Accuracy of validation : 56.79347826086957 % ,  Loss: 1.7398,  Precision: 0.0215,  Recall: 1.0000
# Epoch [8/600], Loss: 1.7961,  Accuracy: 55.5952,  Precision: 0.0154,  Recall: 0.8537
# Accuracy of validation : 57.472826086956516 % ,  Loss: 1.4633,  Precision: 0.0369,  Recall: 1.0000
# Epoch [9/600], Loss: 1.5197,  Accuracy: 56.2488,  Precision: 0.0339,  Recall: 0.8370
# Accuracy of validation : 58.28804347826087 % ,  Loss: 1.2221,  Precision: 0.0615,  Recall: 0.9091
# Epoch [10/600], Loss: 1.2786,  Accuracy: 56.9618,  Precision: 0.0581,  Recall: 0.7952
# Accuracy of validation : 59.10326086956522 % ,  Loss: 1.0276,  Precision: 0.0923,  Recall: 0.8333
# Epoch [11/600], Loss: 1.0837,  Accuracy: 57.8927,  Precision: 0.0898,  Recall: 0.7757
# Accuracy of validation : 60.733695652173914 % ,  Loss: 0.8871,  Precision: 0.1477,  Recall: 0.8000
# Epoch [12/600], Loss: 0.9417,  Accuracy: 58.5661,  Precision: 0.1233,  Recall: 0.7349
# Accuracy of validation : 61.00543478260869 % ,  Loss: 0.7984,  Precision: 0.1938,  Recall: 0.7159
# Epoch [13/600], Loss: 0.8510,  Accuracy: 59.7940,  Precision: 0.1722,  Recall: 0.7227
# Accuracy of validation : 62.5 % ,  Loss: 0.7504,  Precision: 0.2400,  Recall: 0.7290
# Epoch [14/600], Loss: 0.8008,  Accuracy: 60.6259,  Precision: 0.2171,  Recall: 0.7013
# Accuracy of validation : 62.90760869565217 % ,  Loss: 0.7277,  Precision: 0.2862,  Recall: 0.6940
# Epoch [15/600], Loss: 0.7764,  Accuracy: 60.5466,  Precision: 0.2488,  Recall: 0.6639
# Accuracy of validation : 63.315217391304344 % ,  Loss: 0.7181,  Precision: 0.3138,  Recall: 0.6846
# Epoch [16/600], Loss: 0.7654,  Accuracy: 60.6061,  Precision: 0.2743,  Recall: 0.6463
# Accuracy of validation : 62.90760869565217 % ,  Loss: 0.7142,  Precision: 0.3354,  Recall: 0.6566
# Epoch [17/600], Loss: 0.7606,  Accuracy: 60.6259,  Precision: 0.2950,  Recall: 0.6339
# Accuracy of validation : 62.90760869565217 % ,  Loss: 0.7125,  Precision: 0.3477,  Recall: 0.6494
# Epoch [18/600], Loss: 0.7582,  Accuracy: 60.5268,  Precision: 0.3074,  Recall: 0.6243
# Accuracy of validation : 62.90760869565217 % ,  Loss: 0.7116,  Precision: 0.3508,  Recall: 0.6477
# Epoch [19/600], Loss: 0.7569,  Accuracy: 60.4278,  Precision: 0.3157,  Recall: 0.6176
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7109,  Precision: 0.3631,  Recall: 0.6484
# Epoch [20/600], Loss: 0.7559,  Accuracy: 60.6061,  Precision: 0.3219,  Recall: 0.6195
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7103,  Precision: 0.3631,  Recall: 0.6484
# Epoch [21/600], Loss: 0.7550,  Accuracy: 60.5268,  Precision: 0.3245,  Recall: 0.6162
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7097,  Precision: 0.3631,  Recall: 0.6484
# Epoch [22/600], Loss: 0.7542,  Accuracy: 60.5863,  Precision: 0.3272,  Recall: 0.6166
# Accuracy of validation : 63.04347826086957 % ,  Loss: 0.7090,  Precision: 0.3631,  Recall: 0.6448
# Epoch [23/600], Loss: 0.7534,  Accuracy: 60.6061,  Precision: 0.3280,  Recall: 0.6167
# Accuracy of validation : 63.04347826086957 % ,  Loss: 0.7084,  Precision: 0.3631,  Recall: 0.6448
# Epoch [24/600], Loss: 0.7526,  Accuracy: 60.7645,  Precision: 0.3316,  Recall: 0.6192
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7078,  Precision: 0.3662,  Recall: 0.6467
# Epoch [25/600], Loss: 0.7518,  Accuracy: 60.8635,  Precision: 0.3338,  Recall: 0.6208
# Accuracy of validation : 63.315217391304344 % ,  Loss: 0.7072,  Precision: 0.3692,  Recall: 0.6486
# Epoch [26/600], Loss: 0.7510,  Accuracy: 60.8833,  Precision: 0.3342,  Recall: 0.6211
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7065,  Precision: 0.3692,  Recall: 0.6452
# Epoch [27/600], Loss: 0.7502,  Accuracy: 60.9031,  Precision: 0.3347,  Recall: 0.6214
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7059,  Precision: 0.3692,  Recall: 0.6452
# Epoch [28/600], Loss: 0.7495,  Accuracy: 60.9031,  Precision: 0.3347,  Recall: 0.6214
# Accuracy of validation : 63.315217391304344 % ,  Loss: 0.7053,  Precision: 0.3723,  Recall: 0.6471
# Epoch [29/600], Loss: 0.7487,  Accuracy: 60.9626,  Precision: 0.3351,  Recall: 0.6227
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7047,  Precision: 0.3723,  Recall: 0.6436
# Epoch [30/600], Loss: 0.7480,  Accuracy: 61.0022,  Precision: 0.3355,  Recall: 0.6236
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7041,  Precision: 0.3723,  Recall: 0.6436
# Epoch [31/600], Loss: 0.7472,  Accuracy: 61.0220,  Precision: 0.3364,  Recall: 0.6237
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7034,  Precision: 0.3723,  Recall: 0.6436
# Epoch [32/600], Loss: 0.7465,  Accuracy: 61.1210,  Precision: 0.3369,  Recall: 0.6260
# Accuracy of validation : 63.315217391304344 % ,  Loss: 0.7028,  Precision: 0.3754,  Recall: 0.6455
# Epoch [33/600], Loss: 0.7457,  Accuracy: 61.0814,  Precision: 0.3360,  Recall: 0.6254
# Accuracy of validation : 63.315217391304344 % ,  Loss: 0.7022,  Precision: 0.3754,  Recall: 0.6455
# Epoch [34/600], Loss: 0.7450,  Accuracy: 61.1012,  Precision: 0.3360,  Recall: 0.6259
# Accuracy of validation : 63.315217391304344 % ,  Loss: 0.7016,  Precision: 0.3754,  Recall: 0.6455
# Epoch [35/600], Loss: 0.7442,  Accuracy: 61.1012,  Precision: 0.3360,  Recall: 0.6259
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7010,  Precision: 0.3754,  Recall: 0.6421
# Epoch [36/600], Loss: 0.7435,  Accuracy: 61.1012,  Precision: 0.3360,  Recall: 0.6259
# Accuracy of validation : 63.17934782608695 % ,  Loss: 0.7004,  Precision: 0.3754,  Recall: 0.6421
# Epoch [37/600], Loss: 0.7428,  Accuracy: 61.0616,  Precision: 0.3342,  Recall: 0.6257
# Accuracy of validation : 63.315217391304344 % ,  Loss: 0.6998,  Precision: 0.3754,  Recall: 0.6455
# Epoch [38/600], Loss: 0.7421,  Accuracy: 61.0814,  Precision: 0.3347,  Recall: 0.6260
# Accuracy of validation : 63.315217391304344 % ,  Loss: 0.6993,  Precision: 0.3754,  Recall: 0.6455
# Epoch [39/600], Loss: 0.7413,  Accuracy: 61.0418,  Precision: 0.3347,  Recall: 0.6250
# Accuracy of validation : 63.45108695652174 % ,  Loss: 0.6987,  Precision: 0.3785,  Recall: 0.6474
# Epoch [40/600], Loss: 0.7406,  Accuracy: 61.0418,  Precision: 0.3347,  Recall: 0.6250
# Accuracy of validation : 63.58695652173913 % ,  Loss: 0.6981,  Precision: 0.3815,  Recall: 0.6492
# Epoch [41/600], Loss: 0.7399,  Accuracy: 61.0418,  Precision: 0.3347,  Recall: 0.6250
# Accuracy of validation : 63.58695652173913 % ,  Loss: 0.6975,  Precision: 0.3815,  Recall: 0.6492
# Epoch [42/600], Loss: 0.7392,  Accuracy: 61.0418,  Precision: 0.3347,  Recall: 0.6250
# Accuracy of validation : 63.58695652173913 % ,  Loss: 0.6970,  Precision: 0.3815,  Recall: 0.6492
# Epoch [43/600], Loss: 0.7385,  Accuracy: 61.0616,  Precision: 0.3364,  Recall: 0.6247
# Accuracy of validation : 63.58695652173913 % ,  Loss: 0.6964,  Precision: 0.3815,  Recall: 0.6492
# Epoch [44/600], Loss: 0.7378,  Accuracy: 61.1210,  Precision: 0.3369,  Recall: 0.6260
# Accuracy of validation : 63.58695652173913 % ,  Loss: 0.6958,  Precision: 0.3815,  Recall: 0.6492
# Epoch [45/600], Loss: 0.7371,  Accuracy: 61.1606,  Precision: 0.3373,  Recall: 0.6268
# Accuracy of validation : 63.58695652173913 % ,  Loss: 0.6953,  Precision: 0.3815,  Recall: 0.6492
# Epoch [46/600], Loss: 0.7364,  Accuracy: 61.2002,  Precision: 0.3382,  Recall: 0.6275
# Accuracy of validation : 63.58695652173913 % ,  Loss: 0.6947,  Precision: 0.3815,  Recall: 0.6492
# Epoch [47/600], Loss: 0.7357,  Accuracy: 61.2398,  Precision: 0.3382,  Recall: 0.6285
# Accuracy of validation : 63.45108695652174 % ,  Loss: 0.6942,  Precision: 0.3815,  Recall: 0.6458
# Epoch [48/600], Loss: 0.7350,  Accuracy: 61.2200,  Precision: 0.3377,  Recall: 0.6282
# Accuracy of validation : 63.45108695652174 % ,  Loss: 0.6936,  Precision: 0.3815,  Recall: 0.6458
# Epoch [49/600], Loss: 0.7344,  Accuracy: 61.2795,  Precision: 0.3373,  Recall: 0.6299
# Accuracy of validation : 63.58695652173913 % ,  Loss: 0.6931,  Precision: 0.3846,  Recall: 0.6477
# Epoch [50/600], Loss: 0.7337,  Accuracy: 61.2993,  Precision: 0.3377,  Recall: 0.6302
# Accuracy of validation : 63.722826086956516 % ,  Loss: 0.6925,  Precision: 0.3877,  Recall: 0.6495
# Epoch [51/600], Loss: 0.7330,  Accuracy: 61.2993,  Precision: 0.3377,  Recall: 0.6302
# Accuracy of validation : 63.722826086956516 % ,  Loss: 0.6920,  Precision: 0.3877,  Recall: 0.6495
# Epoch [52/600], Loss: 0.7324,  Accuracy: 61.2993,  Precision: 0.3377,  Recall: 0.6302
# Accuracy of validation : 63.722826086956516 % ,  Loss: 0.6914,  Precision: 0.3877,  Recall: 0.6495
# Epoch [53/600], Loss: 0.7317,  Accuracy: 61.2795,  Precision: 0.3377,  Recall: 0.6297
# Accuracy of validation : 63.858695652173914 % ,  Loss: 0.6909,  Precision: 0.3908,  Recall: 0.6513
# Epoch [54/600], Loss: 0.7310,  Accuracy: 61.2795,  Precision: 0.3377,  Recall: 0.6297
# Accuracy of validation : 63.99456521739131 % ,  Loss: 0.6904,  Precision: 0.3938,  Recall: 0.6531
# Epoch [55/600], Loss: 0.7304,  Accuracy: 61.2597,  Precision: 0.3377,  Recall: 0.6292
# Accuracy of validation : 63.99456521739131 % ,  Loss: 0.6898,  Precision: 0.3938,  Recall: 0.6531
# Epoch [56/600], Loss: 0.7297,  Accuracy: 61.2597,  Precision: 0.3377,  Recall: 0.6292
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6893,  Precision: 0.3938,  Recall: 0.6564
# Epoch [57/600], Loss: 0.7291,  Accuracy: 61.3191,  Precision: 0.3391,  Recall: 0.6301
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6888,  Precision: 0.3938,  Recall: 0.6564
# Epoch [58/600], Loss: 0.7284,  Accuracy: 61.3389,  Precision: 0.3395,  Recall: 0.6304
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6883,  Precision: 0.3938,  Recall: 0.6564
# Epoch [59/600], Loss: 0.7278,  Accuracy: 61.4577,  Precision: 0.3413,  Recall: 0.6327
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6878,  Precision: 0.3938,  Recall: 0.6564
# Epoch [60/600], Loss: 0.7272,  Accuracy: 61.4775,  Precision: 0.3413,  Recall: 0.6332
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6873,  Precision: 0.3938,  Recall: 0.6564
# Epoch [61/600], Loss: 0.7265,  Accuracy: 61.4973,  Precision: 0.3417,  Recall: 0.6335
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6868,  Precision: 0.3938,  Recall: 0.6564
# Epoch [62/600], Loss: 0.7259,  Accuracy: 61.5171,  Precision: 0.3421,  Recall: 0.6338
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6863,  Precision: 0.3969,  Recall: 0.6582
# Epoch [63/600], Loss: 0.7253,  Accuracy: 61.5369,  Precision: 0.3426,  Recall: 0.6341
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6858,  Precision: 0.3969,  Recall: 0.6582
# Epoch [64/600], Loss: 0.7246,  Accuracy: 61.5964,  Precision: 0.3430,  Recall: 0.6354
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6853,  Precision: 0.3969,  Recall: 0.6582
# Epoch [65/600], Loss: 0.7240,  Accuracy: 61.6558,  Precision: 0.3443,  Recall: 0.6363
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6848,  Precision: 0.3969,  Recall: 0.6582
# Epoch [66/600], Loss: 0.7234,  Accuracy: 61.7152,  Precision: 0.3448,  Recall: 0.6376
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6843,  Precision: 0.3969,  Recall: 0.6582
# Epoch [67/600], Loss: 0.7228,  Accuracy: 61.6954,  Precision: 0.3448,  Recall: 0.6371
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6838,  Precision: 0.3969,  Recall: 0.6582
# Epoch [68/600], Loss: 0.7222,  Accuracy: 61.7548,  Precision: 0.3452,  Recall: 0.6384
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6833,  Precision: 0.3969,  Recall: 0.6582
# Epoch [69/600], Loss: 0.7216,  Accuracy: 61.7548,  Precision: 0.3452,  Recall: 0.6384
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6828,  Precision: 0.3969,  Recall: 0.6582
# Epoch [70/600], Loss: 0.7210,  Accuracy: 61.7548,  Precision: 0.3457,  Recall: 0.6382
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6823,  Precision: 0.3938,  Recall: 0.6564
# Epoch [71/600], Loss: 0.7204,  Accuracy: 61.7548,  Precision: 0.3457,  Recall: 0.6382
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6819,  Precision: 0.3908,  Recall: 0.6580
# Epoch [72/600], Loss: 0.7198,  Accuracy: 61.7746,  Precision: 0.3461,  Recall: 0.6385
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6814,  Precision: 0.3908,  Recall: 0.6580
# Epoch [73/600], Loss: 0.7192,  Accuracy: 61.7944,  Precision: 0.3465,  Recall: 0.6388
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6809,  Precision: 0.3908,  Recall: 0.6580
# Epoch [74/600], Loss: 0.7186,  Accuracy: 61.8538,  Precision: 0.3465,  Recall: 0.6404
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6804,  Precision: 0.3908,  Recall: 0.6580
# Epoch [75/600], Loss: 0.7180,  Accuracy: 61.8340,  Precision: 0.3461,  Recall: 0.6401
# Accuracy of validation : 63.99456521739131 % ,  Loss: 0.6800,  Precision: 0.3908,  Recall: 0.6546
# Epoch [76/600], Loss: 0.7174,  Accuracy: 61.8340,  Precision: 0.3461,  Recall: 0.6401
# Accuracy of validation : 63.99456521739131 % ,  Loss: 0.6795,  Precision: 0.3908,  Recall: 0.6546
# Epoch [77/600], Loss: 0.7168,  Accuracy: 61.8340,  Precision: 0.3461,  Recall: 0.6401
# Accuracy of validation : 63.99456521739131 % ,  Loss: 0.6791,  Precision: 0.3908,  Recall: 0.6546
# Epoch [78/600], Loss: 0.7163,  Accuracy: 61.8538,  Precision: 0.3461,  Recall: 0.6406
# Accuracy of validation : 63.99456521739131 % ,  Loss: 0.6786,  Precision: 0.3908,  Recall: 0.6546
# Epoch [79/600], Loss: 0.7157,  Accuracy: 61.8142,  Precision: 0.3457,  Recall: 0.6398
# Accuracy of validation : 63.99456521739131 % ,  Loss: 0.6781,  Precision: 0.3908,  Recall: 0.6546
# Epoch [80/600], Loss: 0.7151,  Accuracy: 61.8340,  Precision: 0.3461,  Recall: 0.6401
# Accuracy of validation : 63.99456521739131 % ,  Loss: 0.6777,  Precision: 0.3908,  Recall: 0.6546
# Epoch [81/600], Loss: 0.7146,  Accuracy: 61.8736,  Precision: 0.3470,  Recall: 0.6407
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6772,  Precision: 0.3938,  Recall: 0.6564
# Epoch [82/600], Loss: 0.7140,  Accuracy: 61.9133,  Precision: 0.3465,  Recall: 0.6419
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6768,  Precision: 0.3938,  Recall: 0.6564
# Epoch [83/600], Loss: 0.7134,  Accuracy: 61.9331,  Precision: 0.3470,  Recall: 0.6422
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6764,  Precision: 0.3938,  Recall: 0.6564
# Epoch [84/600], Loss: 0.7129,  Accuracy: 61.9529,  Precision: 0.3474,  Recall: 0.6425
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6759,  Precision: 0.3938,  Recall: 0.6564
# Epoch [85/600], Loss: 0.7123,  Accuracy: 61.9529,  Precision: 0.3474,  Recall: 0.6425
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6755,  Precision: 0.3938,  Recall: 0.6564
# Epoch [86/600], Loss: 0.7118,  Accuracy: 61.9331,  Precision: 0.3479,  Recall: 0.6418
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6750,  Precision: 0.3938,  Recall: 0.6598
# Epoch [87/600], Loss: 0.7112,  Accuracy: 61.9133,  Precision: 0.3474,  Recall: 0.6415
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6746,  Precision: 0.3938,  Recall: 0.6598
# Epoch [88/600], Loss: 0.7107,  Accuracy: 61.9331,  Precision: 0.3479,  Recall: 0.6418
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6742,  Precision: 0.3938,  Recall: 0.6598
# Epoch [89/600], Loss: 0.7101,  Accuracy: 61.9727,  Precision: 0.3487,  Recall: 0.6423
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6738,  Precision: 0.3938,  Recall: 0.6598
# Epoch [90/600], Loss: 0.7096,  Accuracy: 62.0321,  Precision: 0.3505,  Recall: 0.6430
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6733,  Precision: 0.3938,  Recall: 0.6598
# Epoch [91/600], Loss: 0.7091,  Accuracy: 62.1113,  Precision: 0.3514,  Recall: 0.6446
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6729,  Precision: 0.3938,  Recall: 0.6564
# Epoch [92/600], Loss: 0.7085,  Accuracy: 62.1707,  Precision: 0.3509,  Recall: 0.6464
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6725,  Precision: 0.3938,  Recall: 0.6564
# Epoch [93/600], Loss: 0.7080,  Accuracy: 62.1509,  Precision: 0.3505,  Recall: 0.6461
# Accuracy of validation : 64.13043478260869 % ,  Loss: 0.6721,  Precision: 0.3938,  Recall: 0.6564
# Epoch [94/600], Loss: 0.7075,  Accuracy: 62.1509,  Precision: 0.3509,  Recall: 0.6459
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6717,  Precision: 0.3938,  Recall: 0.6598
# Epoch [95/600], Loss: 0.7070,  Accuracy: 62.1509,  Precision: 0.3509,  Recall: 0.6459
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6712,  Precision: 0.3938,  Recall: 0.6598
# Epoch [96/600], Loss: 0.7064,  Accuracy: 62.1311,  Precision: 0.3509,  Recall: 0.6453
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6708,  Precision: 0.3938,  Recall: 0.6598
# Epoch [97/600], Loss: 0.7059,  Accuracy: 62.1707,  Precision: 0.3518,  Recall: 0.6459
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6704,  Precision: 0.3938,  Recall: 0.6598
# Epoch [98/600], Loss: 0.7054,  Accuracy: 62.2103,  Precision: 0.3518,  Recall: 0.6470
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6700,  Precision: 0.3938,  Recall: 0.6598
# Epoch [99/600], Loss: 0.7049,  Accuracy: 62.2103,  Precision: 0.3518,  Recall: 0.6470
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6696,  Precision: 0.3938,  Recall: 0.6598
# Epoch [100/600], Loss: 0.7044,  Accuracy: 62.2103,  Precision: 0.3518,  Recall: 0.6470
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6692,  Precision: 0.3938,  Recall: 0.6598
# Epoch [101/600], Loss: 0.7039,  Accuracy: 62.2103,  Precision: 0.3518,  Recall: 0.6470
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6688,  Precision: 0.3938,  Recall: 0.6598
# Epoch [102/600], Loss: 0.7034,  Accuracy: 62.1905,  Precision: 0.3523,  Recall: 0.6462
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6684,  Precision: 0.3969,  Recall: 0.6615
# Epoch [103/600], Loss: 0.7029,  Accuracy: 62.1905,  Precision: 0.3523,  Recall: 0.6462
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6680,  Precision: 0.3938,  Recall: 0.6598
# Epoch [104/600], Loss: 0.7024,  Accuracy: 62.2301,  Precision: 0.3531,  Recall: 0.6468
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6676,  Precision: 0.3938,  Recall: 0.6598
# Epoch [105/600], Loss: 0.7019,  Accuracy: 62.2301,  Precision: 0.3531,  Recall: 0.6468
# Accuracy of validation : 64.2663043478261 % ,  Loss: 0.6673,  Precision: 0.3938,  Recall: 0.6598
# Epoch [106/600], Loss: 0.7014,  Accuracy: 62.2301,  Precision: 0.3531,  Recall: 0.6468
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6669,  Precision: 0.3969,  Recall: 0.6615
# Epoch [107/600], Loss: 0.7009,  Accuracy: 62.2698,  Precision: 0.3540,  Recall: 0.6473
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6665,  Precision: 0.3969,  Recall: 0.6615
# Epoch [108/600], Loss: 0.7004,  Accuracy: 62.3094,  Precision: 0.3545,  Recall: 0.6481
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6661,  Precision: 0.3969,  Recall: 0.6615
# Epoch [109/600], Loss: 0.6999,  Accuracy: 62.3094,  Precision: 0.3545,  Recall: 0.6481
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6657,  Precision: 0.3969,  Recall: 0.6615
# Epoch [110/600], Loss: 0.6994,  Accuracy: 62.3490,  Precision: 0.3549,  Recall: 0.6490
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6654,  Precision: 0.3969,  Recall: 0.6615
# Epoch [111/600], Loss: 0.6989,  Accuracy: 62.3688,  Precision: 0.3549,  Recall: 0.6495
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6650,  Precision: 0.3969,  Recall: 0.6615
# Epoch [112/600], Loss: 0.6985,  Accuracy: 62.3688,  Precision: 0.3545,  Recall: 0.6497
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6646,  Precision: 0.3969,  Recall: 0.6615
# Epoch [113/600], Loss: 0.6980,  Accuracy: 62.4480,  Precision: 0.3554,  Recall: 0.6513
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6642,  Precision: 0.3969,  Recall: 0.6615
# Epoch [114/600], Loss: 0.6975,  Accuracy: 62.5470,  Precision: 0.3571,  Recall: 0.6530
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6639,  Precision: 0.3969,  Recall: 0.6615
# Epoch [115/600], Loss: 0.6970,  Accuracy: 62.5272,  Precision: 0.3571,  Recall: 0.6525
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6635,  Precision: 0.3969,  Recall: 0.6615
# Epoch [116/600], Loss: 0.6966,  Accuracy: 62.5272,  Precision: 0.3571,  Recall: 0.6525
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6631,  Precision: 0.3969,  Recall: 0.6615
# Epoch [117/600], Loss: 0.6961,  Accuracy: 62.5867,  Precision: 0.3584,  Recall: 0.6533
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6628,  Precision: 0.3969,  Recall: 0.6615
# Epoch [118/600], Loss: 0.6957,  Accuracy: 62.6263,  Precision: 0.3593,  Recall: 0.6538
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6624,  Precision: 0.3969,  Recall: 0.6615
# Epoch [119/600], Loss: 0.6952,  Accuracy: 62.6659,  Precision: 0.3589,  Recall: 0.6551
# Accuracy of validation : 64.40217391304348 % ,  Loss: 0.6621,  Precision: 0.3969,  Recall: 0.6615
# Epoch [120/600], Loss: 0.6947,  Accuracy: 62.6659,  Precision: 0.3589,  Recall: 0.6551
# Accuracy of validation : 64.53804347826086 % ,  Loss: 0.6617,  Precision: 0.4031,  Recall: 0.6616
# Epoch [121/600], Loss: 0.6943,  Accuracy: 62.6659,  Precision: 0.3589,  Recall: 0.6551
# Accuracy of validation : 64.53804347826086 % ,  Loss: 0.6614,  Precision: 0.4031,  Recall: 0.6616
# Epoch [122/600], Loss: 0.6938,  Accuracy: 62.7055,  Precision: 0.3589,  Recall: 0.6562
# Accuracy of validation : 64.67391304347827 % ,  Loss: 0.6610,  Precision: 0.4062,  Recall: 0.6633
# Epoch [123/600], Loss: 0.6934,  Accuracy: 62.7253,  Precision: 0.3584,  Recall: 0.6570
# Accuracy of validation : 64.67391304347827 % ,  Loss: 0.6607,  Precision: 0.4062,  Recall: 0.6633
# Epoch [124/600], Loss: 0.6929,  Accuracy: 62.7649,  Precision: 0.3589,  Recall: 0.6578
# Accuracy of validation : 64.67391304347827 % ,  Loss: 0.6603,  Precision: 0.4062,  Recall: 0.6633
# Epoch [125/600], Loss: 0.6925,  Accuracy: 62.7649,  Precision: 0.3589,  Recall: 0.6578
# Accuracy of validation : 64.67391304347827 % ,  Loss: 0.6600,  Precision: 0.4062,  Recall: 0.6633
# Epoch [126/600], Loss: 0.6920,  Accuracy: 62.8045,  Precision: 0.3593,  Recall: 0.6586
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6596,  Precision: 0.4092,  Recall: 0.6650
# Epoch [127/600], Loss: 0.6916,  Accuracy: 62.8045,  Precision: 0.3598,  Recall: 0.6583
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6593,  Precision: 0.4092,  Recall: 0.6650
# Epoch [128/600], Loss: 0.6912,  Accuracy: 62.8045,  Precision: 0.3593,  Recall: 0.6586
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6590,  Precision: 0.4092,  Recall: 0.6650
# Epoch [129/600], Loss: 0.6907,  Accuracy: 62.8837,  Precision: 0.3611,  Recall: 0.6597
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6586,  Precision: 0.4092,  Recall: 0.6650
# Epoch [130/600], Loss: 0.6903,  Accuracy: 62.8837,  Precision: 0.3606,  Recall: 0.6600
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6583,  Precision: 0.4092,  Recall: 0.6650
# Epoch [131/600], Loss: 0.6899,  Accuracy: 62.9432,  Precision: 0.3611,  Recall: 0.6613
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6580,  Precision: 0.4092,  Recall: 0.6650
# Epoch [132/600], Loss: 0.6894,  Accuracy: 62.9432,  Precision: 0.3615,  Recall: 0.6610
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6576,  Precision: 0.4092,  Recall: 0.6650
# Epoch [133/600], Loss: 0.6890,  Accuracy: 62.9630,  Precision: 0.3620,  Recall: 0.6613
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6573,  Precision: 0.4092,  Recall: 0.6650
# Epoch [134/600], Loss: 0.6886,  Accuracy: 62.9630,  Precision: 0.3620,  Recall: 0.6613
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6570,  Precision: 0.4092,  Recall: 0.6650
# Epoch [135/600], Loss: 0.6882,  Accuracy: 62.9828,  Precision: 0.3624,  Recall: 0.6616
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6566,  Precision: 0.4123,  Recall: 0.6667
# Epoch [136/600], Loss: 0.6877,  Accuracy: 63.0026,  Precision: 0.3628,  Recall: 0.6618
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6563,  Precision: 0.4123,  Recall: 0.6667
# Epoch [137/600], Loss: 0.6873,  Accuracy: 62.9828,  Precision: 0.3628,  Recall: 0.6613
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6560,  Precision: 0.4123,  Recall: 0.6667
# Epoch [138/600], Loss: 0.6869,  Accuracy: 63.0818,  Precision: 0.3642,  Recall: 0.6632
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6557,  Precision: 0.4123,  Recall: 0.6667
# Epoch [139/600], Loss: 0.6865,  Accuracy: 63.0818,  Precision: 0.3642,  Recall: 0.6632
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6554,  Precision: 0.4123,  Recall: 0.6667
# Epoch [140/600], Loss: 0.6861,  Accuracy: 63.0818,  Precision: 0.3642,  Recall: 0.6632
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6551,  Precision: 0.4123,  Recall: 0.6667
# Epoch [141/600], Loss: 0.6857,  Accuracy: 63.1016,  Precision: 0.3646,  Recall: 0.6635
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6547,  Precision: 0.4123,  Recall: 0.6667
# Epoch [142/600], Loss: 0.6853,  Accuracy: 63.1016,  Precision: 0.3646,  Recall: 0.6635
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6544,  Precision: 0.4123,  Recall: 0.6667
# Epoch [143/600], Loss: 0.6849,  Accuracy: 63.1412,  Precision: 0.3659,  Recall: 0.6637
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6541,  Precision: 0.4154,  Recall: 0.6683
# Epoch [144/600], Loss: 0.6845,  Accuracy: 63.1610,  Precision: 0.3672,  Recall: 0.6635
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6538,  Precision: 0.4154,  Recall: 0.6716
# Epoch [145/600], Loss: 0.6841,  Accuracy: 63.1412,  Precision: 0.3672,  Recall: 0.6630
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6535,  Precision: 0.4154,  Recall: 0.6716
# Epoch [146/600], Loss: 0.6837,  Accuracy: 63.1412,  Precision: 0.3672,  Recall: 0.6630
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6532,  Precision: 0.4154,  Recall: 0.6716
# Epoch [147/600], Loss: 0.6833,  Accuracy: 63.1808,  Precision: 0.3677,  Recall: 0.6638
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6529,  Precision: 0.4154,  Recall: 0.6716
# Epoch [148/600], Loss: 0.6829,  Accuracy: 63.2204,  Precision: 0.3677,  Recall: 0.6648
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6526,  Precision: 0.4154,  Recall: 0.6716
# Epoch [149/600], Loss: 0.6825,  Accuracy: 63.2006,  Precision: 0.3672,  Recall: 0.6645
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6523,  Precision: 0.4154,  Recall: 0.6716
# Epoch [150/600], Loss: 0.6821,  Accuracy: 63.2402,  Precision: 0.3672,  Recall: 0.6656
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6520,  Precision: 0.4123,  Recall: 0.6700
# Epoch [151/600], Loss: 0.6817,  Accuracy: 63.2799,  Precision: 0.3677,  Recall: 0.6664
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6517,  Precision: 0.4123,  Recall: 0.6700
# Epoch [152/600], Loss: 0.6813,  Accuracy: 63.2799,  Precision: 0.3677,  Recall: 0.6664
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6514,  Precision: 0.4123,  Recall: 0.6700
# Epoch [153/600], Loss: 0.6809,  Accuracy: 63.2799,  Precision: 0.3677,  Recall: 0.6664
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6511,  Precision: 0.4123,  Recall: 0.6734
# Epoch [154/600], Loss: 0.6806,  Accuracy: 63.2997,  Precision: 0.3672,  Recall: 0.6672
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6508,  Precision: 0.4092,  Recall: 0.6717
# Epoch [155/600], Loss: 0.6802,  Accuracy: 63.2601,  Precision: 0.3664,  Recall: 0.6667
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6505,  Precision: 0.4123,  Recall: 0.6734
# Epoch [156/600], Loss: 0.6798,  Accuracy: 63.2402,  Precision: 0.3664,  Recall: 0.6661
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6503,  Precision: 0.4123,  Recall: 0.6734
# Epoch [157/600], Loss: 0.6794,  Accuracy: 63.2402,  Precision: 0.3664,  Recall: 0.6661
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6500,  Precision: 0.4154,  Recall: 0.6750
# Epoch [158/600], Loss: 0.6790,  Accuracy: 63.2402,  Precision: 0.3659,  Recall: 0.6664
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6497,  Precision: 0.4154,  Recall: 0.6750
# Epoch [159/600], Loss: 0.6787,  Accuracy: 63.2601,  Precision: 0.3664,  Recall: 0.6667
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6494,  Precision: 0.4154,  Recall: 0.6750
# Epoch [160/600], Loss: 0.6783,  Accuracy: 63.2601,  Precision: 0.3664,  Recall: 0.6667
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6491,  Precision: 0.4154,  Recall: 0.6750
# Epoch [161/600], Loss: 0.6779,  Accuracy: 63.2601,  Precision: 0.3664,  Recall: 0.6667
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6489,  Precision: 0.4154,  Recall: 0.6750
# Epoch [162/600], Loss: 0.6776,  Accuracy: 63.2601,  Precision: 0.3664,  Recall: 0.6667
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6486,  Precision: 0.4154,  Recall: 0.6750
# Epoch [163/600], Loss: 0.6772,  Accuracy: 63.2601,  Precision: 0.3664,  Recall: 0.6667
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6483,  Precision: 0.4154,  Recall: 0.6750
# Epoch [164/600], Loss: 0.6768,  Accuracy: 63.2997,  Precision: 0.3668,  Recall: 0.6675
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6480,  Precision: 0.4154,  Recall: 0.6750
# Epoch [165/600], Loss: 0.6765,  Accuracy: 63.3393,  Precision: 0.3677,  Recall: 0.6680
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6478,  Precision: 0.4123,  Recall: 0.6734
# Epoch [166/600], Loss: 0.6761,  Accuracy: 63.2799,  Precision: 0.3677,  Recall: 0.6664
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6475,  Precision: 0.4123,  Recall: 0.6768
# Epoch [167/600], Loss: 0.6758,  Accuracy: 63.2601,  Precision: 0.3672,  Recall: 0.6661
# Accuracy of validation : 65.48913043478261 % ,  Loss: 0.6472,  Precision: 0.4154,  Recall: 0.6784
# Epoch [168/600], Loss: 0.6754,  Accuracy: 63.2402,  Precision: 0.3672,  Recall: 0.6656
# Accuracy of validation : 65.48913043478261 % ,  Loss: 0.6469,  Precision: 0.4154,  Recall: 0.6784
# Epoch [169/600], Loss: 0.6751,  Accuracy: 63.2402,  Precision: 0.3677,  Recall: 0.6653
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6467,  Precision: 0.4154,  Recall: 0.6750
# Epoch [170/600], Loss: 0.6747,  Accuracy: 63.2601,  Precision: 0.3681,  Recall: 0.6656
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6464,  Precision: 0.4154,  Recall: 0.6750
# Epoch [171/600], Loss: 0.6744,  Accuracy: 63.2601,  Precision: 0.3681,  Recall: 0.6656
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6462,  Precision: 0.4154,  Recall: 0.6750
# Epoch [172/600], Loss: 0.6740,  Accuracy: 63.2601,  Precision: 0.3681,  Recall: 0.6656
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6459,  Precision: 0.4154,  Recall: 0.6750
# Epoch [173/600], Loss: 0.6737,  Accuracy: 63.2799,  Precision: 0.3686,  Recall: 0.6659
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6456,  Precision: 0.4154,  Recall: 0.6750
# Epoch [174/600], Loss: 0.6733,  Accuracy: 63.2601,  Precision: 0.3686,  Recall: 0.6653
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6454,  Precision: 0.4154,  Recall: 0.6750
# Epoch [175/600], Loss: 0.6730,  Accuracy: 63.2402,  Precision: 0.3686,  Recall: 0.6648
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6451,  Precision: 0.4154,  Recall: 0.6750
# Epoch [176/600], Loss: 0.6726,  Accuracy: 63.2799,  Precision: 0.3690,  Recall: 0.6656
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6449,  Precision: 0.4154,  Recall: 0.6750
# Epoch [177/600], Loss: 0.6723,  Accuracy: 63.3195,  Precision: 0.3699,  Recall: 0.6661
# Accuracy of validation : 65.48913043478261 % ,  Loss: 0.6446,  Precision: 0.4154,  Recall: 0.6784
# Epoch [178/600], Loss: 0.6720,  Accuracy: 63.3393,  Precision: 0.3703,  Recall: 0.6664
# Accuracy of validation : 65.48913043478261 % ,  Loss: 0.6444,  Precision: 0.4154,  Recall: 0.6784
# Epoch [179/600], Loss: 0.6716,  Accuracy: 63.3591,  Precision: 0.3708,  Recall: 0.6667
# Accuracy of validation : 65.48913043478261 % ,  Loss: 0.6441,  Precision: 0.4154,  Recall: 0.6784
# Epoch [180/600], Loss: 0.6713,  Accuracy: 63.3591,  Precision: 0.3708,  Recall: 0.6667
# Accuracy of validation : 65.48913043478261 % ,  Loss: 0.6439,  Precision: 0.4154,  Recall: 0.6784
# Epoch [181/600], Loss: 0.6710,  Accuracy: 63.3987,  Precision: 0.3712,  Recall: 0.6675
# Accuracy of validation : 65.48913043478261 % ,  Loss: 0.6436,  Precision: 0.4154,  Recall: 0.6784
# Epoch [182/600], Loss: 0.6706,  Accuracy: 63.4185,  Precision: 0.3712,  Recall: 0.6680
# Accuracy of validation : 65.48913043478261 % ,  Loss: 0.6434,  Precision: 0.4154,  Recall: 0.6784
# Epoch [183/600], Loss: 0.6703,  Accuracy: 63.4383,  Precision: 0.3716,  Recall: 0.6683
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6431,  Precision: 0.4123,  Recall: 0.6768
# Epoch [184/600], Loss: 0.6700,  Accuracy: 63.4977,  Precision: 0.3725,  Recall: 0.6693
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6429,  Precision: 0.4092,  Recall: 0.6751
# Epoch [185/600], Loss: 0.6697,  Accuracy: 63.4977,  Precision: 0.3725,  Recall: 0.6693
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6426,  Precision: 0.4092,  Recall: 0.6751
# Epoch [186/600], Loss: 0.6693,  Accuracy: 63.4977,  Precision: 0.3725,  Recall: 0.6693
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6424,  Precision: 0.4092,  Recall: 0.6751
# Epoch [187/600], Loss: 0.6690,  Accuracy: 63.4977,  Precision: 0.3725,  Recall: 0.6693
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6422,  Precision: 0.4092,  Recall: 0.6751
# Epoch [188/600], Loss: 0.6687,  Accuracy: 63.4977,  Precision: 0.3725,  Recall: 0.6693
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6419,  Precision: 0.4123,  Recall: 0.6768
# Epoch [189/600], Loss: 0.6684,  Accuracy: 63.4977,  Precision: 0.3725,  Recall: 0.6693
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6417,  Precision: 0.4123,  Recall: 0.6734
# Epoch [190/600], Loss: 0.6681,  Accuracy: 63.4977,  Precision: 0.3721,  Recall: 0.6696
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6414,  Precision: 0.4123,  Recall: 0.6734
# Epoch [191/600], Loss: 0.6677,  Accuracy: 63.5571,  Precision: 0.3734,  Recall: 0.6704
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6412,  Precision: 0.4123,  Recall: 0.6734
# Epoch [192/600], Loss: 0.6674,  Accuracy: 63.5571,  Precision: 0.3734,  Recall: 0.6704
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6410,  Precision: 0.4123,  Recall: 0.6734
# Epoch [193/600], Loss: 0.6671,  Accuracy: 63.5968,  Precision: 0.3734,  Recall: 0.6714
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6407,  Precision: 0.4123,  Recall: 0.6734
# Epoch [194/600], Loss: 0.6668,  Accuracy: 63.5968,  Precision: 0.3734,  Recall: 0.6714
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6405,  Precision: 0.4123,  Recall: 0.6734
# Epoch [195/600], Loss: 0.6665,  Accuracy: 63.5968,  Precision: 0.3738,  Recall: 0.6711
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6403,  Precision: 0.4123,  Recall: 0.6734
# Epoch [196/600], Loss: 0.6662,  Accuracy: 63.6364,  Precision: 0.3743,  Recall: 0.6719
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6401,  Precision: 0.4123,  Recall: 0.6734
# Epoch [197/600], Loss: 0.6659,  Accuracy: 63.6562,  Precision: 0.3747,  Recall: 0.6722
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6398,  Precision: 0.4123,  Recall: 0.6734
# Epoch [198/600], Loss: 0.6656,  Accuracy: 63.6760,  Precision: 0.3752,  Recall: 0.6725
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6396,  Precision: 0.4123,  Recall: 0.6734
# Epoch [199/600], Loss: 0.6653,  Accuracy: 63.6958,  Precision: 0.3756,  Recall: 0.6727
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6394,  Precision: 0.4123,  Recall: 0.6734
# Epoch [200/600], Loss: 0.6650,  Accuracy: 63.6958,  Precision: 0.3756,  Recall: 0.6727
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6392,  Precision: 0.4154,  Recall: 0.6750
# Epoch [201/600], Loss: 0.6647,  Accuracy: 63.7156,  Precision: 0.3756,  Recall: 0.6732
# Accuracy of validation : 65.35326086956522 % ,  Loss: 0.6389,  Precision: 0.4154,  Recall: 0.6750
# Epoch [202/600], Loss: 0.6644,  Accuracy: 63.7354,  Precision: 0.3760,  Recall: 0.6735
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6387,  Precision: 0.4154,  Recall: 0.6716
# Epoch [203/600], Loss: 0.6641,  Accuracy: 63.7354,  Precision: 0.3760,  Recall: 0.6735
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6385,  Precision: 0.4154,  Recall: 0.6716
# Epoch [204/600], Loss: 0.6638,  Accuracy: 63.7552,  Precision: 0.3765,  Recall: 0.6738
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6383,  Precision: 0.4154,  Recall: 0.6716
# Epoch [205/600], Loss: 0.6635,  Accuracy: 63.8146,  Precision: 0.3769,  Recall: 0.6751
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6381,  Precision: 0.4154,  Recall: 0.6716
# Epoch [206/600], Loss: 0.6632,  Accuracy: 63.8344,  Precision: 0.3769,  Recall: 0.6756
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6379,  Precision: 0.4154,  Recall: 0.6716
# Epoch [207/600], Loss: 0.6629,  Accuracy: 63.7948,  Precision: 0.3769,  Recall: 0.6745
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6377,  Precision: 0.4154,  Recall: 0.6683
# Epoch [208/600], Loss: 0.6626,  Accuracy: 63.7948,  Precision: 0.3765,  Recall: 0.6748
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6374,  Precision: 0.4154,  Recall: 0.6683
# Epoch [209/600], Loss: 0.6624,  Accuracy: 63.8542,  Precision: 0.3778,  Recall: 0.6756
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6372,  Precision: 0.4154,  Recall: 0.6683
# Epoch [210/600], Loss: 0.6621,  Accuracy: 63.9136,  Precision: 0.3787,  Recall: 0.6766
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6370,  Precision: 0.4154,  Recall: 0.6683
# Epoch [211/600], Loss: 0.6618,  Accuracy: 63.9731,  Precision: 0.3796,  Recall: 0.6777
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6368,  Precision: 0.4154,  Recall: 0.6683
# Epoch [212/600], Loss: 0.6615,  Accuracy: 63.9533,  Precision: 0.3791,  Recall: 0.6774
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6366,  Precision: 0.4185,  Recall: 0.6700
# Epoch [213/600], Loss: 0.6612,  Accuracy: 63.9533,  Precision: 0.3791,  Recall: 0.6774
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6364,  Precision: 0.4185,  Recall: 0.6700
# Epoch [214/600], Loss: 0.6609,  Accuracy: 63.9533,  Precision: 0.3791,  Recall: 0.6774
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6362,  Precision: 0.4185,  Recall: 0.6700
# Epoch [215/600], Loss: 0.6607,  Accuracy: 63.9335,  Precision: 0.3787,  Recall: 0.6772
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6360,  Precision: 0.4185,  Recall: 0.6700
# Epoch [216/600], Loss: 0.6604,  Accuracy: 63.9533,  Precision: 0.3791,  Recall: 0.6774
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6358,  Precision: 0.4185,  Recall: 0.6700
# Epoch [217/600], Loss: 0.6601,  Accuracy: 63.9533,  Precision: 0.3791,  Recall: 0.6774
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6356,  Precision: 0.4185,  Recall: 0.6700
# Epoch [218/600], Loss: 0.6598,  Accuracy: 64.0127,  Precision: 0.3804,  Recall: 0.6782
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6354,  Precision: 0.4185,  Recall: 0.6700
# Epoch [219/600], Loss: 0.6596,  Accuracy: 63.9929,  Precision: 0.3809,  Recall: 0.6774
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6352,  Precision: 0.4154,  Recall: 0.6683
# Epoch [220/600], Loss: 0.6593,  Accuracy: 64.0127,  Precision: 0.3809,  Recall: 0.6779
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6350,  Precision: 0.4154,  Recall: 0.6650
# Epoch [221/600], Loss: 0.6590,  Accuracy: 64.0325,  Precision: 0.3809,  Recall: 0.6784
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6348,  Precision: 0.4154,  Recall: 0.6650
# Epoch [222/600], Loss: 0.6588,  Accuracy: 64.0721,  Precision: 0.3818,  Recall: 0.6789
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6346,  Precision: 0.4185,  Recall: 0.6667
# Epoch [223/600], Loss: 0.6585,  Accuracy: 64.0721,  Precision: 0.3818,  Recall: 0.6789
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6344,  Precision: 0.4185,  Recall: 0.6667
# Epoch [224/600], Loss: 0.6582,  Accuracy: 64.0919,  Precision: 0.3822,  Recall: 0.6792
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6342,  Precision: 0.4185,  Recall: 0.6667
# Epoch [225/600], Loss: 0.6580,  Accuracy: 64.0919,  Precision: 0.3822,  Recall: 0.6792
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6340,  Precision: 0.4185,  Recall: 0.6667
# Epoch [226/600], Loss: 0.6577,  Accuracy: 64.0919,  Precision: 0.3822,  Recall: 0.6792
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6338,  Precision: 0.4185,  Recall: 0.6667
# Epoch [227/600], Loss: 0.6574,  Accuracy: 64.1117,  Precision: 0.3822,  Recall: 0.6797
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6336,  Precision: 0.4185,  Recall: 0.6667
# Epoch [228/600], Loss: 0.6572,  Accuracy: 64.1117,  Precision: 0.3822,  Recall: 0.6797
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6334,  Precision: 0.4185,  Recall: 0.6667
# Epoch [229/600], Loss: 0.6569,  Accuracy: 64.1711,  Precision: 0.3835,  Recall: 0.6805
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6333,  Precision: 0.4185,  Recall: 0.6667
# Epoch [230/600], Loss: 0.6567,  Accuracy: 64.1711,  Precision: 0.3835,  Recall: 0.6805
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6331,  Precision: 0.4185,  Recall: 0.6667
# Epoch [231/600], Loss: 0.6564,  Accuracy: 64.1711,  Precision: 0.3835,  Recall: 0.6805
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6329,  Precision: 0.4185,  Recall: 0.6700
# Epoch [232/600], Loss: 0.6561,  Accuracy: 64.1513,  Precision: 0.3840,  Recall: 0.6797
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6327,  Precision: 0.4185,  Recall: 0.6700
# Epoch [233/600], Loss: 0.6559,  Accuracy: 64.1711,  Precision: 0.3840,  Recall: 0.6802
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6325,  Precision: 0.4185,  Recall: 0.6700
# Epoch [234/600], Loss: 0.6556,  Accuracy: 64.1909,  Precision: 0.3840,  Recall: 0.6807
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6323,  Precision: 0.4185,  Recall: 0.6700
# Epoch [235/600], Loss: 0.6554,  Accuracy: 64.2305,  Precision: 0.3849,  Recall: 0.6812
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6322,  Precision: 0.4185,  Recall: 0.6700
# Epoch [236/600], Loss: 0.6551,  Accuracy: 64.2702,  Precision: 0.3857,  Recall: 0.6817
# Accuracy of validation : 65.21739130434783 % ,  Loss: 0.6320,  Precision: 0.4185,  Recall: 0.6700
# Epoch [237/600], Loss: 0.6549,  Accuracy: 64.2503,  Precision: 0.3857,  Recall: 0.6812
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6318,  Precision: 0.4154,  Recall: 0.6683
# Epoch [238/600], Loss: 0.6546,  Accuracy: 64.2503,  Precision: 0.3857,  Recall: 0.6812
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6316,  Precision: 0.4154,  Recall: 0.6683
# Epoch [239/600], Loss: 0.6544,  Accuracy: 64.3098,  Precision: 0.3866,  Recall: 0.6822
# Accuracy of validation : 65.08152173913044 % ,  Loss: 0.6314,  Precision: 0.4154,  Recall: 0.6683
# Epoch [240/600], Loss: 0.6541,  Accuracy: 64.3098,  Precision: 0.3871,  Recall: 0.6819
# Accuracy of validation : 64.94565217391305 % ,  Loss: 0.6313,  Precision: 0.4123,  Recall: 0.6667
# Epoch [241/600], Loss: 0.6539,  Accuracy: 64.3098,  Precision: 0.3871,  Recall: 0.6819
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6311,  Precision: 0.4092,  Recall: 0.6650
# Epoch [242/600], Loss: 0.6537,  Accuracy: 64.3098,  Precision: 0.3871,  Recall: 0.6819
# Accuracy of validation : 64.67391304347827 % ,  Loss: 0.6309,  Precision: 0.4092,  Recall: 0.6617
# Epoch [243/600], Loss: 0.6534,  Accuracy: 64.2900,  Precision: 0.3871,  Recall: 0.6814
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6307,  Precision: 0.4123,  Recall: 0.6634
# Epoch [244/600], Loss: 0.6532,  Accuracy: 64.3296,  Precision: 0.3879,  Recall: 0.6819
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6306,  Precision: 0.4123,  Recall: 0.6634
# Epoch [245/600], Loss: 0.6529,  Accuracy: 64.3296,  Precision: 0.3879,  Recall: 0.6819
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6304,  Precision: 0.4123,  Recall: 0.6634
# Epoch [246/600], Loss: 0.6527,  Accuracy: 64.3296,  Precision: 0.3884,  Recall: 0.6816
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6302,  Precision: 0.4123,  Recall: 0.6634
# Epoch [247/600], Loss: 0.6525,  Accuracy: 64.3890,  Precision: 0.3897,  Recall: 0.6823
# Accuracy of validation : 64.80978260869566 % ,  Loss: 0.6301,  Precision: 0.4123,  Recall: 0.6634
# ...
# Epoch [531/600], Loss: 0.6165,  Accuracy: 67.6570,  Precision: 0.4813,  Recall: 0.7061
# Accuracy of validation : 66.84782608695652 % ,  Loss: 0.6070,  Precision: 0.4677,  Recall: 0.6816
# Epoch [532/600], Loss: 0.6165,  Accuracy: 67.6570,  Precision: 0.4813,  Recall: 0.7061
# Accuracy of validation : 66.84782608695652 % ,  Loss: 0.6069,  Precision: 0.4677,  Recall: 0.6816
# Epoch [533/600], Loss: 0.6164,  Accuracy: 67.6570,  Precision: 0.4813,  Recall: 0.7061
# Accuracy of validation : 66.84782608695652 % ,  Loss: 0.6069,  Precision: 0.4677,  Recall: 0.6816
# Epoch [534/600], Loss: 0.6164,  Accuracy: 67.6768,  Precision: 0.4817,  Recall: 0.7063
# Accuracy of validation : 66.84782608695652 % ,  Loss: 0.6069,  Precision: 0.4677,  Recall: 0.6816
# Epoch [535/600], Loss: 0.6163,  Accuracy: 67.6966,  Precision: 0.4822,  Recall: 0.7065
# Accuracy of validation : 66.84782608695652 % ,  Loss: 0.6069,  Precision: 0.4677,  Recall: 0.6816
# Epoch [536/600], Loss: 0.6163,  Accuracy: 67.6966,  Precision: 0.4822,  Recall: 0.7065
# Accuracy of validation : 66.84782608695652 % ,  Loss: 0.6068,  Precision: 0.4677,  Recall: 0.6816
# Epoch [537/600], Loss: 0.6162,  Accuracy: 67.6768,  Precision: 0.4822,  Recall: 0.7060
# Accuracy of validation : 66.71195652173914 % ,  Loss: 0.6068,  Precision: 0.4646,  Recall: 0.6802
# Epoch [538/600], Loss: 0.6162,  Accuracy: 67.6966,  Precision: 0.4826,  Recall: 0.7062
# Accuracy of validation : 66.71195652173914 % ,  Loss: 0.6068,  Precision: 0.4646,  Recall: 0.6802
# Epoch [539/600], Loss: 0.6161,  Accuracy: 67.7164,  Precision: 0.4830,  Recall: 0.7064
# Accuracy of validation : 66.71195652173914 % ,  Loss: 0.6068,  Precision: 0.4646,  Recall: 0.6802
# Epoch [540/600], Loss: 0.6160,  Accuracy: 67.7164,  Precision: 0.4835,  Recall: 0.7061
# Accuracy of validation : 66.71195652173914 % ,  Loss: 0.6067,  Precision: 0.4646,  Recall: 0.6802
# Epoch [541/600], Loss: 0.6160,  Accuracy: 67.7362,  Precision: 0.4839,  Recall: 0.7063
# Accuracy of validation : 66.71195652173914 % ,  Loss: 0.6067,  Precision: 0.4646,  Recall: 0.6802
# Epoch [542/600], Loss: 0.6159,  Accuracy: 67.7560,  Precision: 0.4839,  Recall: 0.7068
# Accuracy of validation : 66.84782608695652 % ,  Loss: 0.6067,  Precision: 0.4677,  Recall: 0.6816
# Epoch [543/600], Loss: 0.6159,  Accuracy: 67.7956,  Precision: 0.4848,  Recall: 0.7071
# Accuracy of validation : 66.9836956521739 % ,  Loss: 0.6066,  Precision: 0.4677,  Recall: 0.6847
# Epoch [544/600], Loss: 0.6158,  Accuracy: 67.7956,  Precision: 0.4848,  Recall: 0.7071
# Accuracy of validation : 66.9836956521739 % ,  Loss: 0.6066,  Precision: 0.4677,  Recall: 0.6847
# Epoch [545/600], Loss: 0.6158,  Accuracy: 67.8352,  Precision: 0.4857,  Recall: 0.7075
# Accuracy of validation : 66.9836956521739 % ,  Loss: 0.6066,  Precision: 0.4677,  Recall: 0.6847
# Epoch [546/600], Loss: 0.6157,  Accuracy: 67.8550,  Precision: 0.4870,  Recall: 0.7072
# Accuracy of validation : 67.11956521739131 % ,  Loss: 0.6066,  Precision: 0.4708,  Recall: 0.6861
# Epoch [547/600], Loss: 0.6157,  Accuracy: 67.8550,  Precision: 0.4870,  Recall: 0.7072
# Accuracy of validation : 67.11956521739131 % ,  Loss: 0.6065,  Precision: 0.4708,  Recall: 0.6861
# Epoch [548/600], Loss: 0.6156,  Accuracy: 67.8550,  Precision: 0.4870,  Recall: 0.7072
# Accuracy of validation : 67.11956521739131 % ,  Loss: 0.6065,  Precision: 0.4708,  Recall: 0.6861
# Epoch [549/600], Loss: 0.6156,  Accuracy: 67.8748,  Precision: 0.4875,  Recall: 0.7073
# Accuracy of validation : 67.11956521739131 % ,  Loss: 0.6065,  Precision: 0.4708,  Recall: 0.6861
# Epoch [550/600], Loss: 0.6155,  Accuracy: 67.8748,  Precision: 0.4875,  Recall: 0.7073
# Accuracy of validation : 67.11956521739131 % ,  Loss: 0.6065,  Precision: 0.4708,  Recall: 0.6861
# Epoch [551/600], Loss: 0.6155,  Accuracy: 67.8550,  Precision: 0.4879,  Recall: 0.7066
# Accuracy of validation : 67.11956521739131 % ,  Loss: 0.6064,  Precision: 0.4708,  Recall: 0.6861
# Epoch [552/600], Loss: 0.6154,  Accuracy: 67.8748,  Precision: 0.4879,  Recall: 0.7071
# Accuracy of validation : 67.25543478260869 % ,  Loss: 0.6064,  Precision: 0.4708,  Recall: 0.6892
# Epoch [553/600], Loss: 0.6153,  Accuracy: 67.8748,  Precision: 0.4879,  Recall: 0.7071
# Accuracy of validation : 67.25543478260869 % ,  Loss: 0.6064,  Precision: 0.4708,  Recall: 0.6892
# Epoch [554/600], Loss: 0.6153,  Accuracy: 67.8748,  Precision: 0.4879,  Recall: 0.7071
# Accuracy of validation : 67.25543478260869 % ,  Loss: 0.6064,  Precision: 0.4708,  Recall: 0.6892
# Epoch [555/600], Loss: 0.6152,  Accuracy: 67.8748,  Precision: 0.4879,  Recall: 0.7071
# Accuracy of validation : 67.25543478260869 % ,  Loss: 0.6064,  Precision: 0.4708,  Recall: 0.6892
# Epoch [556/600], Loss: 0.6152,  Accuracy: 67.9144,  Precision: 0.4888,  Recall: 0.7075
# Accuracy of validation : 67.25543478260869 % ,  Loss: 0.6063,  Precision: 0.4708,  Recall: 0.6892
# Epoch [557/600], Loss: 0.6151,  Accuracy: 67.8946,  Precision: 0.4883,  Recall: 0.7073
# Accuracy of validation : 67.25543478260869 % ,  Loss: 0.6063,  Precision: 0.4708,  Recall: 0.6892
# Epoch [558/600], Loss: 0.6151,  Accuracy: 67.8748,  Precision: 0.4883,  Recall: 0.7068
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6063,  Precision: 0.4738,  Recall: 0.6906
# Epoch [559/600], Loss: 0.6150,  Accuracy: 67.8748,  Precision: 0.4883,  Recall: 0.7068
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6063,  Precision: 0.4738,  Recall: 0.6906
# Epoch [560/600], Loss: 0.6150,  Accuracy: 67.9541,  Precision: 0.4897,  Recall: 0.7078
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6062,  Precision: 0.4738,  Recall: 0.6906
# Epoch [561/600], Loss: 0.6149,  Accuracy: 67.9541,  Precision: 0.4897,  Recall: 0.7078
# Accuracy of validation : 67.52717391304348 % ,  Loss: 0.6062,  Precision: 0.4769,  Recall: 0.6920
# Epoch [562/600], Loss: 0.6149,  Accuracy: 67.9541,  Precision: 0.4897,  Recall: 0.7078
# Accuracy of validation : 67.52717391304348 % ,  Loss: 0.6062,  Precision: 0.4769,  Recall: 0.6920
# Epoch [563/600], Loss: 0.6148,  Accuracy: 67.9739,  Precision: 0.4910,  Recall: 0.7075
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6062,  Precision: 0.4738,  Recall: 0.6906
# Epoch [564/600], Loss: 0.6148,  Accuracy: 67.9541,  Precision: 0.4910,  Recall: 0.7070
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6061,  Precision: 0.4738,  Recall: 0.6906
# Epoch [565/600], Loss: 0.6147,  Accuracy: 67.9342,  Precision: 0.4905,  Recall: 0.7069
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6061,  Precision: 0.4738,  Recall: 0.6906
# Epoch [566/600], Loss: 0.6147,  Accuracy: 67.9342,  Precision: 0.4905,  Recall: 0.7069
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6061,  Precision: 0.4738,  Recall: 0.6906
# Epoch [567/600], Loss: 0.6147,  Accuracy: 67.9342,  Precision: 0.4905,  Recall: 0.7069
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6061,  Precision: 0.4738,  Recall: 0.6906
# Epoch [568/600], Loss: 0.6146,  Accuracy: 67.9541,  Precision: 0.4910,  Recall: 0.7070
# Accuracy of validation : 67.52717391304348 % ,  Loss: 0.6061,  Precision: 0.4769,  Recall: 0.6920
# Epoch [569/600], Loss: 0.6146,  Accuracy: 67.9937,  Precision: 0.4919,  Recall: 0.7074
# Accuracy of validation : 67.52717391304348 % ,  Loss: 0.6060,  Precision: 0.4769,  Recall: 0.6920
# Epoch [570/600], Loss: 0.6145,  Accuracy: 67.9937,  Precision: 0.4919,  Recall: 0.7074
# Accuracy of validation : 67.52717391304348 % ,  Loss: 0.6060,  Precision: 0.4769,  Recall: 0.6920
# Epoch [571/600], Loss: 0.6145,  Accuracy: 67.9937,  Precision: 0.4914,  Recall: 0.7077
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6060,  Precision: 0.4769,  Recall: 0.6889
# Epoch [572/600], Loss: 0.6144,  Accuracy: 68.0135,  Precision: 0.4914,  Recall: 0.7081
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6060,  Precision: 0.4769,  Recall: 0.6889
# Epoch [573/600], Loss: 0.6144,  Accuracy: 68.0135,  Precision: 0.4914,  Recall: 0.7081
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6060,  Precision: 0.4769,  Recall: 0.6889
# Epoch [574/600], Loss: 0.6143,  Accuracy: 68.0531,  Precision: 0.4923,  Recall: 0.7085
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6059,  Precision: 0.4769,  Recall: 0.6889
# Epoch [575/600], Loss: 0.6143,  Accuracy: 68.0531,  Precision: 0.4927,  Recall: 0.7082
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6059,  Precision: 0.4769,  Recall: 0.6889
# Epoch [576/600], Loss: 0.6142,  Accuracy: 68.0333,  Precision: 0.4932,  Recall: 0.7075
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6059,  Precision: 0.4769,  Recall: 0.6889
# Epoch [577/600], Loss: 0.6142,  Accuracy: 68.0927,  Precision: 0.4949,  Recall: 0.7078
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6059,  Precision: 0.4769,  Recall: 0.6889
# Epoch [578/600], Loss: 0.6141,  Accuracy: 68.0927,  Precision: 0.4949,  Recall: 0.7078
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6059,  Precision: 0.4769,  Recall: 0.6889
# Epoch [579/600], Loss: 0.6141,  Accuracy: 68.1125,  Precision: 0.4949,  Recall: 0.7083
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6058,  Precision: 0.4769,  Recall: 0.6889
# Epoch [580/600], Loss: 0.6140,  Accuracy: 68.1719,  Precision: 0.4958,  Recall: 0.7091
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6058,  Precision: 0.4738,  Recall: 0.6906
# Epoch [581/600], Loss: 0.6140,  Accuracy: 68.1917,  Precision: 0.4963,  Recall: 0.7093
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6058,  Precision: 0.4738,  Recall: 0.6906
# Epoch [582/600], Loss: 0.6140,  Accuracy: 68.1917,  Precision: 0.4963,  Recall: 0.7093
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6058,  Precision: 0.4738,  Recall: 0.6906
# Epoch [583/600], Loss: 0.6139,  Accuracy: 68.1719,  Precision: 0.4963,  Recall: 0.7088
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6058,  Precision: 0.4738,  Recall: 0.6906
# Epoch [584/600], Loss: 0.6139,  Accuracy: 68.1719,  Precision: 0.4963,  Recall: 0.7088
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6057,  Precision: 0.4738,  Recall: 0.6906
# Epoch [585/600], Loss: 0.6138,  Accuracy: 68.1719,  Precision: 0.4963,  Recall: 0.7088
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6057,  Precision: 0.4738,  Recall: 0.6906
# Epoch [586/600], Loss: 0.6138,  Accuracy: 68.1917,  Precision: 0.4967,  Recall: 0.7090
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6057,  Precision: 0.4738,  Recall: 0.6906
# Epoch [587/600], Loss: 0.6137,  Accuracy: 68.1917,  Precision: 0.4967,  Recall: 0.7090
# Accuracy of validation : 67.52717391304348 % ,  Loss: 0.6057,  Precision: 0.4769,  Recall: 0.6920
# Epoch [588/600], Loss: 0.6137,  Accuracy: 68.1917,  Precision: 0.4971,  Recall: 0.7087
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6057,  Precision: 0.4769,  Recall: 0.6889
# Epoch [589/600], Loss: 0.6137,  Accuracy: 68.2511,  Precision: 0.4989,  Recall: 0.7090
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6057,  Precision: 0.4769,  Recall: 0.6889
# Epoch [590/600], Loss: 0.6136,  Accuracy: 68.2511,  Precision: 0.4989,  Recall: 0.7090
# Accuracy of validation : 67.3913043478261 % ,  Loss: 0.6056,  Precision: 0.4769,  Recall: 0.6889
# Epoch [591/600], Loss: 0.6136,  Accuracy: 68.2511,  Precision: 0.4989,  Recall: 0.7090
# Accuracy of validation : 67.52717391304348 % ,  Loss: 0.6056,  Precision: 0.4800,  Recall: 0.6903
# Epoch [592/600], Loss: 0.6135,  Accuracy: 68.2313,  Precision: 0.4989,  Recall: 0.7086
# Accuracy of validation : 67.52717391304348 % ,  Loss: 0.6056,  Precision: 0.4800,  Recall: 0.6903
# Epoch [593/600], Loss: 0.6135,  Accuracy: 68.2709,  Precision: 0.4998,  Recall: 0.7089
# Accuracy of validation : 67.66304347826086 % ,  Loss: 0.6056,  Precision: 0.4831,  Recall: 0.6916
# Epoch [594/600], Loss: 0.6134,  Accuracy: 68.2908,  Precision: 0.5007,  Recall: 0.7089
# Accuracy of validation : 67.66304347826086 % ,  Loss: 0.6056,  Precision: 0.4831,  Recall: 0.6916
# Epoch [595/600], Loss: 0.6134,  Accuracy: 68.2709,  Precision: 0.5011,  Recall: 0.7082
# Accuracy of validation : 67.66304347826086 % ,  Loss: 0.6055,  Precision: 0.4831,  Recall: 0.6916
# Epoch [596/600], Loss: 0.6134,  Accuracy: 68.2511,  Precision: 0.5007,  Recall: 0.7080
# Accuracy of validation : 67.66304347826086 % ,  Loss: 0.6055,  Precision: 0.4831,  Recall: 0.6916
# Epoch [597/600], Loss: 0.6133,  Accuracy: 68.2511,  Precision: 0.5007,  Recall: 0.7080
# Accuracy of validation : 67.66304347826086 % ,  Loss: 0.6055,  Precision: 0.4831,  Recall: 0.6916
# Epoch [598/600], Loss: 0.6133,  Accuracy: 68.2511,  Precision: 0.5007,  Recall: 0.7080
# Accuracy of validation : 67.66304347826086 % ,  Loss: 0.6055,  Precision: 0.4831,  Recall: 0.6916
# Epoch [599/600], Loss: 0.6132,  Accuracy: 68.2511,  Precision: 0.5007,  Recall: 0.7080
# Accuracy of validation : 67.79891304347827 % ,  Loss: 0.6055,  Precision: 0.4831,  Recall: 0.6947
# Epoch [600/600], Loss: 0.6132,  Accuracy: 68.2511,  Precision: 0.5007,  Recall: 0.7080
# Accuracy of validation : 67.79891304347827 % ,  Loss: 0.6055,  Precision: 0.4831,  Recall: 0.6947
# Test Results, Loss: 0.6066,  Accuracy: 67.2498,  Precision: 0.4840,  Recall: 0.7092
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.117 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.008290…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>train_dpd</td><td>▁▄▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>train_dpr</td><td>▁███████████▇█▇▇▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>train_edd</td><td>▁▄▄▅▄▅▅▅▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇██████</td></tr><tr><td>train_eoo</td><td>▁███████████▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▅▅▅</td></tr><tr><td>train_loss</td><td>█▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_precision</td><td>▁▅▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>train_recall</td><td>█▂▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▄▄▃▄▃▃▃▄▄</td></tr><tr><td>val_accuracy</td><td>▁▅▅▅▆▅▆▆▆▆▆▆▆▆▆▆▆▆▆▇▆▆▇▇▇▇▇▇▇▇▇█▇▇▇▇████</td></tr><tr><td>val_loss</td><td>█▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_precision</td><td>▁▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████████████</td></tr><tr><td>val_recall</td><td>█▁▁▁▁▁▁▁▁▂▁▂▂▂▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>0.6725</td></tr><tr><td>test_loss</td><td>0.60663</td></tr><tr><td>test_precision</td><td>0.48397</td></tr><tr><td>test_recall</td><td>0.70917</td></tr><tr><td>train_accuracy</td><td>0.68251</td></tr><tr><td>train_dpd</td><td>0.2314</td></tr><tr><td>train_dpr</td><td>0.41626</td></tr><tr><td>train_edd</td><td>0.29442</td></tr><tr><td>train_eoo</td><td>0.37525</td></tr><tr><td>train_loss</td><td>0.61319</td></tr><tr><td>train_precision</td><td>0.50066</td></tr><tr><td>train_recall</td><td>0.70797</td></tr><tr><td>val_accuracy</td><td>0.67799</td></tr><tr><td>val_loss</td><td>0.60546</td></tr><tr><td>val_precision</td><td>0.48308</td></tr><tr><td>val_recall</td><td>0.69469</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">jumping-music-9</strong> at: <a href='https://wandb.ai/mie424/compas_2/runs/3vhear9w' target="_blank">https://wandb.ai/mie424/compas_2/runs/3vhear9w</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230401_224725-3vhear9w/logs</code>

# %%
df['race'].unique()
# Out:
# array([1, 0], dtype=object)
