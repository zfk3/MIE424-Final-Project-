# %%
# !pip install wandb
# !pip install fairlearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wandb in /usr/local/lib/python3.9/dist-packages (0.14.0)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.9/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (5.9.4)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (8.1.3)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (3.1.31)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from wandb) (6.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (1.18.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (2.27.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb) (67.6.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.9/dist-packages (from wandb) (1.3.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fairlearn
#   Downloading fairlearn-0.8.0-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.0/235.0 KB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.2.2)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.4.4)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25.1->fairlearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25.1->fairlearn) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.1->fairlearn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.1->fairlearn) (1.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=0.25.1->fairlearn) (1.16.0)
# Installing collected packages: fairlearn
# Successfully installed fairlearn-0.8.0

# %%
import pandas as pd
import plotly
import plotly.express as px
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model, metrics, preprocessing
from datetime import datetime, timedelta

import wandb
import random

from fairlearn.postprocessing import ThresholdOptimizer, plot_threshold_optimizer
from fairlearn.metrics import demographic_parity_ratio, equalized_odds_ratio
from fairlearn.reductions import DemographicParity


from google.colab import drive

from sklearn.model_selection import KFold, cross_val_score



drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %%
import torch
from torch import nn
from torch.nn import functional as F


class ConstraintLoss(nn.Module):
    def __init__(self, n_class=2, alpha=1, p_norm=2):
        super(ConstraintLoss, self).__init__()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.alpha = alpha
        self.p_norm = p_norm
        self.n_class = n_class
        self.n_constraints = 2
        self.dim_condition = self.n_class + 1
        self.M = torch.zeros((self.n_constraints, self.dim_condition))
        self.c = torch.zeros(self.n_constraints)

    def mu_f(self, X=None, y=None, sensitive=None):
        return torch.zeros(self.n_constraints)

    def forward(self, X, out, sensitive, y=None):
        # Reshapes sensitive attribute tensor to the same shape as the output 
        sensitive = sensitive.view(out.shape)
        # Reshapes y (label) tensor to the same shape as the output 
        if isinstance(y, torch.Tensor):
            y = y.view(out.shape)
        # Get probability output by applying sigmoid (like logistic regression?)
        out = torch.sigmoid(out)
        # Get the mu_f value given these tensors 
        mu = self.mu_f(X=X, out=out, sensitive=sensitive, y=y)
        # Gap constraint???
        # Apply relu to matrix vector product of M compared to mu-c 
        # Using cuda if applicable (self.device references)
        gap_constraint = F.relu(
            torch.mv(self.M.to(self.device), mu.to(self.device)) - self.c.to(self.device)
        )
        # Using the L2 Norm of the gap constraint as regularizer with alpha parameter. 
        if self.p_norm == 2:
            cons = self.alpha * torch.dot(gap_constraint, gap_constraint)
        else:
            cons = self.alpha * torch.dot(gap_constraint.detach(), gap_constraint)
        return cons


class DemographicParityLoss(ConstraintLoss):
    def __init__(self, sensitive_classes=[0, 1], alpha=1, p_norm=2):
        """loss of demograpfhic parity

        Args:
            sensitive_classes (list, optional): list of unique values of sensitive attribute. Defaults to [0, 1].
            alpha (int, optional): [description]. Defaults to 1.
            p_norm (int, optional): [description]. Defaults to 2.
        """
        self.sensitive_classes = sensitive_classes
        self.n_class = len(sensitive_classes)
        super(DemographicParityLoss, self).__init__(
            n_class=self.n_class, alpha=alpha, p_norm=p_norm
        )
        
        self.n_constraints = 2 * self.n_class
        self.dim_condition = self.n_class + 1
        self.M = torch.zeros((self.n_constraints, self.dim_condition))
        for i in range(self.n_constraints):
            j = i % 2
            if j == 0:
                self.M[i, j] = 1.0
                self.M[i, -1] = -1.0
            else:
                self.M[i, j - 1] = -1.0
                self.M[i, -1] = 1.0
            #print(self.M)
        self.c = torch.zeros(self.n_constraints)

    def mu_f(self, X, out, sensitive, y=None):
        expected_values_list = []
        for v in self.sensitive_classes:
            # Get the index for each of the senstive classes 
            idx_true = sensitive == v  # torch.bool
            # Get the average prediction for that sensitive class
            expected_values_list.append(out[idx_true].mean())
        # Append the overall mean to the expected values list
        print(expected_values_list) 
        expected_values_list.append(out.mean())
        return torch.stack(expected_values_list)

    def forward(self, X, out, sensitive, y=None):
        return super(DemographicParityLoss, self).forward(X, out, sensitive)

# Convex 
class EqualiedOddsLoss(ConstraintLoss):
    def __init__(self, sensitive_classes=[0, 1], alpha=1, p_norm=2):
        """loss of demograpfhic parity

        Args:
            sensitive_classes (list, optional): list of unique values of sensitive attribute. Defaults to [0, 1].
            alpha (int, optional): [description]. Defaults to 1.
            p_norm (int, optional): [description]. Defaults to 2.
        """
        self.sensitive_classes = sensitive_classes
        self.y_classes = [0, 1]
        self.n_class = len(sensitive_classes)
        self.n_y_class = len(self.y_classes)
        super(EqualiedOddsLoss, self).__init__(n_class=self.n_class, alpha=alpha, p_norm=p_norm)
        # K:  number of constraint : (|A| x |Y| x {+, -})
        self.n_constraints = self.n_class * self.n_y_class * 2
        # J : dim of conditions  : ((|A|+1) x |Y|)
        self.dim_condition = self.n_y_class * (self.n_class + 1)
        self.M = torch.zeros((self.n_constraints, self.dim_condition))
        # make M (K * J): (|A| x |Y| x {+, -})  *   (|A|+1) x |Y|) )
        self.c = torch.zeros(self.n_constraints)
        element_K_A = self.sensitive_classes + [None]
        for i_a, a_0 in enumerate(self.sensitive_classes):
            for i_y, y_0 in enumerate(self.y_classes):
                for i_s, s in enumerate([-1, 1]):
                    for j_y, y_1 in enumerate(self.y_classes):
                        for j_a, a_1 in enumerate(element_K_A):
                            i = i_a * (2 * self.n_y_class) + i_y * 2 + i_s
                            j = j_y + self.n_y_class * j_a
                            self.M[i, j] = self.__element_M(a_0, a_1, y_1, y_1, s)

    def __element_M(self, a0, a1, y0, y1, s):
        if a0 is None or a1 is None:
            x = y0 == y1
            return -1 * s * x
        else:
            x = (a0 == a1) & (y0 == y1)
            return s * float(x)

    def mu_f(self, X, out, sensitive, y):
        expected_values_list = []
        for u in self.sensitive_classes:
            for v in self.y_classes:
                idx_true = (y == v) * (sensitive == u)  # torch.bool
                expected_values_list.append(out[idx_true].mean())
        # sensitive is star
        for v in self.y_classes:
            idx_true = y == v
            expected_values_list.append(out[idx_true].mean())
        return torch.stack(expected_values_list)

    def forward(self, X, out, sensitive, y):
        return super(EqualiedOddsLoss, self).forward(X, out, sensitive, y=y)

# %%
# https://towardsdatascience.com/logistic-regression-with-pytorch-3c8bbea594be
class LogisticRegression(torch.nn.Module):
     def __init__(self, input_dim, output_dim):
         super(LogisticRegression, self).__init__()
         self.linear = torch.nn.Linear(input_dim, output_dim)
     def forward(self, x):
         (self.linear) 

         outputs = torch.sigmoid(self.linear(x))
         return outputs

# %%
def label_encode(df):

  for i in df.columns:
    tmp = df[i].iloc[0]
    
    if type(tmp) != int or type(tmp) != float:
      le = preprocessing.LabelEncoder()
      df[i] = le.fit_transform(df[i].values)

  return df

def one_hot(df):
  
  for i in df.columns:
    tmp = df[i].iloc[0]

    if i == 'Loan_Status':
      pass
    elif type(tmp) == str:
      df = pd.get_dummies(df, columns = [i])
      # ohe = preprocessing.OneHotEncoder()
      # df[i] =  ohe.fit_transform(df[i].values.reshape(-1, 1)) # double check the shape

  return df


def get_dataset(name):
  if name == 'compas':
    compas_link ='https://raw.githubusercontent.com/propublica/compas-analysis/master/compas-scores-two-years.csv'
    df = pd.read_csv(compas_link, on_bad_lines='skip')
    df = label_encode(df)

  else: 
    df = pd.read_csv("/content/drive/MyDrive/Project/Data/adult.csv")
    df = label_encode(df)

  return df

def split(x, y, sensitive_features, train_ratio, test_ratio):
  validation_ratio = 100 - train_ratio - test_ratio

  if validation_ratio < 0:
    print ("Incorrect Ratios")
    return -1

  # train is now 75% of the entire data set
  x_train, x_test, y_train, y_test, a_train, a_test = train_test_split(x, y, sensitive_features, test_size=1 - train_ratio, random_state=42)

  # test is now 10% of the initial data set
  # validation is now 15% of the initial data set
  x_val, x_test, y_val, y_test, a_val, a_test = train_test_split(x_test, y_test, a_test, test_size=test_ratio, random_state=42) 

  return  x_train, x_test, x_val, y_train, y_test, y_val, a_train, a_test, a_val

def mae(prediction, true):
  return metrics.mean_absolute_error(prediction, true)

def accuracy(prediction, true):
  true = true.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)

  return (metrics.accuracy_score(prediction, true))

def precision(prediction, true):
  true = true.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return (metrics.precision_score(prediction, true))

def recall(prediction, true):
  true = true.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return (metrics.recall_score(prediction, true))

def tpr(prediction, true):
  return np.logical_and(prediction == 1, true== 1).sum()/prediction.shape[0]

def fpr(prediction, true):
  return np.logical_and(prediction == 1, true== 0).sum()/prediction.shape[0]

def tnr(prediction, true):
  return np.logical_and(prediction == 0, true== 0).sum()/prediction.shape[0]

def fnr(prediction, true):
  return np.logical_and(prediction == 0, true== 1).sum()/prediction.shape[0]


def dpr(prediction, true, sensitive_features):
  return demographic_parity_ratio(prediction, true, sensitive_features=sensitive_features)

def eor(prediction, true, sensitive_features):
  return equalized_odds_ratio(prediction, true, sensitive_features=sensitive_features)
  

def test(model, x_test, y_test):
  x_test, y_test = torch.tensor(x_test), torch.tensor(y_test)
  outputs = model(x_test.float()) 
  loss = criterion(outputs, y_test.float())

  # log model results
  wandb.log({"test_loss": loss.item(), 
          "test_accuracy": accuracy(outputs, y_test), 
          "test_precision": precision(outputs, y_test), 
          "test_recall": recall(outputs, y_test)})
  wandb.watch(model)
  print ('Test Results, Loss: {:.4f},  Accuracy: {:.4f},  Precision: {:.4f},  Recall: {:.4f}' 
                  .format(loss.item(), 100 * accuracy(outputs, y_test),precision(outputs, y_test), recall(outputs, y_test)))



def train( model, criterion, optimizer, name,   lr,   x_train, x_val, y_train, y_val, a_train, a_val,  alpha = None, regularizers = None, num_epochs = None):
  x_train, x_val, y_train, y_val, a_train, a_val = torch.from_numpy(x_train), torch.from_numpy(x_val), torch.from_numpy(y_train), torch.from_numpy(y_val), torch.from_numpy(a_train), torch.from_numpy(a_val)

  config= {
      "learning_rate":lr,
      "epochs": num_epochs,
      "model":model.__class__.__name__,
      "criterion":criterion.__class__.__name__,
      "optimizer":optimizer.__class__.__name__,
      "train_ratio":train_ratio, 
      "test_ratio":test_ratio,
      "data":name,
    }
  
  if regularizers != None:
    for i in range(len(regularizers)):
      config['regularizer_'+str(i)] = regularizers[i]
      config['alpha_'+str(i)] = alpha[i]

  # # store the hyperparameters in weights and bias
  wandb.init(project=name, entity="mie424",config = config)

  epoch_loss_train = []
  epoch_accuracy_train = []
  epoch_precision_train = []
  epoch_recall_train = []

  epoch_loss_val = []
  epoch_accuracy_val = []
  epoch_precision_val = []
  epoch_recall_val = []

  # train loop
  for epoch in range(num_epochs):

    outputs = []
    # for i in range(0, x_train.shape[0], 10):
    optimizer.zero_grad()
  
    # x_i = x_train[i].float()

    # Forward pass
    outputs   = model(x_train.float()) 

      
        
    # outside of lop
    loss = criterion(outputs, y_train.float())
    if regularizers != None:
      # loss function
      for i in range(len(regularizers)):
        loss += regularizers[i](x_train.float(), outputs, a_train.float(), y_train.float()) #*alpha[i]
    # Backward and optimize
    
    loss.backward()
    optimizer.step()

    
    # store the epoch
    epoch_loss_train += [loss.item()]
    epoch_accuracy_train += [accuracy(outputs, y_train)]
    epoch_precision_train += [precision(outputs, y_train)]
    epoch_recall_train += [recall(outputs, y_train)]

    # log model results
    wandb.log({"train_loss": epoch_loss_train[-1], 
              "train_accuracy": epoch_accuracy_train[-1], 
              "train_precision": epoch_precision_train[-1], 
              "train_recall": epoch_recall_train[-1], })
    
    wandb.watch(model)

    # print results
    print ('Epoch [{}/{}], Loss: {:.4f},  Accuracy: {:.4f},  Precision: {:.4f},  Recall: {:.4f}' 
                  .format(epoch+1, num_epochs, epoch_loss_train[-1], 100 * epoch_accuracy_train[-1],epoch_precision_train[-1],epoch_recall_train[-1]))
    
    # Validation loop
    with torch.no_grad():
      
      # model results
      outputs_v =  model(x_val.float()) 

      loss_v = criterion(outputs_v, y_val.float())
      if regularizers != None:
        # loss function
        for i in range(len(regularizers)):
          loss_v += regularizers[i](x_val.float(), outputs_v, a_val.float(), y_val.float()) #* alpha[i]
      

    
      # store resulst for the pass through
      epoch_loss_val += [loss_v.item()]
      epoch_accuracy_val += [accuracy(outputs_v, y_val)]
      epoch_precision_val += [precision(outputs_v, y_val)]
      epoch_recall_val += [recall(outputs_v, y_val)]
      
      # log and print model results
      wandb.log({"val_loss": epoch_loss_val[-1], 
                  "val_accuracy": epoch_accuracy_val[-1], 
                  "val_precision": epoch_precision_val[-1], 
                  "val_recall": epoch_recall_val[-1], })
      wandb.watch(model)

      print('Accuracy of validation : {} % ,  Loss: {:.4f},  Precision: {:.4f},  Recall: {:.4f}'.format(100 * epoch_accuracy_val[-1], epoch_loss_val[-1],epoch_precision_val[-1], epoch_recall_val[-1]))

# %%
wandb.login()
# get df
name = "adult"

df = get_dataset(name)

# x_var, y_var, sensitive  = ['race', 'juv_fel_count', 'decile_score', 'juv_misd_count', 'juv_other_count', 'priors_count', 'v_decile_score', 'v_score_text'], ['two_year_recid'], ['race']

      #                        'sex', 'dob',
      #  'age',  'race', 'juv_fel_count', 'decile_score',
      #  'juv_misd_count', 'juv_other_count', 'priors_count',
      #  'days_b_screening_arrest',  'c_days_from_compas',
      #  'c_charge_degree', 'c_charge_desc',  'r_case_number',
      #  'r_charge_degree', 'r_days_from_arrest', 'r_offense_date',
      #  'r_charge_desc', 'r_jail_in', 'r_jail_out', 'violent_recid',
      #  'is_violent_recid', 'vr_case_number', 'vr_charge_degree',
      #  'vr_offense_date', 'vr_charge_desc', 'type_of_assessment',
      #  'v_type_of_assessment', 'v_decile_score', 'v_score_text',
      #   'in_custody', 'out_custody'],

x_var, y_var, sensitive = ['age', 'work_class', 'education', 'education_num',
       'marital-status', 'occupation', 'relationship', 'race', 'sex','capital_gain', 'capital_loss',
       
        'hours_per_week', 
       ]       , ['income'], ['race']
# 'Loan_Amount_Term','LoanAmount',


train_ratio, test_ratio = 0.7, 0.66

# select x, y, and sensitive features
x = df[x_var].values 
y = df[y_var].values
sensitive_features = df[sensitive].values


# split 
x_train, x_test, x_val, y_train, y_test, y_val, a_train, a_test, a_val = split(x, y, sensitive_features, train_ratio, test_ratio)


num_epochs = 200

alpha_dp = 1
DemographicParity = DemographicParityLoss(sensitive_classes=[0, 1], alpha=alpha_dp) # constraint 
alpha_eo = 1
EqualizedOdds = EqualiedOddsLoss(sensitive_classes=[0, 1], alpha=alpha_eo) # constraint 


alphas = [alpha_dp,alpha_eo]
regularizers = [DemographicParity,EqualizedOdds]
input_dim =  x_train.shape[1]# Two inputs x1 and x2 
output_dim = 1 # Single binary output 
lr = 0.001

model = LogisticRegression(input_dim,output_dim)
criterion = torch.nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

train( model, 
      criterion=criterion, 
      optimizer=optimizer, 
      name=name, 
      lr=lr, 
      x_train=x_train, 
      x_val=x_val, 
      y_train=y_train, 
      y_val=y_val, 
      a_train=a_train, 
      a_val=a_val,  
      alpha = alphas, 
      regularizers = regularizers, 
      num_epochs = num_epochs)

test(model, x_test, y_test)
wandb.finish()
# Out:
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/content/wandb/run-20230401_205648-xamcg7j1</code>
# Syncing run <strong><a href='https://wandb.ai/mie424/adult/runs/xamcg7j1' target="_blank">crisp-valley-24</a></strong> to <a href='https://wandb.ai/mie424/adult' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mie424/adult' target="_blank">https://wandb.ai/mie424/adult</a>
#  View run at <a href='https://wandb.ai/mie424/adult/runs/xamcg7j1' target="_blank">https://wandb.ai/mie424/adult/runs/xamcg7j1</a>
# [tensor(0.7218, grad_fn=<MeanBackward0>), tensor(0.7239, grad_fn=<MeanBackward0>)]
# Epoch [1/200], Loss: 7.1189,  Accuracy: 26.5532,  Precision: 0.9879,  Recall: 0.2467
# [tensor(0.7230), tensor(0.7195)]
# Accuracy of validation : 27.883167720566092 % ,  Loss: 5.7890,  Precision: 0.9813,  Recall: 0.2490
# [tensor(0.7143, grad_fn=<MeanBackward0>), tensor(0.7175, grad_fn=<MeanBackward0>)]
# Epoch [2/200], Loss: 5.7761,  Accuracy: 27.9616,  Precision: 0.9796,  Recall: 0.2493
# [tensor(0.7132), tensor(0.7071)]
# Accuracy of validation : 29.84040951520626 % ,  Loss: 4.7123,  Precision: 0.9515,  Recall: 0.2503
# [tensor(0.6997, grad_fn=<MeanBackward0>), tensor(0.7053, grad_fn=<MeanBackward0>)]
# Epoch [3/200], Loss: 4.6074,  Accuracy: 30.5765,  Precision: 0.9504,  Recall: 0.2525
# [tensor(0.6964), tensor(0.6854)]
# Accuracy of validation : 34.23667570009034 % ,  Loss: 3.7760,  Precision: 0.8818,  Recall: 0.2534
# [tensor(0.6777, grad_fn=<MeanBackward0>), tensor(0.6868, grad_fn=<MeanBackward0>)]
# Epoch [4/200], Loss: 3.6843,  Accuracy: 34.4375,  Precision: 0.8676,  Recall: 0.2523
# [tensor(0.6721), tensor(0.6598)]
# Accuracy of validation : 37.97049081601927 % ,  Loss: 3.0817,  Precision: 0.7326,  Recall: 0.2420
# [tensor(0.6536, grad_fn=<MeanBackward0>), tensor(0.6651, grad_fn=<MeanBackward0>)]
# Epoch [5/200], Loss: 2.9615,  Accuracy: 38.2590,  Precision: 0.7429,  Recall: 0.2450
# [tensor(0.6480), tensor(0.6374)]
# Accuracy of validation : 41.94519722975008 % ,  Loss: 2.5549,  Precision: 0.6294,  Recall: 0.2369
# [tensor(0.6314, grad_fn=<MeanBackward0>), tensor(0.6439, grad_fn=<MeanBackward0>)]
# Epoch [6/200], Loss: 2.4270,  Accuracy: 42.0279,  Precision: 0.6240,  Recall: 0.2365
# [tensor(0.6273), tensor(0.6188)]
# Accuracy of validation : 45.408009635651915 % ,  Loss: 2.2388,  Precision: 0.5386,  Recall: 0.2309
# [tensor(0.6130, grad_fn=<MeanBackward0>), tensor(0.6260, grad_fn=<MeanBackward0>)]
# Epoch [7/200], Loss: 2.0912,  Accuracy: 45.1123,  Precision: 0.5252,  Recall: 0.2270
# [tensor(0.6103), tensor(0.6035)]
# Accuracy of validation : 48.569707919301415 % ,  Loss: 1.9335,  Precision: 0.4639,  Recall: 0.2261
# [tensor(0.5986, grad_fn=<MeanBackward0>), tensor(0.6118, grad_fn=<MeanBackward0>)]
# Epoch [8/200], Loss: 1.8862,  Accuracy: 47.6966,  Precision: 0.4514,  Recall: 0.2192
# [tensor(0.5969), tensor(0.5917)]
# Accuracy of validation : 50.79795242396868 % ,  Loss: 1.7297,  Precision: 0.4216,  Recall: 0.2248
# [tensor(0.5876, grad_fn=<MeanBackward0>), tensor(0.6010, grad_fn=<MeanBackward0>)]
# Epoch [9/200], Loss: 1.7583,  Accuracy: 50.0658,  Precision: 0.3982,  Recall: 0.2146
# [tensor(0.5867), tensor(0.5829)]
# Accuracy of validation : 52.634748569707924 % ,  Loss: 1.6312,  Precision: 0.3806,  Recall: 0.2216
# [tensor(0.5794, grad_fn=<MeanBackward0>), tensor(0.5929, grad_fn=<MeanBackward0>)]
# Epoch [10/200], Loss: 1.6306,  Accuracy: 52.1718,  Precision: 0.3610,  Recall: 0.2130
# [tensor(0.5789), tensor(0.5763)]
# Accuracy of validation : 54.08009635651913 % ,  Loss: 1.5476,  Precision: 0.3495,  Recall: 0.2190
# [tensor(0.5733, grad_fn=<MeanBackward0>), tensor(0.5867, grad_fn=<MeanBackward0>)]
# Epoch [11/200], Loss: 1.5490,  Accuracy: 53.8654,  Precision: 0.3371,  Recall: 0.2138
# [tensor(0.5730), tensor(0.5714)]
# Accuracy of validation : 55.67600120445649 % ,  Loss: 1.4491,  Precision: 0.3271,  Recall: 0.2203
# [tensor(0.5686, grad_fn=<MeanBackward0>), tensor(0.5821, grad_fn=<MeanBackward0>)]
# Epoch [12/200], Loss: 1.5032,  Accuracy: 55.3791,  Precision: 0.3190,  Recall: 0.2158
# [tensor(0.5685), tensor(0.5678)]
# Accuracy of validation : 57.091237579042456 % ,  Loss: 1.3809,  Precision: 0.3134,  Recall: 0.2240
# [tensor(0.5651, grad_fn=<MeanBackward0>), tensor(0.5786, grad_fn=<MeanBackward0>)]
# Epoch [13/200], Loss: 1.4556,  Accuracy: 56.6295,  Precision: 0.3056,  Recall: 0.2183
# [tensor(0.5651), tensor(0.5650)]
# Accuracy of validation : 58.14513700692563 % ,  Loss: 1.3670,  Precision: 0.3072,  Recall: 0.2287
# [tensor(0.5624, grad_fn=<MeanBackward0>), tensor(0.5758, grad_fn=<MeanBackward0>)]
# Epoch [14/200], Loss: 1.4298,  Accuracy: 57.7703,  Precision: 0.2967,  Recall: 0.2223
# [tensor(0.5624), tensor(0.5629)]
# Accuracy of validation : 59.01836796145739 % ,  Loss: 1.3292,  Precision: 0.3022,  Recall: 0.2330
# [tensor(0.5603, grad_fn=<MeanBackward0>), tensor(0.5737, grad_fn=<MeanBackward0>)]
# Epoch [15/200], Loss: 1.4025,  Accuracy: 58.6434,  Precision: 0.2918,  Recall: 0.2264
# [tensor(0.5604), tensor(0.5612)]
# Accuracy of validation : 59.590484793736834 % ,  Loss: 1.3185,  Precision: 0.2948,  Recall: 0.2342
# [tensor(0.5587, grad_fn=<MeanBackward0>), tensor(0.5721, grad_fn=<MeanBackward0>)]
# Epoch [16/200], Loss: 1.3839,  Accuracy: 59.4068,  Precision: 0.2882,  Recall: 0.2305
# [tensor(0.5587), tensor(0.5599)]
# Accuracy of validation : 60.28304727491719 % ,  Loss: 1.3080,  Precision: 0.2935,  Recall: 0.2391
# [tensor(0.5575, grad_fn=<MeanBackward0>), tensor(0.5708, grad_fn=<MeanBackward0>)]
# Epoch [17/200], Loss: 1.3660,  Accuracy: 60.1000,  Precision: 0.2853,  Recall: 0.2346
# [tensor(0.5574), tensor(0.5590)]
# Accuracy of validation : 61.096055404998495 % ,  Loss: 1.2983,  Precision: 0.2910,  Recall: 0.2448
# [tensor(0.5565, grad_fn=<MeanBackward0>), tensor(0.5698, grad_fn=<MeanBackward0>)]
# Epoch [18/200], Loss: 1.3338,  Accuracy: 60.7231,  Precision: 0.2828,  Recall: 0.2386
# [tensor(0.5564), tensor(0.5582)]
# Accuracy of validation : 61.547726588376996 % ,  Loss: 1.2888,  Precision: 0.2898,  Recall: 0.2481
# [tensor(0.5557, grad_fn=<MeanBackward0>), tensor(0.5690, grad_fn=<MeanBackward0>)]
# Epoch [19/200], Loss: 1.3058,  Accuracy: 61.2101,  Precision: 0.2808,  Recall: 0.2418
# [tensor(0.5555), tensor(0.5575)]
# Accuracy of validation : 61.75850647395363 % ,  Loss: 1.2540,  Precision: 0.2861,  Recall: 0.2484
# [tensor(0.5550, grad_fn=<MeanBackward0>), tensor(0.5684, grad_fn=<MeanBackward0>)]
# Epoch [20/200], Loss: 1.2854,  Accuracy: 61.6444,  Precision: 0.2788,  Recall: 0.2447
# [tensor(0.5548), tensor(0.5571)]
# Accuracy of validation : 62.42095754290876 % ,  Loss: 1.2194,  Precision: 0.2848,  Recall: 0.2539
# [tensor(0.5545, grad_fn=<MeanBackward0>), tensor(0.5679, grad_fn=<MeanBackward0>)]
# Epoch [21/200], Loss: 1.2651,  Accuracy: 62.0261,  Precision: 0.2788,  Recall: 0.2481
# [tensor(0.5543), tensor(0.5567)]
# Accuracy of validation : 62.601626016260155 % ,  Loss: 1.2105,  Precision: 0.2823,  Recall: 0.2545
# [tensor(0.5541, grad_fn=<MeanBackward0>), tensor(0.5675, grad_fn=<MeanBackward0>)]
# Epoch [22/200], Loss: 1.2524,  Accuracy: 62.4473,  Precision: 0.2777,  Recall: 0.2516
# [tensor(0.5538), tensor(0.5564)]
# Accuracy of validation : 63.1737428485396 % ,  Loss: 1.2018,  Precision: 0.2836,  Recall: 0.2606
# [tensor(0.5538, grad_fn=<MeanBackward0>), tensor(0.5672, grad_fn=<MeanBackward0>)]
# Epoch [23/200], Loss: 1.2361,  Accuracy: 62.8729,  Precision: 0.2774,  Recall: 0.2555
# [tensor(0.5534), tensor(0.5561)]
# Accuracy of validation : 63.59530261969286 % ,  Loss: 1.1923,  Precision: 0.2823,  Recall: 0.2643
# [tensor(0.5535, grad_fn=<MeanBackward0>), tensor(0.5669, grad_fn=<MeanBackward0>)]
# Epoch [24/200], Loss: 1.2272,  Accuracy: 63.2152,  Precision: 0.2766,  Recall: 0.2585
# [tensor(0.5531), tensor(0.5559)]
# Accuracy of validation : 63.83619391749473 % ,  Loss: 1.1837,  Precision: 0.2823,  Recall: 0.2667
# [tensor(0.5533, grad_fn=<MeanBackward0>), tensor(0.5667, grad_fn=<MeanBackward0>)]
# Epoch [25/200], Loss: 1.2111,  Accuracy: 63.5047,  Precision: 0.2765,  Recall: 0.2613
# [tensor(0.5528), tensor(0.5558)]
# Accuracy of validation : 64.28786510087323 % ,  Loss: 1.1751,  Precision: 0.2836,  Recall: 0.2721
# [tensor(0.5531, grad_fn=<MeanBackward0>), tensor(0.5665, grad_fn=<MeanBackward0>)]
# Epoch [26/200], Loss: 1.1911,  Accuracy: 63.7768,  Precision: 0.2765,  Recall: 0.2641
# [tensor(0.5525), tensor(0.5557)]
# Accuracy of validation : 64.5287563986751 % ,  Loss: 1.1665,  Precision: 0.2836,  Recall: 0.2747
# [tensor(0.5530, grad_fn=<MeanBackward0>), tensor(0.5664, grad_fn=<MeanBackward0>)]
# Epoch [27/200], Loss: 1.1715,  Accuracy: 64.0663,  Precision: 0.2766,  Recall: 0.2673
# [tensor(0.5523), tensor(0.5556)]
# Accuracy of validation : 64.79975910870219 % ,  Loss: 1.1580,  Precision: 0.2836,  Recall: 0.2777
# [tensor(0.5529, grad_fn=<MeanBackward0>), tensor(0.5663, grad_fn=<MeanBackward0>)]
# Epoch [28/200], Loss: 1.1628,  Accuracy: 64.3208,  Precision: 0.2765,  Recall: 0.2699
# [tensor(0.5521), tensor(0.5555)]
# Accuracy of validation : 65.04065040650406 % ,  Loss: 1.1494,  Precision: 0.2848,  Recall: 0.2810
# [tensor(0.5528, grad_fn=<MeanBackward0>), tensor(0.5662, grad_fn=<MeanBackward0>)]
# Epoch [29/200], Loss: 1.1505,  Accuracy: 64.5972,  Precision: 0.2763,  Recall: 0.2729
# [tensor(0.5519), tensor(0.5555)]
# Accuracy of validation : 65.3417645287564 % ,  Loss: 1.1406,  Precision: 0.2823,  Recall: 0.2834
# [tensor(0.5527, grad_fn=<MeanBackward0>), tensor(0.5661, grad_fn=<MeanBackward0>)]
# Epoch [30/200], Loss: 1.1384,  Accuracy: 64.8956,  Precision: 0.2770,  Recall: 0.2766
# [tensor(0.5517), tensor(0.5554)]
# Accuracy of validation : 65.58265582655827 % ,  Loss: 1.1324,  Precision: 0.2823,  Recall: 0.2863
# [tensor(0.5526, grad_fn=<MeanBackward0>), tensor(0.5661, grad_fn=<MeanBackward0>)]
# Epoch [31/200], Loss: 1.1301,  Accuracy: 65.1413,  Precision: 0.2774,  Recall: 0.2795
# [tensor(0.5516), tensor(0.5554)]
# Accuracy of validation : 65.8837699488106 % ,  Loss: 1.0987,  Precision: 0.2811,  Recall: 0.2894
# [tensor(0.5525, grad_fn=<MeanBackward0>), tensor(0.5660, grad_fn=<MeanBackward0>)]
# Epoch [32/200], Loss: 1.1106,  Accuracy: 65.4265,  Precision: 0.2785,  Recall: 0.2834
# [tensor(0.5515), tensor(0.5554)]
# Accuracy of validation : 66.12466124661248 % ,  Loss: 1.0907,  Precision: 0.2823,  Recall: 0.2929
# [tensor(0.5525, grad_fn=<MeanBackward0>), tensor(0.5660, grad_fn=<MeanBackward0>)]
# Epoch [33/200], Loss: 1.1024,  Accuracy: 65.6151,  Precision: 0.2794,  Recall: 0.2860
# [tensor(0.5513), tensor(0.5553)]
# Accuracy of validation : 66.30532971996386 % ,  Loss: 1.0823,  Precision: 0.2823,  Recall: 0.2952
# [tensor(0.5525, grad_fn=<MeanBackward0>), tensor(0.5660, grad_fn=<MeanBackward0>)]
# Epoch [34/200], Loss: 1.0869,  Accuracy: 65.8126,  Precision: 0.2790,  Recall: 0.2883
# [tensor(0.5512), tensor(0.5553)]
# Accuracy of validation : 66.45588678109003 % ,  Loss: 1.0743,  Precision: 0.2823,  Recall: 0.2971
# [tensor(0.5524, grad_fn=<MeanBackward0>), tensor(0.5659, grad_fn=<MeanBackward0>)]
# Epoch [35/200], Loss: 1.0786,  Accuracy: 66.0539,  Precision: 0.2799,  Recall: 0.2917
# [tensor(0.5511), tensor(0.5553)]
# Accuracy of validation : 66.57633242999097 % ,  Loss: 1.0664,  Precision: 0.2811,  Recall: 0.2982
# [tensor(0.5524, grad_fn=<MeanBackward0>), tensor(0.5659, grad_fn=<MeanBackward0>)]
# Epoch [36/200], Loss: 1.0670,  Accuracy: 66.3084,  Precision: 0.2806,  Recall: 0.2952
# [tensor(0.5510), tensor(0.5553)]
# Accuracy of validation : 66.75700090334237 % ,  Loss: 1.0584,  Precision: 0.2823,  Recall: 0.3011
# [tensor(0.5524, grad_fn=<MeanBackward0>), tensor(0.5659, grad_fn=<MeanBackward0>)]
# Epoch [37/200], Loss: 1.0590,  Accuracy: 66.5014,  Precision: 0.2810,  Recall: 0.2979
# [tensor(0.5509), tensor(0.5553)]
# Accuracy of validation : 66.99789220114424 % ,  Loss: 1.0506,  Precision: 0.2836,  Recall: 0.3048
# [tensor(0.5524, grad_fn=<MeanBackward0>), tensor(0.5659, grad_fn=<MeanBackward0>)]
# Epoch [38/200], Loss: 1.0438,  Accuracy: 66.7032,  Precision: 0.2808,  Recall: 0.3004
# [tensor(0.5508), tensor(0.5553)]
# Accuracy of validation : 67.11833785004517 % ,  Loss: 1.0428,  Precision: 0.2836,  Recall: 0.3065
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5659, grad_fn=<MeanBackward0>)]
# Epoch [39/200], Loss: 1.0322,  Accuracy: 66.9577,  Precision: 0.2813,  Recall: 0.3041
# [tensor(0.5506), tensor(0.5553)]
# Accuracy of validation : 67.29900632339657 % ,  Loss: 1.0352,  Precision: 0.2848,  Recall: 0.3095
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [40/200], Loss: 1.0208,  Accuracy: 67.1946,  Precision: 0.2817,  Recall: 0.3075
# [tensor(0.5505), tensor(0.5553)]
# Accuracy of validation : 67.57000903342367 % ,  Loss: 1.0273,  Precision: 0.2873,  Recall: 0.3143
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [41/200], Loss: 1.0094,  Accuracy: 67.4008,  Precision: 0.2812,  Recall: 0.3101
# [tensor(0.5504), tensor(0.5553)]
# Accuracy of validation : 67.99156880457693 % ,  Loss: 1.0199,  Precision: 0.2886,  Recall: 0.3209
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [42/200], Loss: 1.0018,  Accuracy: 67.6158,  Precision: 0.2813,  Recall: 0.3133
# [tensor(0.5503), tensor(0.5553)]
# Accuracy of validation : 68.32279433905451 % ,  Loss: 1.0124,  Precision: 0.2898,  Recall: 0.3263
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [43/200], Loss: 0.9907,  Accuracy: 67.8659,  Precision: 0.2823,  Recall: 0.3173
# [tensor(0.5502), tensor(0.5554)]
# Accuracy of validation : 68.56368563685636 % ,  Loss: 1.0051,  Precision: 0.2898,  Recall: 0.3300
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [44/200], Loss: 0.9831,  Accuracy: 68.0326,  Precision: 0.2824,  Recall: 0.3198
# [tensor(0.5502), tensor(0.5554)]
# Accuracy of validation : 68.62390846130684 % ,  Loss: 0.9978,  Precision: 0.2898,  Recall: 0.3310
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [45/200], Loss: 0.9720,  Accuracy: 68.2038,  Precision: 0.2826,  Recall: 0.3225
# [tensor(0.5501), tensor(0.5554)]
# Accuracy of validation : 68.83468834688347 % ,  Loss: 0.9905,  Precision: 0.2898,  Recall: 0.3343
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [46/200], Loss: 0.9648,  Accuracy: 68.4231,  Precision: 0.2832,  Recall: 0.3260
# [tensor(0.5500), tensor(0.5554)]
# Accuracy of validation : 69.07557964468533 % ,  Loss: 0.9581,  Precision: 0.2910,  Recall: 0.3386
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [47/200], Loss: 0.9576,  Accuracy: 68.6250,  Precision: 0.2839,  Recall: 0.3295
# [tensor(0.5499), tensor(0.5554)]
# Accuracy of validation : 69.3164709424872 % ,  Loss: 0.9510,  Precision: 0.2910,  Recall: 0.3426
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [48/200], Loss: 0.9504,  Accuracy: 68.9452,  Precision: 0.2839,  Recall: 0.3346
# [tensor(0.5498), tensor(0.5554)]
# Accuracy of validation : 69.46702800361338 % ,  Loss: 0.9440,  Precision: 0.2910,  Recall: 0.3451
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [49/200], Loss: 0.9360,  Accuracy: 69.2041,  Precision: 0.2851,  Recall: 0.3394
# [tensor(0.5497), tensor(0.5554)]
# Accuracy of validation : 69.70791930141523 % ,  Loss: 0.9371,  Precision: 0.2910,  Recall: 0.3493
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [50/200], Loss: 0.9290,  Accuracy: 69.4279,  Precision: 0.2855,  Recall: 0.3433
# [tensor(0.5496), tensor(0.5554)]
# Accuracy of validation : 69.88858777476665 % ,  Loss: 0.9303,  Precision: 0.2923,  Recall: 0.3529
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [51/200], Loss: 0.9221,  Accuracy: 69.6516,  Precision: 0.2859,  Recall: 0.3473
# [tensor(0.5495), tensor(0.5554)]
# Accuracy of validation : 69.97892201144234 % ,  Loss: 0.9235,  Precision: 0.2935,  Recall: 0.3549
# [tensor(0.5523, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [52/200], Loss: 0.9152,  Accuracy: 69.9456,  Precision: 0.2864,  Recall: 0.3526
# [tensor(0.5494), tensor(0.5554)]
# Accuracy of validation : 70.24992472146944 % ,  Loss: 0.9169,  Precision: 0.2973,  Recall: 0.3610
# [tensor(0.5524, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [53/200], Loss: 0.9085,  Accuracy: 70.1957,  Precision: 0.2866,  Recall: 0.3572
# [tensor(0.5493), tensor(0.5554)]
# Accuracy of validation : 70.4908160192713 % ,  Loss: 0.9103,  Precision: 0.2985,  Recall: 0.3659
# [tensor(0.5524, grad_fn=<MeanBackward0>), tensor(0.5658, grad_fn=<MeanBackward0>)]
# Epoch [54/200], Loss: 0.9018,  Accuracy: 70.5247,  Precision: 0.2871,  Recall: 0.3636
# [tensor(0.5493), tensor(0.5555)]
# Accuracy of validation : 70.61126166817225 % ,  Loss: 0.9036,  Precision: 0.2973,  Recall: 0.3677
# [tensor(0.5524, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [55/200], Loss: 0.8953,  Accuracy: 70.7924,  Precision: 0.2875,  Recall: 0.3688
# [tensor(0.5492), tensor(0.5555)]
# Accuracy of validation : 70.88226437819934 % ,  Loss: 0.8972,  Precision: 0.2973,  Recall: 0.3729
# [tensor(0.5524, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [56/200], Loss: 0.8887,  Accuracy: 71.0161,  Precision: 0.2879,  Recall: 0.3734
# [tensor(0.5491), tensor(0.5555)]
# Accuracy of validation : 71.2134899126769 % ,  Loss: 0.8909,  Precision: 0.2985,  Recall: 0.3797
# [tensor(0.5525, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [57/200], Loss: 0.8823,  Accuracy: 71.2311,  Precision: 0.2879,  Recall: 0.3777
# [tensor(0.5490), tensor(0.5555)]
# Accuracy of validation : 71.54471544715447 % ,  Loss: 0.8845,  Precision: 0.2985,  Recall: 0.3865
# [tensor(0.5525, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [58/200], Loss: 0.8760,  Accuracy: 71.5558,  Precision: 0.2889,  Recall: 0.3848
# [tensor(0.5489), tensor(0.5555)]
# Accuracy of validation : 71.87594098163204 % ,  Loss: 0.8783,  Precision: 0.2998,  Recall: 0.3938
# [tensor(0.5525, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [59/200], Loss: 0.8697,  Accuracy: 71.8015,  Precision: 0.2891,  Recall: 0.3901
# [tensor(0.5489), tensor(0.5555)]
# Accuracy of validation : 72.14694369165913 % ,  Loss: 0.8722,  Precision: 0.3010,  Recall: 0.4000
# [tensor(0.5525, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [60/200], Loss: 0.8635,  Accuracy: 72.1218,  Precision: 0.2900,  Recall: 0.3975
# [tensor(0.5488), tensor(0.5555)]
# Accuracy of validation : 72.32761216501054 % ,  Loss: 0.8662,  Precision: 0.3022,  Recall: 0.4043
# [tensor(0.5526, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [61/200], Loss: 0.8574,  Accuracy: 72.3587,  Precision: 0.2908,  Recall: 0.4031
# [tensor(0.5487), tensor(0.5555)]
# Accuracy of validation : 72.59861487503764 % ,  Loss: 0.8602,  Precision: 0.3047,  Recall: 0.4111
# [tensor(0.5526, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [62/200], Loss: 0.8514,  Accuracy: 72.5869,  Precision: 0.2911,  Recall: 0.4085
# [tensor(0.5486), tensor(0.5555)]
# Accuracy of validation : 72.65883769948812 % ,  Loss: 0.8543,  Precision: 0.3035,  Recall: 0.4122
# [tensor(0.5526, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [63/200], Loss: 0.8455,  Accuracy: 72.8238,  Precision: 0.2918,  Recall: 0.4143
# [tensor(0.5486), tensor(0.5556)]
# Accuracy of validation : 72.92984040951521 % ,  Loss: 0.8485,  Precision: 0.3035,  Recall: 0.4185
# [tensor(0.5527, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [64/200], Loss: 0.8397,  Accuracy: 73.0651,  Precision: 0.2922,  Recall: 0.4204
# [tensor(0.5485), tensor(0.5556)]
# Accuracy of validation : 73.11050888286661 % ,  Loss: 0.8428,  Precision: 0.3035,  Recall: 0.4229
# [tensor(0.5527, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [65/200], Loss: 0.8339,  Accuracy: 73.2933,  Precision: 0.2922,  Recall: 0.4261
# [tensor(0.5484), tensor(0.5556)]
# Accuracy of validation : 73.44173441734418 % ,  Loss: 0.8371,  Precision: 0.3035,  Recall: 0.4311
# [tensor(0.5527, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [66/200], Loss: 0.8282,  Accuracy: 73.5258,  Precision: 0.2927,  Recall: 0.4323
# [tensor(0.5483), tensor(0.5556)]
# Accuracy of validation : 73.74284853959651 % ,  Loss: 0.8316,  Precision: 0.3047,  Recall: 0.4391
# [tensor(0.5528, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [67/200], Loss: 0.8226,  Accuracy: 73.7276,  Precision: 0.2935,  Recall: 0.4378
# [tensor(0.5483), tensor(0.5556)]
# Accuracy of validation : 73.86329418849743 % ,  Loss: 0.8261,  Precision: 0.3060,  Recall: 0.4424
# [tensor(0.5528, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [68/200], Loss: 0.8171,  Accuracy: 73.9821,  Precision: 0.2938,  Recall: 0.4448
# [tensor(0.5482), tensor(0.5556)]
# Accuracy of validation : 74.01385124962361 % ,  Loss: 0.8206,  Precision: 0.3060,  Recall: 0.4465
# [tensor(0.5528, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [69/200], Loss: 0.8116,  Accuracy: 74.1576,  Precision: 0.2944,  Recall: 0.4498
# [tensor(0.5481), tensor(0.5556)]
# Accuracy of validation : 74.13429689852454 % ,  Loss: 0.8153,  Precision: 0.3060,  Recall: 0.4497
# [tensor(0.5529, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [70/200], Loss: 0.8062,  Accuracy: 74.3243,  Precision: 0.2946,  Recall: 0.4546
# [tensor(0.5480), tensor(0.5556)]
# Accuracy of validation : 74.25474254742548 % ,  Loss: 0.8101,  Precision: 0.3060,  Recall: 0.4530
# [tensor(0.5529, grad_fn=<MeanBackward0>), tensor(0.5657, grad_fn=<MeanBackward0>)]
# Epoch [71/200], Loss: 0.8009,  Accuracy: 74.5612,  Precision: 0.2955,  Recall: 0.4617
# [tensor(0.5480), tensor(0.5556)]
# Accuracy of validation : 74.43541102077688 % ,  Loss: 0.8049,  Precision: 0.3060,  Recall: 0.4581
# [tensor(0.5530, grad_fn=<MeanBackward0>), tensor(0.5656, grad_fn=<MeanBackward0>)]
# Epoch [72/200], Loss: 0.7957,  Accuracy: 74.7367,  Precision: 0.2962,  Recall: 0.4670
# [tensor(0.5479), tensor(0.5556)]
# Accuracy of validation : 74.64619090635351 % ,  Loss: 0.7998,  Precision: 0.3060,  Recall: 0.4642
# [tensor(0.5530, grad_fn=<MeanBackward0>), tensor(0.5656, grad_fn=<MeanBackward0>)]
# Epoch [73/200], Loss: 0.7906,  Accuracy: 74.9605,  Precision: 0.2965,  Recall: 0.4740
# [tensor(0.5478), tensor(0.5556)]
# Accuracy of validation : 74.82685937970491 % ,  Loss: 0.7948,  Precision: 0.3060,  Recall: 0.4695
# [tensor(0.5530, grad_fn=<MeanBackward0>), tensor(0.5656, grad_fn=<MeanBackward0>)]
# Epoch [74/200], Loss: 0.7855,  Accuracy: 75.1053,  Precision: 0.2964,  Recall: 0.4785
# [tensor(0.5477), tensor(0.5556)]
# Accuracy of validation : 74.94730502860584 % ,  Loss: 0.7898,  Precision: 0.3060,  Recall: 0.4731
# [tensor(0.5531, grad_fn=<MeanBackward0>), tensor(0.5656, grad_fn=<MeanBackward0>)]
# Epoch [75/200], Loss: 0.7805,  Accuracy: 75.2589,  Precision: 0.2960,  Recall: 0.4835
# [tensor(0.5477), tensor(0.5556)]
# Accuracy of validation : 75.097862089732 % ,  Loss: 0.7849,  Precision: 0.3060,  Recall: 0.4777
# [tensor(0.5531, grad_fn=<MeanBackward0>), tensor(0.5656, grad_fn=<MeanBackward0>)]
# Epoch [76/200], Loss: 0.7682,  Accuracy: 75.3554,  Precision: 0.2960,  Recall: 0.4866
# [tensor(0.5476), tensor(0.5556)]
# Accuracy of validation : 75.27853056308341 % ,  Loss: 0.7801,  Precision: 0.3060,  Recall: 0.4833
# [tensor(0.5532, grad_fn=<MeanBackward0>), tensor(0.5656, grad_fn=<MeanBackward0>)]
# Epoch [77/200], Loss: 0.7634,  Accuracy: 75.5090,  Precision: 0.2960,  Recall: 0.4917
# [tensor(0.5475), tensor(0.5556)]
# Accuracy of validation : 75.39897621198433 % ,  Loss: 0.7753,  Precision: 0.3060,  Recall: 0.4871
# [tensor(0.5532, grad_fn=<MeanBackward0>), tensor(0.5656, grad_fn=<MeanBackward0>)]
# Epoch [78/200], Loss: 0.7586,  Accuracy: 75.6669,  Precision: 0.2960,  Recall: 0.4971
# [tensor(0.5474), tensor(0.5556)]
# Accuracy of validation : 75.54953327311051 % ,  Loss: 0.7706,  Precision: 0.3060,  Recall: 0.4920
# [tensor(0.5532, grad_fn=<MeanBackward0>), tensor(0.5656, grad_fn=<MeanBackward0>)]
# Epoch [79/200], Loss: 0.7539,  Accuracy: 75.7634,  Precision: 0.2958,  Recall: 0.5005
# [tensor(0.5474), tensor(0.5556)]
# Accuracy of validation : 75.60975609756098 % ,  Loss: 0.7660,  Precision: 0.3060,  Recall: 0.4940
# [tensor(0.5533, grad_fn=<MeanBackward0>), tensor(0.5655, grad_fn=<MeanBackward0>)]
# Epoch [80/200], Loss: 0.7492,  Accuracy: 75.8556,  Precision: 0.2955,  Recall: 0.5037
# [tensor(0.5473), tensor(0.5556)]
# Accuracy of validation : 75.8205359831376 % ,  Loss: 0.7615,  Precision: 0.3060,  Recall: 0.5010
# [tensor(0.5533, grad_fn=<MeanBackward0>), tensor(0.5655, grad_fn=<MeanBackward0>)]
# Epoch [81/200], Loss: 0.7446,  Accuracy: 76.0355,  Precision: 0.2958,  Recall: 0.5101
# [tensor(0.5472), tensor(0.5556)]
# Accuracy of validation : 76.03131586871424 % ,  Loss: 0.7570,  Precision: 0.3060,  Recall: 0.5083
# [tensor(0.5534, grad_fn=<MeanBackward0>), tensor(0.5655, grad_fn=<MeanBackward0>)]
# Epoch [82/200], Loss: 0.7401,  Accuracy: 76.1408,  Precision: 0.2960,  Recall: 0.5140
# [tensor(0.5471), tensor(0.5556)]
# Accuracy of validation : 76.15176151761518 % ,  Loss: 0.7526,  Precision: 0.3060,  Recall: 0.5125
# [tensor(0.5534, grad_fn=<MeanBackward0>), tensor(0.5655, grad_fn=<MeanBackward0>)]
# Epoch [83/200], Loss: 0.7356,  Accuracy: 76.2548,  Precision: 0.2960,  Recall: 0.5182
# [tensor(0.5471), tensor(0.5556)]
# Accuracy of validation : 76.30231857874135 % ,  Loss: 0.7483,  Precision: 0.3060,  Recall: 0.5179
# [tensor(0.5534, grad_fn=<MeanBackward0>), tensor(0.5655, grad_fn=<MeanBackward0>)]
# Epoch [84/200], Loss: 0.7312,  Accuracy: 76.3163,  Precision: 0.2962,  Recall: 0.5205
# [tensor(0.5470), tensor(0.5555)]
# Accuracy of validation : 76.39265281541704 % ,  Loss: 0.7440,  Precision: 0.3072,  Recall: 0.5211
# [tensor(0.5535, grad_fn=<MeanBackward0>), tensor(0.5655, grad_fn=<MeanBackward0>)]
# Epoch [85/200], Loss: 0.7269,  Accuracy: 76.4084,  Precision: 0.2964,  Recall: 0.5240
# [tensor(0.5469), tensor(0.5555)]
# Accuracy of validation : 76.48298705209274 % ,  Loss: 0.7398,  Precision: 0.3072,  Recall: 0.5244
# [tensor(0.5535, grad_fn=<MeanBackward0>), tensor(0.5654, grad_fn=<MeanBackward0>)]
# Epoch [86/200], Loss: 0.7227,  Accuracy: 76.5269,  Precision: 0.2965,  Recall: 0.5285
# [tensor(0.5468), tensor(0.5555)]
# Accuracy of validation : 76.51309846431798 % ,  Loss: 0.7356,  Precision: 0.3085,  Recall: 0.5254
# [tensor(0.5536, grad_fn=<MeanBackward0>), tensor(0.5654, grad_fn=<MeanBackward0>)]
# Epoch [87/200], Loss: 0.7185,  Accuracy: 76.5883,  Precision: 0.2965,  Recall: 0.5309
# [tensor(0.5468), tensor(0.5555)]
# Accuracy of validation : 76.69376693766937 % ,  Loss: 0.7315,  Precision: 0.3072,  Recall: 0.5323
# [tensor(0.5536, grad_fn=<MeanBackward0>), tensor(0.5654, grad_fn=<MeanBackward0>)]
# Epoch [88/200], Loss: 0.7144,  Accuracy: 76.7199,  Precision: 0.2969,  Recall: 0.5361
# [tensor(0.5467), tensor(0.5555)]
# Accuracy of validation : 76.8142125865703 % ,  Loss: 0.7275,  Precision: 0.3072,  Recall: 0.5370
# [tensor(0.5536, grad_fn=<MeanBackward0>), tensor(0.5654, grad_fn=<MeanBackward0>)]
# Epoch [89/200], Loss: 0.7103,  Accuracy: 76.8120,  Precision: 0.2969,  Recall: 0.5398
# [tensor(0.5466), tensor(0.5555)]
# Accuracy of validation : 76.84432399879555 % ,  Loss: 0.7235,  Precision: 0.3072,  Recall: 0.5381
# [tensor(0.5537, grad_fn=<MeanBackward0>), tensor(0.5654, grad_fn=<MeanBackward0>)]
# Epoch [90/200], Loss: 0.7063,  Accuracy: 76.8779,  Precision: 0.2971,  Recall: 0.5425
# [tensor(0.5466), tensor(0.5555)]
# Accuracy of validation : 76.87443541102078 % ,  Loss: 0.7196,  Precision: 0.3060,  Recall: 0.5395
# [tensor(0.5537, grad_fn=<MeanBackward0>), tensor(0.5653, grad_fn=<MeanBackward0>)]
# Epoch [91/200], Loss: 0.7024,  Accuracy: 76.9612,  Precision: 0.2971,  Recall: 0.5459
# [tensor(0.5465), tensor(0.5554)]
# Accuracy of validation : 76.90454682324601 % ,  Loss: 0.7158,  Precision: 0.3060,  Recall: 0.5407
# [tensor(0.5538, grad_fn=<MeanBackward0>), tensor(0.5653, grad_fn=<MeanBackward0>)]
# Epoch [92/200], Loss: 0.6985,  Accuracy: 77.0007,  Precision: 0.2971,  Recall: 0.5475
# [tensor(0.5464), tensor(0.5554)]
# Accuracy of validation : 76.96476964769647 % ,  Loss: 0.7120,  Precision: 0.3072,  Recall: 0.5429
# [tensor(0.5538, grad_fn=<MeanBackward0>), tensor(0.5653, grad_fn=<MeanBackward0>)]
# Epoch [93/200], Loss: 0.6947,  Accuracy: 77.0797,  Precision: 0.2971,  Recall: 0.5508
# [tensor(0.5463), tensor(0.5554)]
# Accuracy of validation : 77.02499247214695 % ,  Loss: 0.7082,  Precision: 0.3072,  Recall: 0.5453
# [tensor(0.5539, grad_fn=<MeanBackward0>), tensor(0.5653, grad_fn=<MeanBackward0>)]
# Epoch [94/200], Loss: 0.6909,  Accuracy: 77.1455,  Precision: 0.2969,  Recall: 0.5536
# [tensor(0.5463), tensor(0.5554)]
# Accuracy of validation : 77.20566094549835 % ,  Loss: 0.7046,  Precision: 0.3072,  Recall: 0.5526
# [tensor(0.5539, grad_fn=<MeanBackward0>), tensor(0.5653, grad_fn=<MeanBackward0>)]
# Epoch [95/200], Loss: 0.6872,  Accuracy: 77.2508,  Precision: 0.2971,  Recall: 0.5581
# [tensor(0.5462), tensor(0.5554)]
# Accuracy of validation : 77.23577235772358 % ,  Loss: 0.7009,  Precision: 0.3072,  Recall: 0.5538
# [tensor(0.5539, grad_fn=<MeanBackward0>), tensor(0.5652, grad_fn=<MeanBackward0>)]
# Epoch [96/200], Loss: 0.6835,  Accuracy: 77.2947,  Precision: 0.2971,  Recall: 0.5600
# [tensor(0.5461), tensor(0.5554)]
# Accuracy of validation : 77.32610659439928 % ,  Loss: 0.6973,  Precision: 0.3085,  Recall: 0.5573
# [tensor(0.5540, grad_fn=<MeanBackward0>), tensor(0.5652, grad_fn=<MeanBackward0>)]
# Epoch [97/200], Loss: 0.6799,  Accuracy: 77.3649,  Precision: 0.2969,  Recall: 0.5631
# [tensor(0.5461), tensor(0.5553)]
# Accuracy of validation : 77.35621800662452 % ,  Loss: 0.6938,  Precision: 0.3085,  Recall: 0.5586
# [tensor(0.5540, grad_fn=<MeanBackward0>), tensor(0.5652, grad_fn=<MeanBackward0>)]
# Epoch [98/200], Loss: 0.6764,  Accuracy: 77.4087,  Precision: 0.2969,  Recall: 0.5651
# [tensor(0.5460), tensor(0.5553)]
# Accuracy of validation : 77.44655224330022 % ,  Loss: 0.6903,  Precision: 0.3085,  Recall: 0.5624
# [tensor(0.5541, grad_fn=<MeanBackward0>), tensor(0.5652, grad_fn=<MeanBackward0>)]
# Epoch [99/200], Loss: 0.6729,  Accuracy: 77.4482,  Precision: 0.2969,  Recall: 0.5668
# [tensor(0.5459), tensor(0.5553)]
# Accuracy of validation : 77.47666365552544 % ,  Loss: 0.6869,  Precision: 0.3085,  Recall: 0.5636
# [tensor(0.5541, grad_fn=<MeanBackward0>), tensor(0.5651, grad_fn=<MeanBackward0>)]
# Epoch [100/200], Loss: 0.6694,  Accuracy: 77.5097,  Precision: 0.2969,  Recall: 0.5696
# [tensor(0.5458), tensor(0.5553)]
# Accuracy of validation : 77.47666365552544 % ,  Loss: 0.6835,  Precision: 0.3085,  Recall: 0.5636
# [tensor(0.5541, grad_fn=<MeanBackward0>), tensor(0.5651, grad_fn=<MeanBackward0>)]
# Epoch [101/200], Loss: 0.6660,  Accuracy: 77.5316,  Precision: 0.2965,  Recall: 0.5707
# [tensor(0.5458), tensor(0.5553)]
# Accuracy of validation : 77.50677506775068 % ,  Loss: 0.6802,  Precision: 0.3072,  Recall: 0.5652
# [tensor(0.5542, grad_fn=<MeanBackward0>), tensor(0.5651, grad_fn=<MeanBackward0>)]
# Epoch [102/200], Loss: 0.6627,  Accuracy: 77.5579,  Precision: 0.2965,  Recall: 0.5719
# [tensor(0.5457), tensor(0.5552)]
# Accuracy of validation : 77.59710930442638 % ,  Loss: 0.6769,  Precision: 0.3085,  Recall: 0.5688
# [tensor(0.5542, grad_fn=<MeanBackward0>), tensor(0.5651, grad_fn=<MeanBackward0>)]
# Epoch [103/200], Loss: 0.6594,  Accuracy: 77.5799,  Precision: 0.2962,  Recall: 0.5730
# [tensor(0.5456), tensor(0.5552)]
# Accuracy of validation : 77.65733212887685 % ,  Loss: 0.6737,  Precision: 0.3085,  Recall: 0.5714
# [tensor(0.5542, grad_fn=<MeanBackward0>), tensor(0.5650, grad_fn=<MeanBackward0>)]
# Epoch [104/200], Loss: 0.6561,  Accuracy: 77.6369,  Precision: 0.2962,  Recall: 0.5756
# [tensor(0.5455), tensor(0.5552)]
# Accuracy of validation : 77.68744354110207 % ,  Loss: 0.6705,  Precision: 0.3085,  Recall: 0.5727
# [tensor(0.5543, grad_fn=<MeanBackward0>), tensor(0.5650, grad_fn=<MeanBackward0>)]
# Epoch [105/200], Loss: 0.6529,  Accuracy: 77.6676,  Precision: 0.2962,  Recall: 0.5770
# [tensor(0.5455), tensor(0.5552)]
# Accuracy of validation : 77.65733212887685 % ,  Loss: 0.6673,  Precision: 0.3085,  Recall: 0.5714
# [tensor(0.5543, grad_fn=<MeanBackward0>), tensor(0.5650, grad_fn=<MeanBackward0>)]
# Epoch [106/200], Loss: 0.6498,  Accuracy: 77.6895,  Precision: 0.2965,  Recall: 0.5779
# [tensor(0.5454), tensor(0.5551)]
# Accuracy of validation : 77.65733212887685 % ,  Loss: 0.6642,  Precision: 0.3085,  Recall: 0.5714
# [tensor(0.5544, grad_fn=<MeanBackward0>), tensor(0.5649, grad_fn=<MeanBackward0>)]
# Epoch [107/200], Loss: 0.6466,  Accuracy: 77.7115,  Precision: 0.2964,  Recall: 0.5790
# [tensor(0.5453), tensor(0.5551)]
# Accuracy of validation : 77.71755495332731 % ,  Loss: 0.6611,  Precision: 0.3072,  Recall: 0.5744
# [tensor(0.5544, grad_fn=<MeanBackward0>), tensor(0.5649, grad_fn=<MeanBackward0>)]
# Epoch [108/200], Loss: 0.6436,  Accuracy: 77.7334,  Precision: 0.2964,  Recall: 0.5800
# [tensor(0.5453), tensor(0.5551)]
# Accuracy of validation : 77.68744354110207 % ,  Loss: 0.6581,  Precision: 0.3072,  Recall: 0.5731
# [tensor(0.5544, grad_fn=<MeanBackward0>), tensor(0.5649, grad_fn=<MeanBackward0>)]
# Epoch [109/200], Loss: 0.6405,  Accuracy: 77.7554,  Precision: 0.2962,  Recall: 0.5811
# [tensor(0.5452), tensor(0.5551)]
# Accuracy of validation : 77.71755495332731 % ,  Loss: 0.6551,  Precision: 0.3072,  Recall: 0.5744
# [tensor(0.5545, grad_fn=<MeanBackward0>), tensor(0.5649, grad_fn=<MeanBackward0>)]
# Epoch [110/200], Loss: 0.6376,  Accuracy: 77.7861,  Precision: 0.2960,  Recall: 0.5826
# [tensor(0.5451), tensor(0.5550)]
# Accuracy of validation : 77.71755495332731 % ,  Loss: 0.6522,  Precision: 0.3072,  Recall: 0.5744
# [tensor(0.5545, grad_fn=<MeanBackward0>), tensor(0.5648, grad_fn=<MeanBackward0>)]
# Epoch [111/200], Loss: 0.6346,  Accuracy: 77.7992,  Precision: 0.2958,  Recall: 0.5833
# [tensor(0.5450), tensor(0.5550)]
# Accuracy of validation : 77.74766636555255 % ,  Loss: 0.6493,  Precision: 0.3072,  Recall: 0.5758
# [tensor(0.5545, grad_fn=<MeanBackward0>), tensor(0.5648, grad_fn=<MeanBackward0>)]
# Epoch [112/200], Loss: 0.6317,  Accuracy: 77.7992,  Precision: 0.2955,  Recall: 0.5834
# [tensor(0.5450), tensor(0.5550)]
# Accuracy of validation : 77.74766636555255 % ,  Loss: 0.6464,  Precision: 0.3072,  Recall: 0.5758
# [tensor(0.5546, grad_fn=<MeanBackward0>), tensor(0.5648, grad_fn=<MeanBackward0>)]
# Epoch [113/200], Loss: 0.6288,  Accuracy: 77.8212,  Precision: 0.2955,  Recall: 0.5845
# [tensor(0.5449), tensor(0.5549)]
# Accuracy of validation : 77.71755495332731 % ,  Loss: 0.6436,  Precision: 0.3072,  Recall: 0.5744
# [tensor(0.5546, grad_fn=<MeanBackward0>), tensor(0.5647, grad_fn=<MeanBackward0>)]
# Epoch [114/200], Loss: 0.6260,  Accuracy: 77.8387,  Precision: 0.2953,  Recall: 0.5854
# [tensor(0.5448), tensor(0.5549)]
# Accuracy of validation : 77.77777777777779 % ,  Loss: 0.6408,  Precision: 0.3072,  Recall: 0.5771
# [tensor(0.5546, grad_fn=<MeanBackward0>), tensor(0.5647, grad_fn=<MeanBackward0>)]
# Epoch [115/200], Loss: 0.6233,  Accuracy: 77.8431,  Precision: 0.2951,  Recall: 0.5856
# [tensor(0.5447), tensor(0.5549)]
# Accuracy of validation : 77.77777777777779 % ,  Loss: 0.6381,  Precision: 0.3072,  Recall: 0.5771
# [tensor(0.5547, grad_fn=<MeanBackward0>), tensor(0.5647, grad_fn=<MeanBackward0>)]
# Epoch [116/200], Loss: 0.6205,  Accuracy: 77.8650,  Precision: 0.2949,  Recall: 0.5868
# [tensor(0.5447), tensor(0.5549)]
# Accuracy of validation : 77.83800060222823 % ,  Loss: 0.6354,  Precision: 0.3072,  Recall: 0.5798
# [tensor(0.5547, grad_fn=<MeanBackward0>), tensor(0.5646, grad_fn=<MeanBackward0>)]
# Epoch [117/200], Loss: 0.6178,  Accuracy: 77.8870,  Precision: 0.2949,  Recall: 0.5878
# [tensor(0.5446), tensor(0.5548)]
# Accuracy of validation : 77.77777777777779 % ,  Loss: 0.6327,  Precision: 0.3072,  Recall: 0.5771
# [tensor(0.5548, grad_fn=<MeanBackward0>), tensor(0.5646, grad_fn=<MeanBackward0>)]
# Epoch [118/200], Loss: 0.6152,  Accuracy: 77.8958,  Precision: 0.2942,  Recall: 0.5885
# [tensor(0.5445), tensor(0.5548)]
# Accuracy of validation : 77.83800060222823 % ,  Loss: 0.6301,  Precision: 0.3060,  Recall: 0.5802
# [tensor(0.5548, grad_fn=<MeanBackward0>), tensor(0.5646, grad_fn=<MeanBackward0>)]
# Epoch [119/200], Loss: 0.6125,  Accuracy: 77.9309,  Precision: 0.2942,  Recall: 0.5902
# [tensor(0.5444), tensor(0.5548)]
# Accuracy of validation : 77.86811201445349 % ,  Loss: 0.6275,  Precision: 0.3060,  Recall: 0.5816
# [tensor(0.5548, grad_fn=<MeanBackward0>), tensor(0.5645, grad_fn=<MeanBackward0>)]
# Epoch [120/200], Loss: 0.6100,  Accuracy: 77.9352,  Precision: 0.2944,  Recall: 0.5903
# [tensor(0.5444), tensor(0.5547)]
# Accuracy of validation : 77.92833483890395 % ,  Loss: 0.6249,  Precision: 0.3060,  Recall: 0.5843
# [tensor(0.5549, grad_fn=<MeanBackward0>), tensor(0.5645, grad_fn=<MeanBackward0>)]
# Epoch [121/200], Loss: 0.6074,  Accuracy: 77.9484,  Precision: 0.2942,  Recall: 0.5911
# [tensor(0.5443), tensor(0.5547)]
# Accuracy of validation : 77.98855766335441 % ,  Loss: 0.6224,  Precision: 0.3060,  Recall: 0.5871
# [tensor(0.5549, grad_fn=<MeanBackward0>), tensor(0.5645, grad_fn=<MeanBackward0>)]
# Epoch [122/200], Loss: 0.6049,  Accuracy: 77.9660,  Precision: 0.2942,  Recall: 0.5919
# [tensor(0.5442), tensor(0.5547)]
# Accuracy of validation : 77.98855766335441 % ,  Loss: 0.6199,  Precision: 0.3060,  Recall: 0.5871
# [tensor(0.5549, grad_fn=<MeanBackward0>), tensor(0.5644, grad_fn=<MeanBackward0>)]
# Epoch [123/200], Loss: 0.6025,  Accuracy: 77.9616,  Precision: 0.2940,  Recall: 0.5918
# [tensor(0.5441), tensor(0.5546)]
# Accuracy of validation : 78.01866907557965 % ,  Loss: 0.6175,  Precision: 0.3060,  Recall: 0.5885
# [tensor(0.5549, grad_fn=<MeanBackward0>), tensor(0.5644, grad_fn=<MeanBackward0>)]
# Epoch [124/200], Loss: 0.6001,  Accuracy: 77.9835,  Precision: 0.2940,  Recall: 0.5928
# [tensor(0.5441), tensor(0.5546)]
# Accuracy of validation : 77.98855766335441 % ,  Loss: 0.6151,  Precision: 0.3060,  Recall: 0.5871
# [tensor(0.5550, grad_fn=<MeanBackward0>), tensor(0.5644, grad_fn=<MeanBackward0>)]
# Epoch [125/200], Loss: 0.5977,  Accuracy: 78.0098,  Precision: 0.2942,  Recall: 0.5941
# [tensor(0.5440), tensor(0.5545)]
# Accuracy of validation : 78.07889190003011 % ,  Loss: 0.6128,  Precision: 0.3060,  Recall: 0.5913
# [tensor(0.5550, grad_fn=<MeanBackward0>), tensor(0.5643, grad_fn=<MeanBackward0>)]
# Epoch [126/200], Loss: 0.5954,  Accuracy: 78.0537,  Precision: 0.2944,  Recall: 0.5962
# [tensor(0.5439), tensor(0.5545)]
# Accuracy of validation : 78.07889190003011 % ,  Loss: 0.6104,  Precision: 0.3060,  Recall: 0.5913
# [tensor(0.5550, grad_fn=<MeanBackward0>), tensor(0.5643, grad_fn=<MeanBackward0>)]
# Epoch [127/200], Loss: 0.5931,  Accuracy: 78.0800,  Precision: 0.2944,  Recall: 0.5975
# [tensor(0.5439), tensor(0.5545)]
# Accuracy of validation : 78.10900331225534 % ,  Loss: 0.6082,  Precision: 0.3060,  Recall: 0.5928
# [tensor(0.5551, grad_fn=<MeanBackward0>), tensor(0.5643, grad_fn=<MeanBackward0>)]
# Epoch [128/200], Loss: 0.5909,  Accuracy: 78.0756,  Precision: 0.2942,  Recall: 0.5974
# [tensor(0.5438), tensor(0.5544)]
# Accuracy of validation : 78.19933754893104 % ,  Loss: 0.6059,  Precision: 0.3060,  Recall: 0.5971
# [tensor(0.5551, grad_fn=<MeanBackward0>), tensor(0.5642, grad_fn=<MeanBackward0>)]
# Epoch [129/200], Loss: 0.5887,  Accuracy: 78.1195,  Precision: 0.2944,  Recall: 0.5995
# [tensor(0.5437), tensor(0.5544)]
# Accuracy of validation : 78.19933754893104 % ,  Loss: 0.6038,  Precision: 0.3047,  Recall: 0.5976
# [tensor(0.5551, grad_fn=<MeanBackward0>), tensor(0.5642, grad_fn=<MeanBackward0>)]
# Epoch [130/200], Loss: 0.5865,  Accuracy: 78.1239,  Precision: 0.2944,  Recall: 0.5997
# [tensor(0.5437), tensor(0.5544)]
# Accuracy of validation : 78.22944896115628 % ,  Loss: 0.6016,  Precision: 0.3047,  Recall: 0.5990
# [tensor(0.5552, grad_fn=<MeanBackward0>), tensor(0.5642, grad_fn=<MeanBackward0>)]
# Epoch [131/200], Loss: 0.5844,  Accuracy: 78.1020,  Precision: 0.2944,  Recall: 0.5986
# [tensor(0.5436), tensor(0.5543)]
# Accuracy of validation : 78.28967178560674 % ,  Loss: 0.5995,  Precision: 0.3047,  Recall: 0.6020
# [tensor(0.5552, grad_fn=<MeanBackward0>), tensor(0.5642, grad_fn=<MeanBackward0>)]
# Epoch [132/200], Loss: 0.5824,  Accuracy: 78.0932,  Precision: 0.2942,  Recall: 0.5982
# [tensor(0.5435), tensor(0.5543)]
# Accuracy of validation : 78.28967178560674 % ,  Loss: 0.5975,  Precision: 0.3047,  Recall: 0.6020
# [tensor(0.5552, grad_fn=<MeanBackward0>), tensor(0.5641, grad_fn=<MeanBackward0>)]
# Epoch [133/200], Loss: 0.5804,  Accuracy: 78.1107,  Precision: 0.2944,  Recall: 0.5990
# [tensor(0.5435), tensor(0.5543)]
# Accuracy of validation : 78.31978319783198 % ,  Loss: 0.5955,  Precision: 0.3047,  Recall: 0.6034
# [tensor(0.5553, grad_fn=<MeanBackward0>), tensor(0.5641, grad_fn=<MeanBackward0>)]
# Epoch [134/200], Loss: 0.5784,  Accuracy: 78.1151,  Precision: 0.2946,  Recall: 0.5992
# [tensor(0.5434), tensor(0.5542)]
# Accuracy of validation : 78.34989461005722 % ,  Loss: 0.5935,  Precision: 0.3047,  Recall: 0.6049
# [tensor(0.5553, grad_fn=<MeanBackward0>), tensor(0.5641, grad_fn=<MeanBackward0>)]
# Epoch [135/200], Loss: 0.5765,  Accuracy: 78.0976,  Precision: 0.2947,  Recall: 0.5982
# [tensor(0.5433), tensor(0.5542)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5916,  Precision: 0.3060,  Recall: 0.6089
# [tensor(0.5553, grad_fn=<MeanBackward0>), tensor(0.5640, grad_fn=<MeanBackward0>)]
# Epoch [136/200], Loss: 0.5747,  Accuracy: 78.1064,  Precision: 0.2946,  Recall: 0.5987
# [tensor(0.5433), tensor(0.5542)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5898,  Precision: 0.3060,  Recall: 0.6074
# [tensor(0.5554, grad_fn=<MeanBackward0>), tensor(0.5640, grad_fn=<MeanBackward0>)]
# Epoch [137/200], Loss: 0.5729,  Accuracy: 78.1239,  Precision: 0.2940,  Recall: 0.5999
# [tensor(0.5432), tensor(0.5542)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5880,  Precision: 0.3060,  Recall: 0.6089
# [tensor(0.5554, grad_fn=<MeanBackward0>), tensor(0.5640, grad_fn=<MeanBackward0>)]
# Epoch [138/200], Loss: 0.5711,  Accuracy: 78.1151,  Precision: 0.2935,  Recall: 0.5996
# [tensor(0.5432), tensor(0.5541)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5862,  Precision: 0.3060,  Recall: 0.6074
# [tensor(0.5554, grad_fn=<MeanBackward0>), tensor(0.5639, grad_fn=<MeanBackward0>)]
# Epoch [139/200], Loss: 0.5694,  Accuracy: 78.1371,  Precision: 0.2931,  Recall: 0.6009
# [tensor(0.5431), tensor(0.5541)]
# Accuracy of validation : 78.38000602228244 % ,  Loss: 0.5845,  Precision: 0.3060,  Recall: 0.6059
# [tensor(0.5555, grad_fn=<MeanBackward0>), tensor(0.5639, grad_fn=<MeanBackward0>)]
# Epoch [140/200], Loss: 0.5678,  Accuracy: 78.1415,  Precision: 0.2931,  Recall: 0.6011
# [tensor(0.5431), tensor(0.5541)]
# Accuracy of validation : 78.34989461005722 % ,  Loss: 0.5829,  Precision: 0.3060,  Recall: 0.6044
# [tensor(0.5555, grad_fn=<MeanBackward0>), tensor(0.5639, grad_fn=<MeanBackward0>)]
# Epoch [141/200], Loss: 0.5662,  Accuracy: 78.1546,  Precision: 0.2931,  Recall: 0.6018
# [tensor(0.5431), tensor(0.5541)]
# Accuracy of validation : 78.38000602228244 % ,  Loss: 0.5813,  Precision: 0.3072,  Recall: 0.6054
# [tensor(0.5555, grad_fn=<MeanBackward0>), tensor(0.5639, grad_fn=<MeanBackward0>)]
# Epoch [142/200], Loss: 0.5647,  Accuracy: 78.1458,  Precision: 0.2931,  Recall: 0.6013
# [tensor(0.5430), tensor(0.5541)]
# Accuracy of validation : 78.38000602228244 % ,  Loss: 0.5797,  Precision: 0.3072,  Recall: 0.6054
# [tensor(0.5556, grad_fn=<MeanBackward0>), tensor(0.5638, grad_fn=<MeanBackward0>)]
# Epoch [143/200], Loss: 0.5633,  Accuracy: 78.1546,  Precision: 0.2931,  Recall: 0.6018
# [tensor(0.5430), tensor(0.5541)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5783,  Precision: 0.3072,  Recall: 0.6084
# [tensor(0.5556, grad_fn=<MeanBackward0>), tensor(0.5638, grad_fn=<MeanBackward0>)]
# Epoch [144/200], Loss: 0.5619,  Accuracy: 78.1327,  Precision: 0.2929,  Recall: 0.6007
# [tensor(0.5430), tensor(0.5540)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5768,  Precision: 0.3072,  Recall: 0.6084
# [tensor(0.5556, grad_fn=<MeanBackward0>), tensor(0.5638, grad_fn=<MeanBackward0>)]
# Epoch [145/200], Loss: 0.5605,  Accuracy: 78.1283,  Precision: 0.2929,  Recall: 0.6005
# [tensor(0.5429), tensor(0.5540)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5755,  Precision: 0.3085,  Recall: 0.6078
# [tensor(0.5557, grad_fn=<MeanBackward0>), tensor(0.5638, grad_fn=<MeanBackward0>)]
# Epoch [146/200], Loss: 0.5593,  Accuracy: 78.1064,  Precision: 0.2927,  Recall: 0.5995
# [tensor(0.5429), tensor(0.5540)]
# Accuracy of validation : 78.38000602228244 % ,  Loss: 0.5742,  Precision: 0.3085,  Recall: 0.6049
# [tensor(0.5557, grad_fn=<MeanBackward0>), tensor(0.5638, grad_fn=<MeanBackward0>)]
# Epoch [147/200], Loss: 0.5580,  Accuracy: 78.1239,  Precision: 0.2929,  Recall: 0.6003
# [tensor(0.5429), tensor(0.5540)]
# Accuracy of validation : 78.31978319783198 % ,  Loss: 0.5729,  Precision: 0.3085,  Recall: 0.6019
# [tensor(0.5557, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [148/200], Loss: 0.5569,  Accuracy: 78.1590,  Precision: 0.2929,  Recall: 0.6021
# [tensor(0.5429), tensor(0.5540)]
# Accuracy of validation : 78.28967178560674 % ,  Loss: 0.5717,  Precision: 0.3097,  Recall: 0.6000
# [tensor(0.5558, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [149/200], Loss: 0.5558,  Accuracy: 78.1634,  Precision: 0.2927,  Recall: 0.6024
# [tensor(0.5429), tensor(0.5540)]
# Accuracy of validation : 78.2595603733815 % ,  Loss: 0.5706,  Precision: 0.3097,  Recall: 0.5986
# [tensor(0.5558, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [150/200], Loss: 0.5547,  Accuracy: 78.1809,  Precision: 0.2931,  Recall: 0.6031
# [tensor(0.5429), tensor(0.5540)]
# Accuracy of validation : 78.28967178560674 % ,  Loss: 0.5695,  Precision: 0.3097,  Recall: 0.6000
# [tensor(0.5559, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [151/200], Loss: 0.5537,  Accuracy: 78.1722,  Precision: 0.2931,  Recall: 0.6027
# [tensor(0.5429), tensor(0.5541)]
# Accuracy of validation : 78.31978319783198 % ,  Loss: 0.5684,  Precision: 0.3097,  Recall: 0.6014
# [tensor(0.5559, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [152/200], Loss: 0.5528,  Accuracy: 78.1941,  Precision: 0.2931,  Recall: 0.6038
# [tensor(0.5429), tensor(0.5541)]
# Accuracy of validation : 78.31978319783198 % ,  Loss: 0.5674,  Precision: 0.3097,  Recall: 0.6014
# [tensor(0.5559, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [153/200], Loss: 0.5519,  Accuracy: 78.2029,  Precision: 0.2933,  Recall: 0.6042
# [tensor(0.5429), tensor(0.5541)]
# Accuracy of validation : 78.34989461005722 % ,  Loss: 0.5665,  Precision: 0.3109,  Recall: 0.6024
# [tensor(0.5560, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [154/200], Loss: 0.5511,  Accuracy: 78.2160,  Precision: 0.2933,  Recall: 0.6049
# [tensor(0.5429), tensor(0.5541)]
# Accuracy of validation : 78.31978319783198 % ,  Loss: 0.5656,  Precision: 0.3109,  Recall: 0.6010
# [tensor(0.5560, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [155/200], Loss: 0.5503,  Accuracy: 78.2073,  Precision: 0.2933,  Recall: 0.6044
# [tensor(0.5429), tensor(0.5541)]
# Accuracy of validation : 78.28967178560674 % ,  Loss: 0.5648,  Precision: 0.3109,  Recall: 0.5995
# [tensor(0.5561, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [156/200], Loss: 0.5495,  Accuracy: 78.2204,  Precision: 0.2933,  Recall: 0.6051
# [tensor(0.5429), tensor(0.5541)]
# Accuracy of validation : 78.31978319783198 % ,  Loss: 0.5640,  Precision: 0.3109,  Recall: 0.6010
# [tensor(0.5561, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [157/200], Loss: 0.5488,  Accuracy: 78.2160,  Precision: 0.2931,  Recall: 0.6049
# [tensor(0.5430), tensor(0.5541)]
# Accuracy of validation : 78.28967178560674 % ,  Loss: 0.5632,  Precision: 0.3097,  Recall: 0.6000
# [tensor(0.5561, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [158/200], Loss: 0.5482,  Accuracy: 78.2160,  Precision: 0.2929,  Recall: 0.6050
# [tensor(0.5430), tensor(0.5542)]
# Accuracy of validation : 78.28967178560674 % ,  Loss: 0.5625,  Precision: 0.3097,  Recall: 0.6000
# [tensor(0.5562, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [159/200], Loss: 0.5475,  Accuracy: 78.2160,  Precision: 0.2929,  Recall: 0.6050
# [tensor(0.5430), tensor(0.5542)]
# Accuracy of validation : 78.28967178560674 % ,  Loss: 0.5618,  Precision: 0.3097,  Recall: 0.6000
# [tensor(0.5562, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [160/200], Loss: 0.5470,  Accuracy: 78.2204,  Precision: 0.2926,  Recall: 0.6054
# [tensor(0.5430), tensor(0.5542)]
# Accuracy of validation : 78.28967178560674 % ,  Loss: 0.5611,  Precision: 0.3097,  Recall: 0.6000
# [tensor(0.5563, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [161/200], Loss: 0.5464,  Accuracy: 78.1941,  Precision: 0.2926,  Recall: 0.6040
# [tensor(0.5430), tensor(0.5542)]
# Accuracy of validation : 78.31978319783198 % ,  Loss: 0.5605,  Precision: 0.3097,  Recall: 0.6014
# [tensor(0.5563, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [162/200], Loss: 0.5459,  Accuracy: 78.2073,  Precision: 0.2924,  Recall: 0.6048
# [tensor(0.5430), tensor(0.5542)]
# Accuracy of validation : 78.34989461005722 % ,  Loss: 0.5599,  Precision: 0.3097,  Recall: 0.6029
# [tensor(0.5564, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [163/200], Loss: 0.5454,  Accuracy: 78.2029,  Precision: 0.2922,  Recall: 0.6046
# [tensor(0.5431), tensor(0.5543)]
# Accuracy of validation : 78.38000602228244 % ,  Loss: 0.5594,  Precision: 0.3085,  Recall: 0.6049
# [tensor(0.5564, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [164/200], Loss: 0.5449,  Accuracy: 78.2117,  Precision: 0.2922,  Recall: 0.6051
# [tensor(0.5431), tensor(0.5543)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5589,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5564, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [165/200], Loss: 0.5444,  Accuracy: 78.1985,  Precision: 0.2918,  Recall: 0.6046
# [tensor(0.5431), tensor(0.5543)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5584,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5565, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [166/200], Loss: 0.5440,  Accuracy: 78.1897,  Precision: 0.2918,  Recall: 0.6041
# [tensor(0.5431), tensor(0.5543)]
# Accuracy of validation : 78.38000602228244 % ,  Loss: 0.5579,  Precision: 0.3085,  Recall: 0.6049
# [tensor(0.5565, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [167/200], Loss: 0.5436,  Accuracy: 78.1941,  Precision: 0.2913,  Recall: 0.6046
# [tensor(0.5431), tensor(0.5544)]
# Accuracy of validation : 78.38000602228244 % ,  Loss: 0.5574,  Precision: 0.3085,  Recall: 0.6049
# [tensor(0.5566, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [168/200], Loss: 0.5432,  Accuracy: 78.2117,  Precision: 0.2911,  Recall: 0.6056
# [tensor(0.5432), tensor(0.5544)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5570,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5566, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [169/200], Loss: 0.5429,  Accuracy: 78.2117,  Precision: 0.2909,  Recall: 0.6056
# [tensor(0.5432), tensor(0.5544)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5566,  Precision: 0.3085,  Recall: 0.6078
# [tensor(0.5566, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [170/200], Loss: 0.5425,  Accuracy: 78.1941,  Precision: 0.2909,  Recall: 0.6047
# [tensor(0.5432), tensor(0.5544)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5562,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5567, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [171/200], Loss: 0.5422,  Accuracy: 78.1941,  Precision: 0.2902,  Recall: 0.6051
# [tensor(0.5432), tensor(0.5544)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5558,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5567, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [172/200], Loss: 0.5418,  Accuracy: 78.1853,  Precision: 0.2900,  Recall: 0.6047
# [tensor(0.5432), tensor(0.5545)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5554,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5567, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [173/200], Loss: 0.5415,  Accuracy: 78.1809,  Precision: 0.2897,  Recall: 0.6046
# [tensor(0.5432), tensor(0.5545)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5550,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5568, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [174/200], Loss: 0.5412,  Accuracy: 78.1897,  Precision: 0.2893,  Recall: 0.6052
# [tensor(0.5432), tensor(0.5545)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5547,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5568, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [175/200], Loss: 0.5409,  Accuracy: 78.1941,  Precision: 0.2893,  Recall: 0.6055
# [tensor(0.5432), tensor(0.5545)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5544,  Precision: 0.3085,  Recall: 0.6078
# [tensor(0.5568, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [176/200], Loss: 0.5406,  Accuracy: 78.1985,  Precision: 0.2889,  Recall: 0.6058
# [tensor(0.5433), tensor(0.5545)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5540,  Precision: 0.3085,  Recall: 0.6078
# [tensor(0.5569, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [177/200], Loss: 0.5403,  Accuracy: 78.2029,  Precision: 0.2889,  Recall: 0.6061
# [tensor(0.5433), tensor(0.5546)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5537,  Precision: 0.3085,  Recall: 0.6078
# [tensor(0.5569, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [178/200], Loss: 0.5401,  Accuracy: 78.2117,  Precision: 0.2889,  Recall: 0.6065
# [tensor(0.5433), tensor(0.5546)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5534,  Precision: 0.3085,  Recall: 0.6078
# [tensor(0.5569, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [179/200], Loss: 0.5398,  Accuracy: 78.2117,  Precision: 0.2889,  Recall: 0.6065
# [tensor(0.5433), tensor(0.5546)]
# Accuracy of validation : 78.44022884673291 % ,  Loss: 0.5531,  Precision: 0.3085,  Recall: 0.6078
# [tensor(0.5570, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [180/200], Loss: 0.5395,  Accuracy: 78.2117,  Precision: 0.2891,  Recall: 0.6065
# [tensor(0.5433), tensor(0.5546)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5528,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5570, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [181/200], Loss: 0.5393,  Accuracy: 78.2073,  Precision: 0.2891,  Recall: 0.6062
# [tensor(0.5433), tensor(0.5546)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5526,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5570, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [182/200], Loss: 0.5390,  Accuracy: 78.2424,  Precision: 0.2891,  Recall: 0.6081
# [tensor(0.5433), tensor(0.5546)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5523,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5570, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [183/200], Loss: 0.5388,  Accuracy: 78.2424,  Precision: 0.2888,  Recall: 0.6082
# [tensor(0.5433), tensor(0.5547)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5520,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5571, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [184/200], Loss: 0.5385,  Accuracy: 78.2248,  Precision: 0.2882,  Recall: 0.6076
# [tensor(0.5433), tensor(0.5547)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5517,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5571, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [185/200], Loss: 0.5383,  Accuracy: 78.2292,  Precision: 0.2880,  Recall: 0.6079
# [tensor(0.5433), tensor(0.5547)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5515,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5571, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [186/200], Loss: 0.5380,  Accuracy: 78.2424,  Precision: 0.2879,  Recall: 0.6086
# [tensor(0.5433), tensor(0.5547)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5512,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5571, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [187/200], Loss: 0.5378,  Accuracy: 78.2468,  Precision: 0.2879,  Recall: 0.6089
# [tensor(0.5433), tensor(0.5547)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5510,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5572, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [188/200], Loss: 0.5376,  Accuracy: 78.2599,  Precision: 0.2877,  Recall: 0.6097
# [tensor(0.5433), tensor(0.5547)]
# Accuracy of validation : 78.38000602228244 % ,  Loss: 0.5507,  Precision: 0.3085,  Recall: 0.6049
# [tensor(0.5572, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [189/200], Loss: 0.5374,  Accuracy: 78.2599,  Precision: 0.2877,  Recall: 0.6097
# [tensor(0.5433), tensor(0.5547)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5505,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5572, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [190/200], Loss: 0.5371,  Accuracy: 78.2599,  Precision: 0.2877,  Recall: 0.6097
# [tensor(0.5433), tensor(0.5547)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5502,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5572, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [191/200], Loss: 0.5369,  Accuracy: 78.2599,  Precision: 0.2873,  Recall: 0.6098
# [tensor(0.5433), tensor(0.5547)]
# Accuracy of validation : 78.41011743450767 % ,  Loss: 0.5500,  Precision: 0.3085,  Recall: 0.6064
# [tensor(0.5572, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [192/200], Loss: 0.5367,  Accuracy: 78.2511,  Precision: 0.2870,  Recall: 0.6095
# [tensor(0.5433), tensor(0.5548)]
# Accuracy of validation : 78.47034025895815 % ,  Loss: 0.5498,  Precision: 0.3085,  Recall: 0.6093
# [tensor(0.5573, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [193/200], Loss: 0.5365,  Accuracy: 78.2468,  Precision: 0.2868,  Recall: 0.6094
# [tensor(0.5433), tensor(0.5548)]
# Accuracy of validation : 78.47034025895815 % ,  Loss: 0.5496,  Precision: 0.3085,  Recall: 0.6093
# [tensor(0.5573, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [194/200], Loss: 0.5363,  Accuracy: 78.2380,  Precision: 0.2866,  Recall: 0.6090
# [tensor(0.5433), tensor(0.5548)]
# Accuracy of validation : 78.47034025895815 % ,  Loss: 0.5493,  Precision: 0.3085,  Recall: 0.6093
# [tensor(0.5573, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [195/200], Loss: 0.5361,  Accuracy: 78.2380,  Precision: 0.2864,  Recall: 0.6091
# [tensor(0.5433), tensor(0.5548)]
# Accuracy of validation : 78.50045167118338 % ,  Loss: 0.5491,  Precision: 0.3085,  Recall: 0.6108
# [tensor(0.5573, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [196/200], Loss: 0.5359,  Accuracy: 78.2380,  Precision: 0.2864,  Recall: 0.6091
# [tensor(0.5433), tensor(0.5548)]
# Accuracy of validation : 78.50045167118338 % ,  Loss: 0.5489,  Precision: 0.3085,  Recall: 0.6108
# [tensor(0.5573, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [197/200], Loss: 0.5357,  Accuracy: 78.2468,  Precision: 0.2866,  Recall: 0.6095
# [tensor(0.5433), tensor(0.5548)]
# Accuracy of validation : 78.47034025895815 % ,  Loss: 0.5487,  Precision: 0.3085,  Recall: 0.6093
# [tensor(0.5573, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [198/200], Loss: 0.5355,  Accuracy: 78.2468,  Precision: 0.2864,  Recall: 0.6095
# [tensor(0.5433), tensor(0.5548)]
# Accuracy of validation : 78.50045167118338 % ,  Loss: 0.5484,  Precision: 0.3085,  Recall: 0.6108
# [tensor(0.5574, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [199/200], Loss: 0.5353,  Accuracy: 78.2468,  Precision: 0.2862,  Recall: 0.6096
# [tensor(0.5433), tensor(0.5548)]
# Accuracy of validation : 78.50045167118338 % ,  Loss: 0.5482,  Precision: 0.3085,  Recall: 0.6108
# [tensor(0.5574, grad_fn=<MeanBackward0>), tensor(0.5637, grad_fn=<MeanBackward0>)]
# Epoch [200/200], Loss: 0.5351,  Accuracy: 78.2555,  Precision: 0.2864,  Recall: 0.6100
# [tensor(0.5433), tensor(0.5548)]
# Accuracy of validation : 78.47034025895815 % ,  Loss: 0.5480,  Precision: 0.3085,  Recall: 0.6093
# Test Results, Loss: 0.5221,  Accuracy: 78.8151,  Precision: 0.2887,  Recall: 0.5989
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▃▅▅▆▆▆▆▇▇▇▇▇▇██████████████████████████</td></tr><tr><td>train_loss</td><td>█▄▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_precision</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_recall</td><td>▂▁▁▁▂▂▂▂▃▃▃▄▄▅▅▆▆▇▇▇▇▇██████████████████</td></tr><tr><td>val_accuracy</td><td>▁▃▅▅▆▆▆▆▇▇▇▇▇▇▇█████████████████████████</td></tr><tr><td>val_loss</td><td>█▄▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_precision</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_recall</td><td>▁▁▁▁▂▂▂▂▃▃▃▄▄▅▅▆▆▇▇▇▇▇▇▇████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>0.78815</td></tr><tr><td>test_loss</td><td>0.5221</td></tr><tr><td>test_precision</td><td>0.28874</td></tr><tr><td>test_recall</td><td>0.5989</td></tr><tr><td>train_accuracy</td><td>0.78256</td></tr><tr><td>train_loss</td><td>0.53505</td></tr><tr><td>train_precision</td><td>0.28641</td></tr><tr><td>train_recall</td><td>0.61002</td></tr><tr><td>val_accuracy</td><td>0.7847</td></tr><tr><td>val_loss</td><td>0.54802</td></tr><tr><td>val_precision</td><td>0.30846</td></tr><tr><td>val_recall</td><td>0.60934</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">crisp-valley-24</strong> at: <a href='https://wandb.ai/mie424/adult/runs/xamcg7j1' target="_blank">https://wandb.ai/mie424/adult/runs/xamcg7j1</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230401_205648-xamcg7j1/logs</code>

# %%
len(x_train)/(len(x_test)+len(x_val)+len(x_train))
# Out:
# 0.6999785018887626

# %%
len(x_val)
# Out:
# 7815

# %%
len(x_train)
# Out:
# 22792
