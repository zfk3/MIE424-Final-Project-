# %% [markdown]
# # 1.0 Notebook Setup
#
# Note: need to mount your Google Drive to use the adult dataset.

# %%
# Optional - used by our team to record outputs
# !pip install wandb

# Used for fairness evaluation metrics 
# !pip install fairlearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wandb in /usr/local/lib/python3.9/dist-packages (0.14.2)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (3.1.31)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (1.19.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb) (67.6.1)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (8.1.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from wandb) (6.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.9/dist-packages (from wandb) (1.3.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (5.9.4)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.9/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (2.27.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fairlearn in /usr/local/lib/python3.9/dist-packages (0.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.10.1)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.2.2)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.9/dist-packages (from fairlearn) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25.1->fairlearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25.1->fairlearn) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.1->fairlearn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.1->fairlearn) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=0.25.1->fairlearn) (1.16.0)

# %%
# Other imports 

import pandas as pd
import plotly
import plotly.express as px
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model, metrics, preprocessing
from datetime import datetime, timedelta

import wandb
import random

from fairlearn.postprocessing import ThresholdOptimizer, plot_threshold_optimizer
from fairlearn.metrics import demographic_parity_ratio, equalized_odds_ratio, demographic_parity_difference, equalized_odds_difference
from fairlearn.reductions import DemographicParity


from google.colab import drive

from sklearn.model_selection import KFold, cross_val_score


drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2.0 Supporting Functions and Classes

# %% [markdown]
# ## 2.1 Defining Regularizers

# %%
import torch
from torch import nn
from torch.nn import functional as F


class ConstraintLoss(nn.Module):
    def __init__(self, n_class=2, alpha=1, p_norm=2):
        super(ConstraintLoss, self).__init__()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.alpha = alpha
        self.p_norm = p_norm
        self.n_class = n_class
        self.n_constraints = 2
        self.dim_condition = self.n_class + 1
        self.M = torch.zeros((self.n_constraints, self.dim_condition))

    #NOTE!!! --> We never call the parent mu_f in super so it was removed

    def forward(self, X, out, sensitive, y=None):
        # Reshapes sensitive attribute tensor to the same shape as the output 
        sensitive = sensitive.view(out.shape)
        # Reshapes y (label) tensor to the same shape as the output 
        if isinstance(y, torch.Tensor):
            y = y.view(out.shape)

        #Take the sigmoid of 'out' which is the output of our model (aka the weights). 
        #out = torch.sigmoid(out)

        # Get the mu_f value given these tensors by calling the subclass mu_f
        #mu_f is the expected value of a sensitive feature in DP
        # print("super forward -> sub-class mu_f called")
        mu = self.mu_f(X=X, out=out, sensitive=sensitive, y=y)
        
        # Gap constraint refers to the difference beteween the two sensitive classes as calculated by taking the .mv (dot product)
        # Apply relu to matrix vector product of M and mu which 
        # Using cuda if applicable (self.device references)
        gap_constraint = F.relu(
            torch.mv(self.M.to(self.device), mu.to(self.device))
        )
        # print("super forwad -> M*mu gap constraints")

        # Using the L2 Norm of the gap constraint as regularizer with alpha parameter. 
        if self.p_norm == 2:
            cons = self.alpha * torch.dot(gap_constraint, gap_constraint)
        else:
            cons = self.alpha * torch.dot(gap_constraint.detach(), gap_constraint)
        return cons


class DemographicParityLoss(ConstraintLoss):
    def __init__(self, sensitive_classes=[0, 1], alpha=1, p_norm=2):
        """loss of demograpfhic parity

        Args:
            sensitive_classes (list, optional): list of unique values of sensitive attribute. Defaults to [0, 1].
            alpha (int, optional): [description]. Defaults to 1.
            p_norm (int, optional): [description]. Defaults to 2.
        """
        self.sensitive_classes = sensitive_classes
        self.n_class = len(sensitive_classes)
        super(DemographicParityLoss, self).__init__(
            n_class=self.n_class, alpha=alpha, p_norm=p_norm
        )
        self.n_constraints = self.n_class
        self.dim_condition = self.n_class
        self.M = torch.zeros((self.n_constraints, self.dim_condition))
        for i in range(self.n_constraints):
            j = i % 2
            if j == 0:
                self.M[i, j] = 1.0
                self.M[i, 1] = -1.0
            else:
                self.M[i, j - 1] = -1.0
                self.M[i, 1] = 1.0
        # print("DP_init -> M defined")

    def mu_f(self, X, out, sensitive, y=None):
        # print("sub-class mu_f -> return exp vals")
        expected_values_list = []
        for v in self.sensitive_classes:
            # Get the index for each of the senstive classes 
            idx_true = sensitive == v  # torch.bool
            # Get the average prediction for that sensitive class
            expected_values_list.append(out[idx_true].mean())

        #expected_values_list will have two values, one for each sensitive class representing it's average prediction
        #if you look at forward you'll see we take the dot product of these two values with M
        return torch.stack(expected_values_list)

    def forward(self, X, out, sensitive, y=None):
        #Calls parent class forward function
        # print("sub-class forward -> call super forward")
        return super(DemographicParityLoss, self).forward(X, out, sensitive)


class EqualizedOddsLoss(ConstraintLoss):
    def __init__(self, sensitive_classes=[0, 1], alpha=1, p_norm=2):
        """loss of demograpfhic parity
        Args:
            sensitive_classes (list, optional): list of unique values of sensitive attribute. Defaults to [0, 1].
            alpha (int, optional): [description]. Defaults to 1.
            p_norm (int, optional): [description]. Defaults to 2.

            equalized odds: pr(y_hat | A=a, Y=y) = pr(y_hat | Y=y) for all a in A, y in Y.
            pr(y_hat =1 | A=a1, Y=y) = pr(y_hat =1 | A=a2, Y=y) for all y
        """
        self.sensitive_classes = sensitive_classes
        self.y_classes = [0, 1] # binary classification
        self.n_class = len(sensitive_classes)
        self.n_y_class = len(self.y_classes)
        super(EqualizedOddsLoss, self).__init__(n_class=self.n_class, alpha=alpha, p_norm=p_norm)
        # K:  number of constraint : (|A| x |Y| x {+, -})
        self.n_constraints = self.n_class * self.n_y_class
        # J : dim of conditions  : ((|A|+1) x |Y|)
        self.dim_condition = self.n_class* self.n_y_class
        self.M = torch.zeros((self.n_constraints, self.dim_condition))
        # print(self.M)
        #hard coded M matrix
        for i in range(self.n_constraints):
              if i==0:
                self.M[i, i] = 1.0
                self.M[i, i+2] = -1.0
              elif i == 1:
                self.M[i, i-1] = -1.0
                self.M[i, i+1] = 1.0
              elif i==2:
                self.M[i, i-1] = -1.0
                self.M[i, i+1] = 1.0
              elif i==3:
                self.M[i, i-2] = 1.0
                self.M[i, i] = -1.0
        #print(self.M)
                
    def mu_f(self, X, out, sensitive, y):
        expected_values_list = []
        # print(self.sensitive_classes)
        # print(self.y_classes)
        for u in self.sensitive_classes:
            for v in self.y_classes:
                # print("HERE")
                idx_true = (y == v) * (sensitive == u)  # torch.bool
                expected_values_list.append(out[idx_true].mean())
        # print(expected_values_list)
        # print("Loop")
        return torch.stack(expected_values_list)

    def forward(self, X, out, sensitive, y):
        return super(EqualizedOddsLoss, self).forward(X, out, sensitive, y=y)

# %% [markdown]
# ## 2.2 Defining Models

# %%
def weights_init(m):
    if isinstance(m, nn.Linear):
        print ("HELLO")
        nn.init.xavier_uniform_(m.weight.data)
        # nn.init.xavier_uniform_(m.bias.data)
    
# https://towardsdatascience.com/logistic-regression-with-pytorch-3c8bbea594be
class LogisticRegression(torch.nn.Module):
     def __init__(self, input_dim, output_dim):
         super(LogisticRegression, self).__init__()
         self.linear = torch.nn.Linear(input_dim, output_dim)
     def forward(self, x):
         (self.linear) 

         outputs = torch.sigmoid(self.linear(x))
         return outputs


# https://medium.com/analytics-vidhya/pytorch-for-deep-learning-binary-classification-logistic-regression-382abd97fb43
class Net(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Net,self).__init__()
        self.fc1 = nn.Linear(input_dim, 32)
        self.fc2 = nn.Linear(32,16)
        self.fc3 = nn.Linear(16, output_dim)
    def forward(self,x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x

# %% [markdown]
# ## 2.3 Data Loaders

# %% [markdown]
# ### 2.3.1 COMPAS

# %%
def load_compas(sensitive_name = 'race'): 
  # Load Data 
  compas_link ='https://raw.githubusercontent.com/propublica/compas-analysis/master/compas-scores-two-years.csv'
  compas_data = pd.read_csv(compas_link, on_bad_lines='skip')

  # Trim Undesired Columns 
  compas_data = compas_data[['age' , 'juv_fel_count', 'juv_misd_count', 'juv_other_count', 'priors_count','sex','c_charge_degree','race','two_year_recid']]
  compas_to_oh = ['sex','c_charge_degree']

  # Fix Race 
  compas_data.loc[compas_data.race != 'Caucasian', 'race'] = 1
  compas_data.loc[compas_data.race == 'Caucasian', 'race'] = 0
  compas_data.race = compas_data.race.astype(int)

  # Get Sensitive 
  sensitive = compas_data[[sensitive_name]]

  # One-hot-encode sex & c_charge_degree
  compas_data = pd.get_dummies(compas_data, columns = compas_to_oh)

  # Returns x, y, sensitive (with sensitive still included in x )
  return compas_data, sensitive

# %% [markdown]
# ### 2.3.2 Adult

# %%
def load_adult(sensitive_name = 'sex_binary'): 

  # Load Data 
  adult_data = pd.read_csv("/content/drive/MyDrive/Project/Data/adult.csv")

  # Create binary for race 
  adult_data.loc[adult_data.race != ' White', 'race_binary'] = 1
  adult_data.loc[adult_data.race == ' White', 'race_binary'] = 0
  adult_data.race = adult_data.race_binary.astype(int)

  # Create binary for sex 
  adult_data.loc[adult_data.sex != ' Male', 'sex_binary'] = 1
  adult_data.loc[adult_data.sex == ' Male', 'sex_binary'] = 0
  adult_data.sex = adult_data.sex_binary.astype(int)

  # Create binary for income 
  adult_data.loc[adult_data.income != ' >50K', 'income'] = 0
  adult_data.loc[adult_data.income == ' >50K', 'income'] = 1
  adult_data.income = adult_data.income.astype(int)

  adult_data = adult_data[['marital-status','occupation','race_binary','sex_binary','education_num', 'capital_gain', 'capital_loss', 'hours_per_week','income']]

  # One hot encode 
  adult_to_oh = ['marital-status', 'occupation']
  adult_data = pd.get_dummies(adult_data,columns=adult_to_oh)
  
  sensitive = adult_data[sensitive_name]
  
  return adult_data, sensitive

def get_balanced_adult():
  # Load Data 
  df = pd.read_csv("/content/drive/MyDrive/Project/Data/adult.csv")
  df_pos = df.loc[df.income==' >50K']
  df_neg = df.loc[df.income==' <=50K']
  df_neg_sample = df_neg.sample(len(df_pos),random_state=15)
  df_new = pd.concat([df_pos,df_neg_sample],axis=0)
  return df_new

def load_adult_balanced(target_name = 'income', sensitive_name = 'sex_binary'):

  # Load Data 
  adult_data = get_balanced_adult()

  # Create binary for race 
  adult_data.loc[adult_data.race != ' White', 'race_binary'] = 1
  adult_data.loc[adult_data.race == ' White', 'race_binary'] = 0
  adult_data.race = adult_data.race_binary.astype(int)

  # Create binary for sex 
  adult_data.loc[adult_data.sex != ' Male', 'sex_binary'] = 1
  adult_data.loc[adult_data.sex == ' Male', 'sex_binary'] = 0
  adult_data.sex = adult_data.sex_binary.astype(int)

  # Create binary for income 
  adult_data.loc[adult_data.income != ' >50K', 'income'] = 0
  adult_data.loc[adult_data.income == ' >50K', 'income'] = 1
  adult_data.income = adult_data.income.astype(int)

  adult_data = adult_data[['marital-status','occupation','race_binary','sex_binary','education_num', 'capital_gain', 'capital_loss', 'hours_per_week','income']]

  # One hot encode 
  adult_to_oh = ['marital-status', 'occupation']
  adult_data = pd.get_dummies(adult_data,columns=adult_to_oh)
  
  sensitive = adult_data[sensitive_name]
  
  return adult_data, sensitive

# %% [markdown]
# ## 2.4 Data Helpers

# %%
def label_encode(df):

  for i in df.columns:
    tmp = df[i].iloc[0]
    
    if type(tmp) != int or type(tmp) != float:
      le = preprocessing.LabelEncoder()
      df[i] = le.fit_transform(df[i].values)

  return df

def one_hot(df):
  
  for i in df.columns:
    tmp = df[i].iloc[0]

    if i == 'Loan_Status':
      pass
    elif type(tmp) == str:
      df = pd.get_dummies(df, columns = [i])
      # ohe = preprocessing.OneHotEncoder()
      # df[i] =  ohe.fit_transform(df[i].values.reshape(-1, 1)) # double check the shape

  return df


def get_dataset(name, target = None, sensitive = None):
  if name == 'compas':
    print ("*")
    df, sensitive_name = load_compas()
  
  if name == 'adult':
    df, sensitive_name = load_adult()
  
  if name == 'adult_balanced':
    df, sensitive_name = load_adult_balanced()

  # else: 
  #   df = pd.read_csv("/content/drive/MyDrive/Project/Data/adult.csv")
  #   df = label_encode(df)

  return df, sensitive_name

def split(x, y, sensitive_features,  train_ratio, test_ratio):
  validation_ratio = 100 - train_ratio - test_ratio

  if validation_ratio < 0:
    print ("Incorrect Ratios")
    return -1

  # train is now 75% of the entire data set
  x_train, x_test, y_train, y_test, a_train, a_test = train_test_split(x, y, sensitive_features, test_size=1 - train_ratio, random_state=32)

  # test is now 10% of the initial data set
  # validation is now 15% of the initial data set
  x_val, x_test, y_val, y_test, a_val, a_test = train_test_split(x_test, y_test, a_test, test_size=test_ratio, random_state=32) 

  return  x_train, x_test, x_val, y_train, y_test, y_val, a_train, a_test, a_val

# %% [markdown]
# ## 2.5 Evaluation Functions

# %%
def mae(prediction, true):
  return metrics.mean_absolute_error(true, prediction)

def accuracy(prediction, true):
  true = true.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)

  return (metrics.accuracy_score(true, prediction))

def precision(prediction, true):
  true = true.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return (metrics.precision_score(true, prediction))

def recall(prediction, true):
  true = true.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return (metrics.recall_score(true, prediction))

def tpr(prediction, true):
  return np.logical_and(prediction == 1, true== 1).sum()/prediction.shape[0]

def fpr(prediction, true):
  return np.logical_and(prediction == 1, true== 0).sum()/prediction.shape[0]

def tnr(prediction, true):
  return np.logical_and(prediction == 0, true== 0).sum()/prediction.shape[0]

def fnr(prediction, true):
  return np.logical_and(prediction == 0, true== 1).sum()/prediction.shape[0]

# demographic_parity_ratio
def dpr(prediction, true, sensitive_features):
  true = true.detach().numpy()
  sensitive_features = sensitive_features.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return demographic_parity_ratio(true,prediction, sensitive_features=sensitive_features)

# demographic_parity_difference
def dpd(prediction, true, sensitive_features):
  true = true.detach().numpy()
  sensitive_features = sensitive_features.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return demographic_parity_difference(true,prediction, sensitive_features=sensitive_features)

# equalized_odds_ratio
def eor(prediction, true, sensitive_features):
  true = true.detach().numpy()
  sensitive_features = sensitive_features.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return equalized_odds_ratio(true, prediction, sensitive_features=sensitive_features)

# equalized_odds_difference
def eod(prediction, true, sensitive_features):
  true = true.detach().numpy()
  sensitive_features = sensitive_features.detach().numpy()
  prediction = prediction.detach().numpy()
  prediction = np.where( prediction <= 0.5, 0, 1)
  return equalized_odds_difference(true,prediction, sensitive_features=sensitive_features)

# %% [markdown]
# ## 2.6 Train and Test Functions

# %%
def test(model, x_test, y_test, a_test):
  x_test, y_test, a_test = torch.tensor(x_test), torch.tensor(y_test), torch.tensor(a_test)
  outputs = model(x_test.float()) 
  loss = criterion(outputs, y_test.float())

  # log model results
  wandb.log({"test_loss": loss.item(), 
          "test_accuracy": accuracy(outputs, y_test), 
          "test_precision": precision(outputs, y_test), 
          "test_recall": recall(outputs, y_test),
          "test_dpr": dpr(outputs, y_test.float(),a_test ),
          "test_dpd": dpd(outputs, y_test.float(),a_test ),
          "test_eoo": eor(outputs, y_test.float(),a_test ),
          "test_edd": eod(outputs, y_test.float(),a_test )})
  wandb.watch(model)
  print ('Test Results, Loss: {:.4f},  Accuracy: {:.4f},  Precision: {:.4f},  Recall: {:.4f}' 
                  .format(loss.item(), 100 * accuracy(outputs, y_test),precision(outputs, y_test), recall(outputs, y_test)))

  return outputs, y_test

import torch.optim.lr_scheduler as lr_scheduler
 
def train( model, criterion, optimizer, name,   lr,   x_train, x_val, y_train, y_val, a_train, a_val,sensitive,  alpha = None, regularizers = None, num_epochs = None):
  x_train, x_val, y_train, y_val, a_train, a_val = torch.from_numpy(x_train), torch.from_numpy(x_val), torch.from_numpy(y_train), torch.from_numpy(y_val), torch.from_numpy(a_train), torch.from_numpy(a_val)

  # Early stopping parameters
  counter = 0 
  patience = 30
  min_delta = 0.001

  config= {
      "learning_rate":lr,
      "epochs": num_epochs,
      "model":model.__class__.__name__,
      "criterion":criterion.__class__.__name__,
      "optimizer":optimizer.__class__.__name__,
      "train_ratio":train_ratio, 
      "test_ratio":test_ratio,
      "data":name,
      "sensitive_race":sensitive
    }
  
  if regularizers != None:
    for i in range(len(regularizers)):
      config['regularizer_'+str(i)] = regularizers[i]
      config['alpha_'+str(i)] = alpha[i]

  # # store the hyperparameters in weights and bias
  wandb.init(project=name, entity="mie424",config = config)

  epoch_loss_train = []
  epoch_accuracy_train = []
  epoch_precision_train = []
  epoch_recall_train = []
  epoch_recall_dpr = []
  epoch_recall_dpd = []
  epoch_recall_eoo = []
  epoch_recall_eod = []
  
  epoch_loss_val = []
  epoch_accuracy_val = []
  epoch_precision_val = []
  epoch_recall_val = []
  epoch_dpr_val = []
  epoch_dpd_val = []
  epoch_eoo_val = []
  epoch_eod_val = []

  #scheduler = lr_scheduler.LinearLR(optimizer, start_factor=1, end_factor=0.25, total_iters=30) #start_factor=0.5, end_factor=0.05, total_iters=30
  #https://www.kaggle.com/code/isbhargav/guide-to-pytorch-learning-rate-scheduling
  #lambda1 = lambda epoch: 0.99 ** epoch
  #scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda1)
  
  # train loop
  for epoch in range(num_epochs):

    outputs = []
    # for i in range(0, x_train.shape[0], 10):
    optimizer.zero_grad()
  
    # Forward pass
    outputs   = model(x_train.float())  
        
    # outside of lop
    loss = criterion(outputs, y_train.float())
    if regularizers != None:
      # loss function
      for i in range(len(regularizers)):
        loss += regularizers[i](x_train.float(), outputs, a_train.float(), y_train.float()) #*alpha[i]
    
    # Backward and optimize
    loss.backward()
    optimizer.step()
    #scheduler.step()

    
    # store the epoch
    epoch_loss_train += [loss.item()]
    epoch_accuracy_train += [accuracy(outputs, y_train)]
    epoch_precision_train += [precision(outputs, y_train)]
    epoch_recall_train += [recall(outputs, y_train)]
    epoch_recall_dpr += [dpr(outputs, y_train.float(),a_train )]
    epoch_recall_dpd += [dpd(outputs, y_train.float(),a_train )]
    epoch_recall_eoo += [eor(outputs, y_train.float(),a_train )]
    epoch_recall_eod += [eod(outputs, y_train.float(),a_train )]

    # log model results
    wandb.log({"train_loss": epoch_loss_train[-1], 
              "train_accuracy": epoch_accuracy_train[-1], 
              "train_precision": epoch_precision_train[-1], 
              "train_recall": epoch_recall_train[-1],
              "train_dpr": epoch_recall_dpr[-1],
              "train_dpd": epoch_recall_dpd[-1],
              "train_eoo": epoch_recall_eoo[-1],
              "train_edd": epoch_recall_eod[-1]})
    
    wandb.watch(model)

    # print results
    print ('Epoch [{}/{}], Loss: {:.4f},  Accuracy: {:.4f},  Precision: {:.4f},  Recall: {:.4f}' 
                  .format(epoch+1, num_epochs, epoch_loss_train[-1], 100 * epoch_accuracy_train[-1],epoch_precision_train[-1],epoch_recall_train[-1]))
    
    # Validation loop
    with torch.no_grad():
      
      # model results
      outputs_v =  model(x_val.float()) 

      loss_v = criterion(outputs_v, y_val.float())
      if regularizers != None:
        # loss function
        for i in range(len(regularizers)):
          loss_v += regularizers[i](x_val.float(), outputs_v, a_val.float(), y_val.float()) #* alpha[i]
    
      # store resulst for the pass through
      epoch_loss_val += [loss_v.item()]
      epoch_accuracy_val += [accuracy(outputs_v, y_val)]
      epoch_precision_val += [precision(outputs_v, y_val)]
      epoch_recall_val += [recall(outputs_v, y_val)]
      epoch_dpr_val += [dpr(outputs_v, y_val.float(),a_val)]
      epoch_dpd_val += [dpd(outputs_v, y_val.float(),a_val)]
      epoch_eoo_val += [eor(outputs_v, y_val.float(),a_val)]
      epoch_eod_val += [eod(outputs_v, y_val.float(),a_val)]
        
      # log and print model results
      wandb.log({"val_loss": epoch_loss_val[-1], 
                  "val_accuracy": epoch_accuracy_val[-1], 
                  "val_precision": epoch_precision_val[-1], 
                  "val_recall": epoch_recall_val[-1],
                  "val_dpr": epoch_recall_dpr[-1],
                  "val_dpd": epoch_recall_dpd[-1],
                  "val_eoo": epoch_recall_eoo[-1],
                  "val_edd": epoch_recall_eod[-1] })
      wandb.watch(model)

      print('Accuracy of validation : {} % ,  Loss: {:.4f},  Precision: {:.4f},  Recall: {:.4f}'.format(100 * epoch_accuracy_val[-1], epoch_loss_val[-1],epoch_precision_val[-1], epoch_recall_val[-1])) 

      # Early Stopping
      # Inspiration: https://stackoverflow.com/questions/71998978/early-stopping-in-pytorch
      # if epoch > 5: # run for at least 5 epochs before starting
      #   min_validation_loss = round(min(epoch_loss_val[:-1]),4)
      #   validation_loss = round(epoch_loss_val[-1],4)

      #   if validation_loss < min_validation_loss:
      #       counter = 0
      #   elif validation_loss >= (min_validation_loss):
      #       counter += 1
      #       if counter >= patience:
      #         print("\n\n\nEARLY STOPPING\n\n\n")
      #         break
                

  return outputs, y_train, outputs_v, y_val
  # print ()

# %% [markdown]
# # 3.0 Experimentation Loop

# %%
# wandb.login()
# get df
name = "adult_balanced"

df, sensitive_name = get_dataset(name)

if name == "compas":
   x_var, y_var, sensitive = ['age', 'juv_fel_count', 'juv_misd_count', 'juv_other_count',
       'priors_count', 'race', 'sex_Female', 'sex_Male',
       'c_charge_degree_F', 'c_charge_degree_M'], ['two_year_recid'], ['race']
else:

  x_var, y_var, sensitive = ['race_binary', 'education_num', 'capital_gain',
        'capital_loss', 'hours_per_week',  'marital-status_ Divorced',
        'marital-status_ Married-civ-spouse',
        'marital-status_ Never-married','occupation_ Exec-managerial',  
        'occupation_ Prof-specialty',], ['income'], ['sex_binary']

name = "adult_balanced_nosched_seed8_v2"

train_ratio, test_ratio = 0.7, 0.66

# select x, y, and sensitive features
x = df[x_var].values.astype(float)
y = df[y_var].values
sensitive_features = df[sensitive].values.astype(float)

# split 
x_train, x_test, x_val, y_train, y_test, y_val, a_train, a_test, a_val = split(x, y, sensitive_features, train_ratio, test_ratio)

print (x_train.shape[1])
Alpha_1, Alpha_2  = [0,1,10,20, 30, 40, 50,100,150,200], [0,1,10,20, 30, 40, 50,100,150,200]
#[0,1,10,50,100,200], [0,1,10,50,100,200] #[0,1,10,100,300,600,1000,3000, 6000, 12000], [0,1,10,100,300,600,1000,3000, 6000, 12000]
num_epochs = 200


for alpha_dp in Alpha_1:
  for alpha_eo in Alpha_2:
    print (alpha_dp, alpha_eo)

    DemographicParity = DemographicParityLoss(sensitive_classes=[0, 1], alpha=alpha_dp) # constraint 
    EqualizedOdds = EqualizedOddsLoss(sensitive_classes=[0, 1], alpha=alpha_eo) # constraint 

    alphas = [alpha_dp,alpha_eo]
    regularizers = [DemographicParity,EqualizedOdds]
    # regularizers = [EqualizedOdds]
    input_dim =  x_train.shape[1]# Two inputs x1 and x2 
    output_dim = 1 # Single binary output 
    #lr = 0.0015 
    #lr = 0.0003
    #lr = 0.00005
    #lr = 0.00005
    lr = 0.0001
    #lr = 0.00009
    #torch.manual_seed(18)
    torch.manual_seed(8)
    #torch.manual_seed(11)
    #torch.manual_seed(29)
    model = LogisticRegression(input_dim,output_dim)
    
    #model = Net(input_dim, output_dim) # NN

    criterion = torch.nn.BCELoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)

    out_train, ys_train, out_val, ys_val = train( model, 
                                                        criterion=criterion, 
                                                        optimizer=optimizer, 
                                                        name=name, 
                                                        lr=lr, 
                                                        x_train=x_train, 
                                                        x_val=x_val, 
                                                        y_train=y_train, 
                                                        y_val=y_val, 
                                                        a_train=a_train, 
                                                        a_val=a_val,  
                                                        alpha = alphas,
                                                        sensitive =  sensitive_name,
                                                        regularizers = regularizers, 
                                                        num_epochs = num_epochs)

    outputs_test, y_test = test(model, x_test, y_test, a_test)
    wandb.finish()
# Out:
# wandb: WARNING Serializing object of type Series that is 250928 bytes
# 10
# 0 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230417_020958-umu8mpul</code>
# Syncing run <strong><a href='https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2/runs/umu8mpul' target="_blank">bright-sea-1</a></strong> to <a href='https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2' target="_blank">https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2</a>
#  View run at <a href='https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2/runs/umu8mpul' target="_blank">https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2/runs/umu8mpul</a>
# Epoch [1/200], Loss: 8.0894,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.4357,  Precision: 0.4541,  Recall: 0.8901
# Epoch [2/200], Loss: 8.0627,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.4080,  Precision: 0.4541,  Recall: 0.8901
# Epoch [3/200], Loss: 8.0364,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.3807,  Precision: 0.4541,  Recall: 0.8901
# Epoch [4/200], Loss: 8.0106,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.3539,  Precision: 0.4541,  Recall: 0.8901
# Epoch [5/200], Loss: 7.9853,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.3276,  Precision: 0.4541,  Recall: 0.8901
# Epoch [6/200], Loss: 7.9604,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.3018,  Precision: 0.4541,  Recall: 0.8901
# Epoch [7/200], Loss: 7.9361,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.2766,  Precision: 0.4541,  Recall: 0.8901
# Epoch [8/200], Loss: 7.9123,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.2519,  Precision: 0.4541,  Recall: 0.8901
# Epoch [9/200], Loss: 7.8890,  Accuracy: 47.3900,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.34021263289556 % ,  Loss: 8.2279,  Precision: 0.4544,  Recall: 0.8901
# Epoch [10/200], Loss: 7.8663,  Accuracy: 47.4173,  Precision: 0.4899,  Recall: 0.9028
# Accuracy of validation : 44.34021263289556 % ,  Loss: 8.2044,  Precision: 0.4544,  Recall: 0.8901
# Epoch [11/200], Loss: 7.8442,  Accuracy: 47.4264,  Precision: 0.4899,  Recall: 0.9028
# Accuracy of validation : 44.34021263289556 % ,  Loss: 8.1816,  Precision: 0.4544,  Recall: 0.8901
# Epoch [12/200], Loss: 7.8227,  Accuracy: 47.4355,  Precision: 0.4900,  Recall: 0.9028
# Accuracy of validation : 44.40275171982489 % ,  Loss: 8.1594,  Precision: 0.4547,  Recall: 0.8901
# Epoch [13/200], Loss: 7.8019,  Accuracy: 47.4538,  Precision: 0.4900,  Recall: 0.9028
# Accuracy of validation : 44.40275171982489 % ,  Loss: 8.1378,  Precision: 0.4547,  Recall: 0.8901
# Epoch [14/200], Loss: 7.7816,  Accuracy: 47.4902,  Precision: 0.4902,  Recall: 0.9028
# Accuracy of validation : 44.46529080675422 % ,  Loss: 8.1169,  Precision: 0.4550,  Recall: 0.8901
# Epoch [15/200], Loss: 7.7620,  Accuracy: 47.5084,  Precision: 0.4903,  Recall: 0.9028
# Accuracy of validation : 44.46529080675422 % ,  Loss: 8.0967,  Precision: 0.4550,  Recall: 0.8901
# Epoch [16/200], Loss: 7.7431,  Accuracy: 47.5266,  Precision: 0.4904,  Recall: 0.9028
# Accuracy of validation : 44.46529080675422 % ,  Loss: 8.0772,  Precision: 0.4550,  Recall: 0.8901
# Epoch [17/200], Loss: 7.7248,  Accuracy: 47.5722,  Precision: 0.4907,  Recall: 0.9026
# Accuracy of validation : 44.652908067542214 % ,  Loss: 8.0584,  Precision: 0.4559,  Recall: 0.8901
# Epoch [18/200], Loss: 7.7072,  Accuracy: 47.6906,  Precision: 0.4913,  Recall: 0.9026
# Accuracy of validation : 44.71544715447154 % ,  Loss: 8.0403,  Precision: 0.4562,  Recall: 0.8901
# Epoch [19/200], Loss: 7.6903,  Accuracy: 47.7362,  Precision: 0.4915,  Recall: 0.9020
# Accuracy of validation : 44.777986241400875 % ,  Loss: 8.0229,  Precision: 0.4565,  Recall: 0.8901
# Epoch [20/200], Loss: 7.6741,  Accuracy: 47.7817,  Precision: 0.4918,  Recall: 0.9020
# Accuracy of validation : 44.96560350218887 % ,  Loss: 8.0062,  Precision: 0.4575,  Recall: 0.8901
# Epoch [21/200], Loss: 7.6585,  Accuracy: 47.8819,  Precision: 0.4923,  Recall: 0.9020
# Accuracy of validation : 45.15322076297686 % ,  Loss: 7.9901,  Precision: 0.4584,  Recall: 0.8901
# Epoch [22/200], Loss: 7.6436,  Accuracy: 47.9730,  Precision: 0.4928,  Recall: 0.9015
# Accuracy of validation : 45.34083802376485 % ,  Loss: 7.9748,  Precision: 0.4593,  Recall: 0.8901
# Epoch [23/200], Loss: 7.6294,  Accuracy: 48.0550,  Precision: 0.4932,  Recall: 0.9013
# Accuracy of validation : 45.40337711069418 % ,  Loss: 7.9601,  Precision: 0.4596,  Recall: 0.8901
# Epoch [24/200], Loss: 7.6158,  Accuracy: 48.1461,  Precision: 0.4937,  Recall: 0.9003
# Accuracy of validation : 45.6535334584115 % ,  Loss: 7.9461,  Precision: 0.4609,  Recall: 0.8887
# Epoch [25/200], Loss: 7.6029,  Accuracy: 48.2281,  Precision: 0.4941,  Recall: 0.8994
# Accuracy of validation : 46.02876797998749 % ,  Loss: 7.9327,  Precision: 0.4628,  Recall: 0.8887
# Epoch [26/200], Loss: 7.5906,  Accuracy: 48.4832,  Precision: 0.4955,  Recall: 0.8988
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9200,  Precision: 0.4634,  Recall: 0.8887
# Epoch [27/200], Loss: 7.5789,  Accuracy: 48.6016,  Precision: 0.4961,  Recall: 0.8981
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9080,  Precision: 0.4637,  Recall: 0.8887
# Epoch [28/200], Loss: 7.5678,  Accuracy: 48.6290,  Precision: 0.4963,  Recall: 0.8965
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.8965,  Precision: 0.4633,  Recall: 0.8861
# Epoch [29/200], Loss: 7.5573,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8958
# Accuracy of validation : 46.34146341463415 % ,  Loss: 7.8856,  Precision: 0.4642,  Recall: 0.8848
# Epoch [30/200], Loss: 7.5473,  Accuracy: 48.9478,  Precision: 0.4980,  Recall: 0.8938
# Accuracy of validation : 46.59161976235147 % ,  Loss: 7.8753,  Precision: 0.4655,  Recall: 0.8848
# Epoch [31/200], Loss: 7.5379,  Accuracy: 49.1938,  Precision: 0.4993,  Recall: 0.8914
# Accuracy of validation : 46.59161976235147 % ,  Loss: 7.8655,  Precision: 0.4655,  Recall: 0.8834
# Epoch [32/200], Loss: 7.5291,  Accuracy: 49.2849,  Precision: 0.4998,  Recall: 0.8889
# Accuracy of validation : 46.779237023139466 % ,  Loss: 7.8563,  Precision: 0.4664,  Recall: 0.8821
# Epoch [33/200], Loss: 7.5207,  Accuracy: 49.5217,  Precision: 0.5012,  Recall: 0.8882
# Accuracy of validation : 46.966854283927454 % ,  Loss: 7.8475,  Precision: 0.4674,  Recall: 0.8821
# Epoch [34/200], Loss: 7.5128,  Accuracy: 49.6584,  Precision: 0.5019,  Recall: 0.8875
# Accuracy of validation : 47.15447154471545 % ,  Loss: 7.8393,  Precision: 0.4682,  Recall: 0.8768
# Epoch [35/200], Loss: 7.5054,  Accuracy: 49.9317,  Precision: 0.5035,  Recall: 0.8846
# Accuracy of validation : 47.342088805503444 % ,  Loss: 7.8315,  Precision: 0.4691,  Recall: 0.8755
# Epoch [36/200], Loss: 7.4984,  Accuracy: 50.0228,  Precision: 0.5040,  Recall: 0.8828
# Accuracy of validation : 47.779862414008754 % ,  Loss: 7.8241,  Precision: 0.4713,  Recall: 0.8715
# Epoch [37/200], Loss: 7.4919,  Accuracy: 50.4236,  Precision: 0.5063,  Recall: 0.8816
# Accuracy of validation : 47.779862414008754 % ,  Loss: 7.8172,  Precision: 0.4713,  Recall: 0.8689
# Epoch [38/200], Loss: 7.4857,  Accuracy: 50.4601,  Precision: 0.5065,  Recall: 0.8803
# Accuracy of validation : 47.96747967479675 % ,  Loss: 7.8107,  Precision: 0.4720,  Recall: 0.8596
# Epoch [39/200], Loss: 7.4800,  Accuracy: 50.7060,  Precision: 0.5080,  Recall: 0.8765
# Accuracy of validation : 48.21763602251407 % ,  Loss: 7.8046,  Precision: 0.4733,  Recall: 0.8570
# Epoch [40/200], Loss: 7.4746,  Accuracy: 50.8062,  Precision: 0.5086,  Recall: 0.8753
# Accuracy of validation : 48.15509693558474 % ,  Loss: 7.7988,  Precision: 0.4729,  Recall: 0.8543
# Epoch [41/200], Loss: 7.4695,  Accuracy: 50.8882,  Precision: 0.5091,  Recall: 0.8735
# Accuracy of validation : 48.53033145716073 % ,  Loss: 7.7934,  Precision: 0.4749,  Recall: 0.8517
# Epoch [42/200], Loss: 7.4647,  Accuracy: 51.1980,  Precision: 0.5109,  Recall: 0.8719
# Accuracy of validation : 48.96810506566604 % ,  Loss: 7.7882,  Precision: 0.4773,  Recall: 0.8490
# Epoch [43/200], Loss: 7.4603,  Accuracy: 51.0886,  Precision: 0.5104,  Recall: 0.8620
# Accuracy of validation : 49.65603502188868 % ,  Loss: 7.7834,  Precision: 0.4811,  Recall: 0.8450
# Epoch [44/200], Loss: 7.4561,  Accuracy: 51.4713,  Precision: 0.5128,  Recall: 0.8564
# Accuracy of validation : 49.65603502188868 % ,  Loss: 7.7789,  Precision: 0.4811,  Recall: 0.8424
# Epoch [45/200], Loss: 7.4523,  Accuracy: 51.4895,  Precision: 0.5129,  Recall: 0.8544
# Accuracy of validation : 49.78111319574734 % ,  Loss: 7.7747,  Precision: 0.4818,  Recall: 0.8397
# Epoch [46/200], Loss: 7.4486,  Accuracy: 51.7354,  Precision: 0.5144,  Recall: 0.8537
# Accuracy of validation : 50.093808630394 % ,  Loss: 7.7707,  Precision: 0.4836,  Recall: 0.8397
# Epoch [47/200], Loss: 7.4452,  Accuracy: 51.7446,  Precision: 0.5145,  Recall: 0.8519
# Accuracy of validation : 50.34396497811132 % ,  Loss: 7.7670,  Precision: 0.4851,  Recall: 0.8384
# Epoch [48/200], Loss: 7.4420,  Accuracy: 51.7719,  Precision: 0.5147,  Recall: 0.8499
# Accuracy of validation : 50.15634771732332 % ,  Loss: 7.7634,  Precision: 0.4838,  Recall: 0.8291
# Epoch [49/200], Loss: 7.4391,  Accuracy: 51.5624,  Precision: 0.5136,  Recall: 0.8393
# Accuracy of validation : 49.96873045653533 % ,  Loss: 7.7601,  Precision: 0.4825,  Recall: 0.8199
# Epoch [50/200], Loss: 7.4363,  Accuracy: 51.7081,  Precision: 0.5146,  Recall: 0.8341
# Accuracy of validation : 49.906191369606 % ,  Loss: 7.7570,  Precision: 0.4820,  Recall: 0.8146
# Epoch [51/200], Loss: 7.4337,  Accuracy: 51.8903,  Precision: 0.5158,  Recall: 0.8305
# Accuracy of validation : 50.03126954346466 % ,  Loss: 7.7541,  Precision: 0.4827,  Recall: 0.8132
# Epoch [52/200], Loss: 7.4313,  Accuracy: 51.9996,  Precision: 0.5165,  Recall: 0.8287
# Accuracy of validation : 53.5334584115072 % ,  Loss: 7.7514,  Precision: 0.5049,  Recall: 0.8132
# Epoch [53/200], Loss: 7.4291,  Accuracy: 54.2862,  Precision: 0.5316,  Recall: 0.8258
# Accuracy of validation : 53.283302063789876 % ,  Loss: 7.7488,  Precision: 0.5033,  Recall: 0.8066
# Epoch [54/200], Loss: 7.4270,  Accuracy: 54.2953,  Precision: 0.5318,  Recall: 0.8219
# Accuracy of validation : 53.283302063789876 % ,  Loss: 7.7464,  Precision: 0.5033,  Recall: 0.8066
# Epoch [55/200], Loss: 7.4250,  Accuracy: 54.3136,  Precision: 0.5320,  Recall: 0.8205
# Accuracy of validation : 53.65853658536586 % ,  Loss: 7.7441,  Precision: 0.5059,  Recall: 0.8013
# Epoch [56/200], Loss: 7.4232,  Accuracy: 55.2974,  Precision: 0.5390,  Recall: 0.8165
# Accuracy of validation : 53.721075672295186 % ,  Loss: 7.7420,  Precision: 0.5063,  Recall: 0.8000
# Epoch [57/200], Loss: 7.4215,  Accuracy: 55.2246,  Precision: 0.5386,  Recall: 0.8129
# Accuracy of validation : 53.5334584115072 % ,  Loss: 7.7400,  Precision: 0.5051,  Recall: 0.7815
# Epoch [58/200], Loss: 7.4199,  Accuracy: 55.0788,  Precision: 0.5382,  Recall: 0.8005
# Accuracy of validation : 53.65853658536586 % ,  Loss: 7.7381,  Precision: 0.5060,  Recall: 0.7788
# Epoch [59/200], Loss: 7.4184,  Accuracy: 55.0606,  Precision: 0.5383,  Recall: 0.7967
# Accuracy of validation : 53.721075672295186 % ,  Loss: 7.7364,  Precision: 0.5065,  Recall: 0.7775
# Epoch [60/200], Loss: 7.4171,  Accuracy: 55.1244,  Precision: 0.5389,  Recall: 0.7948
# Accuracy of validation : 53.65853658536586 % ,  Loss: 7.7347,  Precision: 0.5061,  Recall: 0.7748
# Epoch [61/200], Loss: 7.4158,  Accuracy: 55.0241,  Precision: 0.5384,  Recall: 0.7899
# Accuracy of validation : 54.03377110694184 % ,  Loss: 7.7331,  Precision: 0.5087,  Recall: 0.7735
# Epoch [62/200], Loss: 7.4146,  Accuracy: 55.3157,  Precision: 0.5406,  Recall: 0.7879
# Accuracy of validation : 54.1588492808005 % ,  Loss: 7.7317,  Precision: 0.5097,  Recall: 0.7642
# Epoch [63/200], Loss: 7.4135,  Accuracy: 55.2155,  Precision: 0.5403,  Recall: 0.7804
# Accuracy of validation : 54.1588492808005 % ,  Loss: 7.7303,  Precision: 0.5097,  Recall: 0.7629
# Epoch [64/200], Loss: 7.4124,  Accuracy: 55.2337,  Precision: 0.5405,  Recall: 0.7795
# Accuracy of validation : 54.09631019387117 % ,  Loss: 7.7290,  Precision: 0.5093,  Recall: 0.7589
# Epoch [65/200], Loss: 7.4114,  Accuracy: 55.2701,  Precision: 0.5409,  Recall: 0.7780
# Accuracy of validation : 55.72232645403376 % ,  Loss: 7.7278,  Precision: 0.5214,  Recall: 0.7576
# Epoch [66/200], Loss: 7.4105,  Accuracy: 56.9646,  Precision: 0.5539,  Recall: 0.7762
# Accuracy of validation : 56.035021888680426 % ,  Loss: 7.7266,  Precision: 0.5239,  Recall: 0.7563
# Epoch [67/200], Loss: 7.4097,  Accuracy: 56.9555,  Precision: 0.5540,  Recall: 0.7739
# Accuracy of validation : 56.035021888680426 % ,  Loss: 7.7255,  Precision: 0.5239,  Recall: 0.7563
# Epoch [68/200], Loss: 7.4089,  Accuracy: 56.9372,  Precision: 0.5539,  Recall: 0.7728
# Accuracy of validation : 56.035021888680426 % ,  Loss: 7.7245,  Precision: 0.5239,  Recall: 0.7563
# Epoch [69/200], Loss: 7.4082,  Accuracy: 56.9281,  Precision: 0.5539,  Recall: 0.7726
# Accuracy of validation : 56.41025641025641 % ,  Loss: 7.7235,  Precision: 0.5269,  Recall: 0.7536
# Epoch [70/200], Loss: 7.4075,  Accuracy: 57.3654,  Precision: 0.5574,  Recall: 0.7714
# Accuracy of validation : 56.973108192620394 % ,  Loss: 7.7226,  Precision: 0.5316,  Recall: 0.7457
# Epoch [71/200], Loss: 7.4068,  Accuracy: 57.4474,  Precision: 0.5590,  Recall: 0.7601
# Accuracy of validation : 57.035647279549714 % ,  Loss: 7.7218,  Precision: 0.5321,  Recall: 0.7457
# Epoch [72/200], Loss: 7.4063,  Accuracy: 57.5385,  Precision: 0.5598,  Recall: 0.7595
# Accuracy of validation : 57.035647279549714 % ,  Loss: 7.7210,  Precision: 0.5321,  Recall: 0.7457
# Epoch [73/200], Loss: 7.4057,  Accuracy: 57.5476,  Precision: 0.5599,  Recall: 0.7595
# Accuracy of validation : 57.098186366479055 % ,  Loss: 7.7202,  Precision: 0.5328,  Recall: 0.7430
# Epoch [74/200], Loss: 7.4052,  Accuracy: 57.5931,  Precision: 0.5604,  Recall: 0.7579
# Accuracy of validation : 56.84803001876173 % ,  Loss: 7.7195,  Precision: 0.5315,  Recall: 0.7272
# Epoch [75/200], Loss: 7.4047,  Accuracy: 57.2561,  Precision: 0.5588,  Recall: 0.7451
# Accuracy of validation : 57.72357723577236 % ,  Loss: 7.7188,  Precision: 0.5388,  Recall: 0.7272
# Epoch [76/200], Loss: 7.4042,  Accuracy: 57.8027,  Precision: 0.5636,  Recall: 0.7426
# Accuracy of validation : 57.72357723577236 % ,  Loss: 7.7182,  Precision: 0.5388,  Recall: 0.7258
# Epoch [77/200], Loss: 7.4038,  Accuracy: 57.8118,  Precision: 0.5638,  Recall: 0.7414
# Accuracy of validation : 57.661038148843026 % ,  Loss: 7.7176,  Precision: 0.5386,  Recall: 0.7205
# Epoch [78/200], Loss: 7.4034,  Accuracy: 57.5749,  Precision: 0.5625,  Recall: 0.7335
# Accuracy of validation : 57.661038148843026 % ,  Loss: 7.7170,  Precision: 0.5387,  Recall: 0.7192
# Epoch [79/200], Loss: 7.4031,  Accuracy: 57.5931,  Precision: 0.5628,  Recall: 0.7324
# Accuracy of validation : 57.5984990619137 % ,  Loss: 7.7164,  Precision: 0.5385,  Recall: 0.7139
# Epoch [80/200], Loss: 7.4027,  Accuracy: 57.5749,  Precision: 0.5630,  Recall: 0.7283
# Accuracy of validation : 57.410881801125704 % ,  Loss: 7.7159,  Precision: 0.5373,  Recall: 0.7060
# Epoch [81/200], Loss: 7.4024,  Accuracy: 57.4929,  Precision: 0.5627,  Recall: 0.7247
# Accuracy of validation : 57.223264540337716 % ,  Loss: 7.7154,  Precision: 0.5359,  Recall: 0.7020
# Epoch [82/200], Loss: 7.4021,  Accuracy: 57.3107,  Precision: 0.5616,  Recall: 0.7198
# Accuracy of validation : 57.410881801125704 % ,  Loss: 7.7150,  Precision: 0.5377,  Recall: 0.6993
# Epoch [83/200], Loss: 7.4018,  Accuracy: 57.4383,  Precision: 0.5628,  Recall: 0.7182
# Accuracy of validation : 57.535959974984365 % ,  Loss: 7.7145,  Precision: 0.5388,  Recall: 0.6993
# Epoch [84/200], Loss: 7.4015,  Accuracy: 57.6205,  Precision: 0.5644,  Recall: 0.7178
# Accuracy of validation : 57.5984990619137 % ,  Loss: 7.7141,  Precision: 0.5393,  Recall: 0.6993
# Epoch [85/200], Loss: 7.4013,  Accuracy: 57.6842,  Precision: 0.5650,  Recall: 0.7178
# Accuracy of validation : 57.5984990619137 % ,  Loss: 7.7137,  Precision: 0.5393,  Recall: 0.6993
# Epoch [86/200], Loss: 7.4011,  Accuracy: 57.6934,  Precision: 0.5652,  Recall: 0.7169
# Accuracy of validation : 57.5984990619137 % ,  Loss: 7.7134,  Precision: 0.5394,  Recall: 0.6980
# Epoch [87/200], Loss: 7.4009,  Accuracy: 57.7025,  Precision: 0.5653,  Recall: 0.7162
# Accuracy of validation : 57.5984990619137 % ,  Loss: 7.7130,  Precision: 0.5394,  Recall: 0.6980
# Epoch [88/200], Loss: 7.4007,  Accuracy: 57.6842,  Precision: 0.5652,  Recall: 0.7157
# Accuracy of validation : 58.41150719199499 % ,  Loss: 7.7127,  Precision: 0.5470,  Recall: 0.6940
# Epoch [89/200], Loss: 7.4005,  Accuracy: 58.8959,  Precision: 0.5765,  Recall: 0.7126
# Accuracy of validation : 58.47404627892433 % ,  Loss: 7.7124,  Precision: 0.5476,  Recall: 0.6927
# Epoch [90/200], Loss: 7.4003,  Accuracy: 59.1327,  Precision: 0.5788,  Recall: 0.7119
# Accuracy of validation : 58.47404627892433 % ,  Loss: 7.7121,  Precision: 0.5476,  Recall: 0.6927
# Epoch [91/200], Loss: 7.4001,  Accuracy: 59.1327,  Precision: 0.5788,  Recall: 0.7119
# Accuracy of validation : 58.47404627892433 % ,  Loss: 7.7118,  Precision: 0.5476,  Recall: 0.6927
# Epoch [92/200], Loss: 7.4000,  Accuracy: 59.2238,  Precision: 0.5796,  Recall: 0.7119
# Accuracy of validation : 58.47404627892433 % ,  Loss: 7.7115,  Precision: 0.5477,  Recall: 0.6914
# Epoch [93/200], Loss: 7.3998,  Accuracy: 59.2603,  Precision: 0.5804,  Recall: 0.7087
# Accuracy of validation : 58.47404627892433 % ,  Loss: 7.7112,  Precision: 0.5479,  Recall: 0.6887
# Epoch [94/200], Loss: 7.3997,  Accuracy: 59.3332,  Precision: 0.5811,  Recall: 0.7083
# Accuracy of validation : 58.47404627892433 % ,  Loss: 7.7110,  Precision: 0.5479,  Recall: 0.6887
# Epoch [95/200], Loss: 7.3996,  Accuracy: 59.3332,  Precision: 0.5811,  Recall: 0.7083
# Accuracy of validation : 58.28642901813633 % ,  Loss: 7.7108,  Precision: 0.5465,  Recall: 0.6848
# Epoch [96/200], Loss: 7.3994,  Accuracy: 59.1874,  Precision: 0.5802,  Recall: 0.7051
# Accuracy of validation : 58.348968105065666 % ,  Loss: 7.7105,  Precision: 0.5471,  Recall: 0.6848
# Epoch [97/200], Loss: 7.3993,  Accuracy: 59.2329,  Precision: 0.5806,  Recall: 0.7051
# Accuracy of validation : 58.348968105065666 % ,  Loss: 7.7103,  Precision: 0.5471,  Recall: 0.6848
# Epoch [98/200], Loss: 7.3992,  Accuracy: 59.2603,  Precision: 0.5808,  Recall: 0.7051
# Accuracy of validation : 58.28642901813633 % ,  Loss: 7.7101,  Precision: 0.5467,  Recall: 0.6821
# Epoch [99/200], Loss: 7.3991,  Accuracy: 59.2603,  Precision: 0.5808,  Recall: 0.7051
# Accuracy of validation : 58.28642901813633 % ,  Loss: 7.7099,  Precision: 0.5467,  Recall: 0.6821
# Epoch [100/200], Loss: 7.3990,  Accuracy: 59.2785,  Precision: 0.5810,  Recall: 0.7051
# Accuracy of validation : 58.41150719199499 % ,  Loss: 7.7097,  Precision: 0.5481,  Recall: 0.6795
# Epoch [101/200], Loss: 7.3989,  Accuracy: 59.3423,  Precision: 0.5820,  Recall: 0.7026
# Accuracy of validation : 58.41150719199499 % ,  Loss: 7.7096,  Precision: 0.5481,  Recall: 0.6795
# Epoch [102/200], Loss: 7.3988,  Accuracy: 59.3149,  Precision: 0.5818,  Recall: 0.7020
# Accuracy of validation : 58.28642901813633 % ,  Loss: 7.7094,  Precision: 0.5472,  Recall: 0.6755
# Epoch [103/200], Loss: 7.3988,  Accuracy: 59.2238,  Precision: 0.5812,  Recall: 0.7000
# Accuracy of validation : 58.536585365853654 % ,  Loss: 7.7092,  Precision: 0.5496,  Recall: 0.6755
# Epoch [104/200], Loss: 7.3987,  Accuracy: 59.5336,  Precision: 0.5842,  Recall: 0.6999
# Accuracy of validation : 58.536585365853654 % ,  Loss: 7.7091,  Precision: 0.5496,  Recall: 0.6755
# Epoch [105/200], Loss: 7.3986,  Accuracy: 59.5336,  Precision: 0.5842,  Recall: 0.6999
# Accuracy of validation : 58.59912445278299 % ,  Loss: 7.7089,  Precision: 0.5502,  Recall: 0.6755
# Epoch [106/200], Loss: 7.3985,  Accuracy: 59.5245,  Precision: 0.5841,  Recall: 0.6997
# Accuracy of validation : 58.59912445278299 % ,  Loss: 7.7088,  Precision: 0.5502,  Recall: 0.6755
# Epoch [107/200], Loss: 7.3985,  Accuracy: 59.5336,  Precision: 0.5842,  Recall: 0.6995
# Accuracy of validation : 58.59912445278299 % ,  Loss: 7.7086,  Precision: 0.5502,  Recall: 0.6755
# Epoch [108/200], Loss: 7.3984,  Accuracy: 59.5336,  Precision: 0.5842,  Recall: 0.6993
# Accuracy of validation : 58.59912445278299 % ,  Loss: 7.7085,  Precision: 0.5502,  Recall: 0.6755
# Epoch [109/200], Loss: 7.3984,  Accuracy: 59.5427,  Precision: 0.5843,  Recall: 0.6993
# Accuracy of validation : 58.786741713570976 % ,  Loss: 7.7084,  Precision: 0.5519,  Recall: 0.6755
# Epoch [110/200], Loss: 7.3983,  Accuracy: 59.7613,  Precision: 0.5865,  Recall: 0.6990
# Accuracy of validation : 58.786741713570976 % ,  Loss: 7.7082,  Precision: 0.5521,  Recall: 0.6742
# Epoch [111/200], Loss: 7.3982,  Accuracy: 59.7613,  Precision: 0.5866,  Recall: 0.6982
# Accuracy of validation : 58.724202626641656 % ,  Loss: 7.7081,  Precision: 0.5517,  Recall: 0.6715
# Epoch [112/200], Loss: 7.3982,  Accuracy: 59.5336,  Precision: 0.5855,  Recall: 0.6902
# Accuracy of validation : 58.724202626641656 % ,  Loss: 7.7080,  Precision: 0.5517,  Recall: 0.6715
# Epoch [113/200], Loss: 7.3981,  Accuracy: 59.5245,  Precision: 0.5855,  Recall: 0.6900
# Accuracy of validation : 58.786741713570976 % ,  Loss: 7.7079,  Precision: 0.5523,  Recall: 0.6715
# Epoch [114/200], Loss: 7.3981,  Accuracy: 59.5427,  Precision: 0.5857,  Recall: 0.6898
# Accuracy of validation : 58.724202626641656 % ,  Loss: 7.7078,  Precision: 0.5518,  Recall: 0.6702
# Epoch [115/200], Loss: 7.3981,  Accuracy: 59.4151,  Precision: 0.5849,  Recall: 0.6869
# Accuracy of validation : 58.724202626641656 % ,  Loss: 7.7077,  Precision: 0.5518,  Recall: 0.6702
# Epoch [116/200], Loss: 7.3980,  Accuracy: 59.4151,  Precision: 0.5849,  Recall: 0.6869
# Accuracy of validation : 58.724202626641656 % ,  Loss: 7.7076,  Precision: 0.5518,  Recall: 0.6702
# Epoch [117/200], Loss: 7.3980,  Accuracy: 59.4151,  Precision: 0.5849,  Recall: 0.6869
# Accuracy of validation : 58.724202626641656 % ,  Loss: 7.7075,  Precision: 0.5518,  Recall: 0.6702
# Epoch [118/200], Loss: 7.3979,  Accuracy: 59.4243,  Precision: 0.5849,  Recall: 0.6869
# Accuracy of validation : 58.724202626641656 % ,  Loss: 7.7074,  Precision: 0.5518,  Recall: 0.6702
# Epoch [119/200], Loss: 7.3979,  Accuracy: 59.4334,  Precision: 0.5850,  Recall: 0.6869
# Accuracy of validation : 58.786741713570976 % ,  Loss: 7.7073,  Precision: 0.5524,  Recall: 0.6702
# Epoch [120/200], Loss: 7.3979,  Accuracy: 59.4060,  Precision: 0.5848,  Recall: 0.6864
# Accuracy of validation : 58.786741713570976 % ,  Loss: 7.7073,  Precision: 0.5524,  Recall: 0.6702
# Epoch [121/200], Loss: 7.3978,  Accuracy: 59.4060,  Precision: 0.5848,  Recall: 0.6864
# Accuracy of validation : 58.786741713570976 % ,  Loss: 7.7072,  Precision: 0.5524,  Recall: 0.6702
# Epoch [122/200], Loss: 7.3978,  Accuracy: 59.4060,  Precision: 0.5848,  Recall: 0.6864
# Accuracy of validation : 58.786741713570976 % ,  Loss: 7.7071,  Precision: 0.5524,  Recall: 0.6702
# Epoch [123/200], Loss: 7.3978,  Accuracy: 59.4060,  Precision: 0.5848,  Recall: 0.6864
# Accuracy of validation : 58.724202626641656 % ,  Loss: 7.7070,  Precision: 0.5519,  Recall: 0.6689
# Epoch [124/200], Loss: 7.3977,  Accuracy: 59.3969,  Precision: 0.5848,  Recall: 0.6860
# Accuracy of validation : 58.786741713570976 % ,  Loss: 7.7069,  Precision: 0.5526,  Recall: 0.6675
# Epoch [125/200], Loss: 7.3977,  Accuracy: 59.5518,  Precision: 0.5864,  Recall: 0.6853
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7069,  Precision: 0.5532,  Recall: 0.6675
# Epoch [126/200], Loss: 7.3977,  Accuracy: 59.5154,  Precision: 0.5863,  Recall: 0.6839
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7068,  Precision: 0.5532,  Recall: 0.6675
# Epoch [127/200], Loss: 7.3976,  Accuracy: 59.5336,  Precision: 0.5865,  Recall: 0.6839
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7067,  Precision: 0.5540,  Recall: 0.6662
# Epoch [128/200], Loss: 7.3976,  Accuracy: 59.5154,  Precision: 0.5866,  Recall: 0.6817
# Accuracy of validation : 58.97435897435898 % ,  Loss: 7.7067,  Precision: 0.5547,  Recall: 0.6649
# Epoch [129/200], Loss: 7.3976,  Accuracy: 59.6064,  Precision: 0.5877,  Recall: 0.6806
# Accuracy of validation : 58.97435897435898 % ,  Loss: 7.7066,  Precision: 0.5547,  Recall: 0.6649
# Epoch [130/200], Loss: 7.3976,  Accuracy: 59.6064,  Precision: 0.5877,  Recall: 0.6806
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7065,  Precision: 0.5553,  Recall: 0.6649
# Epoch [131/200], Loss: 7.3975,  Accuracy: 59.5973,  Precision: 0.5876,  Recall: 0.6804
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7065,  Precision: 0.5553,  Recall: 0.6649
# Epoch [132/200], Loss: 7.3975,  Accuracy: 59.5973,  Precision: 0.5876,  Recall: 0.6804
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7064,  Precision: 0.5553,  Recall: 0.6649
# Epoch [133/200], Loss: 7.3975,  Accuracy: 59.5973,  Precision: 0.5876,  Recall: 0.6804
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7064,  Precision: 0.5553,  Recall: 0.6649
# Epoch [134/200], Loss: 7.3975,  Accuracy: 59.5973,  Precision: 0.5876,  Recall: 0.6804
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7063,  Precision: 0.5553,  Recall: 0.6649
# Epoch [135/200], Loss: 7.3974,  Accuracy: 59.5973,  Precision: 0.5876,  Recall: 0.6804
# Accuracy of validation : 58.97435897435898 % ,  Loss: 7.7063,  Precision: 0.5549,  Recall: 0.6623
# Epoch [136/200], Loss: 7.3974,  Accuracy: 59.3605,  Precision: 0.5861,  Recall: 0.6747
# Accuracy of validation : 58.97435897435898 % ,  Loss: 7.7062,  Precision: 0.5549,  Recall: 0.6623
# Epoch [137/200], Loss: 7.3974,  Accuracy: 59.3605,  Precision: 0.5861,  Recall: 0.6747
# Accuracy of validation : 58.97435897435898 % ,  Loss: 7.7062,  Precision: 0.5549,  Recall: 0.6623
# Epoch [138/200], Loss: 7.3974,  Accuracy: 59.3605,  Precision: 0.5861,  Recall: 0.6747
# Accuracy of validation : 58.97435897435898 % ,  Loss: 7.7061,  Precision: 0.5549,  Recall: 0.6623
# Epoch [139/200], Loss: 7.3973,  Accuracy: 59.3605,  Precision: 0.5861,  Recall: 0.6747
# Accuracy of validation : 58.97435897435898 % ,  Loss: 7.7061,  Precision: 0.5549,  Recall: 0.6623
# Epoch [140/200], Loss: 7.3973,  Accuracy: 59.3605,  Precision: 0.5861,  Recall: 0.6747
# Accuracy of validation : 58.97435897435898 % ,  Loss: 7.7060,  Precision: 0.5549,  Recall: 0.6623
# Epoch [141/200], Loss: 7.3973,  Accuracy: 59.3605,  Precision: 0.5861,  Recall: 0.6747
# Accuracy of validation : 58.97435897435898 % ,  Loss: 7.7060,  Precision: 0.5549,  Recall: 0.6623
# Epoch [142/200], Loss: 7.3973,  Accuracy: 59.3514,  Precision: 0.5860,  Recall: 0.6745
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7059,  Precision: 0.5544,  Recall: 0.6609
# Epoch [143/200], Loss: 7.3972,  Accuracy: 59.2512,  Precision: 0.5853,  Recall: 0.6725
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7059,  Precision: 0.5544,  Recall: 0.6609
# Epoch [144/200], Loss: 7.3972,  Accuracy: 59.2512,  Precision: 0.5853,  Recall: 0.6725
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7058,  Precision: 0.5544,  Recall: 0.6609
# Epoch [145/200], Loss: 7.3972,  Accuracy: 59.2603,  Precision: 0.5854,  Recall: 0.6725
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7058,  Precision: 0.5544,  Recall: 0.6609
# Epoch [146/200], Loss: 7.3972,  Accuracy: 59.2603,  Precision: 0.5854,  Recall: 0.6725
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7058,  Precision: 0.5544,  Recall: 0.6609
# Epoch [147/200], Loss: 7.3972,  Accuracy: 59.2603,  Precision: 0.5854,  Recall: 0.6725
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7057,  Precision: 0.5544,  Recall: 0.6609
# Epoch [148/200], Loss: 7.3971,  Accuracy: 59.2512,  Precision: 0.5854,  Recall: 0.6724
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7057,  Precision: 0.5544,  Recall: 0.6609
# Epoch [149/200], Loss: 7.3971,  Accuracy: 59.2512,  Precision: 0.5854,  Recall: 0.6724
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7056,  Precision: 0.5544,  Recall: 0.6609
# Epoch [150/200], Loss: 7.3971,  Accuracy: 59.2512,  Precision: 0.5854,  Recall: 0.6724
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7056,  Precision: 0.5544,  Recall: 0.6609
# Epoch [151/200], Loss: 7.3971,  Accuracy: 59.2512,  Precision: 0.5854,  Recall: 0.6724
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7056,  Precision: 0.5541,  Recall: 0.6583
# Epoch [152/200], Loss: 7.3971,  Accuracy: 59.2512,  Precision: 0.5855,  Recall: 0.6711
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7055,  Precision: 0.5541,  Recall: 0.6583
# Epoch [153/200], Loss: 7.3971,  Accuracy: 59.2512,  Precision: 0.5855,  Recall: 0.6711
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7055,  Precision: 0.5541,  Recall: 0.6583
# Epoch [154/200], Loss: 7.3970,  Accuracy: 59.2603,  Precision: 0.5856,  Recall: 0.6711
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7055,  Precision: 0.5541,  Recall: 0.6583
# Epoch [155/200], Loss: 7.3970,  Accuracy: 59.2603,  Precision: 0.5856,  Recall: 0.6711
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7054,  Precision: 0.5541,  Recall: 0.6583
# Epoch [156/200], Loss: 7.3970,  Accuracy: 59.2603,  Precision: 0.5856,  Recall: 0.6711
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7054,  Precision: 0.5547,  Recall: 0.6583
# Epoch [157/200], Loss: 7.3970,  Accuracy: 59.2785,  Precision: 0.5858,  Recall: 0.6711
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7054,  Precision: 0.5547,  Recall: 0.6583
# Epoch [158/200], Loss: 7.3970,  Accuracy: 59.2785,  Precision: 0.5858,  Recall: 0.6711
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7053,  Precision: 0.5547,  Recall: 0.6583
# Epoch [159/200], Loss: 7.3969,  Accuracy: 59.2967,  Precision: 0.5860,  Recall: 0.6711
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7053,  Precision: 0.5547,  Recall: 0.6583
# Epoch [160/200], Loss: 7.3969,  Accuracy: 59.3058,  Precision: 0.5861,  Recall: 0.6711
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7053,  Precision: 0.5547,  Recall: 0.6583
# Epoch [161/200], Loss: 7.3969,  Accuracy: 59.3058,  Precision: 0.5861,  Recall: 0.6711
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7052,  Precision: 0.5547,  Recall: 0.6583
# Epoch [162/200], Loss: 7.3969,  Accuracy: 59.2967,  Precision: 0.5860,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7052,  Precision: 0.5547,  Recall: 0.6583
# Epoch [163/200], Loss: 7.3969,  Accuracy: 59.2967,  Precision: 0.5860,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7052,  Precision: 0.5547,  Recall: 0.6583
# Epoch [164/200], Loss: 7.3968,  Accuracy: 59.2967,  Precision: 0.5860,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7051,  Precision: 0.5547,  Recall: 0.6583
# Epoch [165/200], Loss: 7.3968,  Accuracy: 59.2967,  Precision: 0.5860,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7051,  Precision: 0.5547,  Recall: 0.6583
# Epoch [166/200], Loss: 7.3968,  Accuracy: 59.2967,  Precision: 0.5860,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7051,  Precision: 0.5547,  Recall: 0.6583
# Epoch [167/200], Loss: 7.3968,  Accuracy: 59.2967,  Precision: 0.5860,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7051,  Precision: 0.5547,  Recall: 0.6583
# Epoch [168/200], Loss: 7.3968,  Accuracy: 59.2967,  Precision: 0.5860,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7050,  Precision: 0.5547,  Recall: 0.6583
# Epoch [169/200], Loss: 7.3968,  Accuracy: 59.2967,  Precision: 0.5860,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7050,  Precision: 0.5547,  Recall: 0.6583
# Epoch [170/200], Loss: 7.3967,  Accuracy: 59.3058,  Precision: 0.5861,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7050,  Precision: 0.5547,  Recall: 0.6583
# Epoch [171/200], Loss: 7.3967,  Accuracy: 59.3058,  Precision: 0.5861,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7049,  Precision: 0.5547,  Recall: 0.6583
# Epoch [172/200], Loss: 7.3967,  Accuracy: 59.3696,  Precision: 0.5868,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7049,  Precision: 0.5547,  Recall: 0.6583
# Epoch [173/200], Loss: 7.3967,  Accuracy: 59.3696,  Precision: 0.5868,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7049,  Precision: 0.5547,  Recall: 0.6583
# Epoch [174/200], Loss: 7.3967,  Accuracy: 59.3696,  Precision: 0.5868,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7049,  Precision: 0.5547,  Recall: 0.6583
# Epoch [175/200], Loss: 7.3967,  Accuracy: 59.3696,  Precision: 0.5868,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7048,  Precision: 0.5547,  Recall: 0.6583
# Epoch [176/200], Loss: 7.3966,  Accuracy: 59.3696,  Precision: 0.5868,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7048,  Precision: 0.5547,  Recall: 0.6583
# Epoch [177/200], Loss: 7.3966,  Accuracy: 59.4243,  Precision: 0.5873,  Recall: 0.6709
# Accuracy of validation : 58.91181988742964 % ,  Loss: 7.7048,  Precision: 0.5547,  Recall: 0.6583
# Epoch [178/200], Loss: 7.3966,  Accuracy: 59.4243,  Precision: 0.5873,  Recall: 0.6709
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7048,  Precision: 0.5544,  Recall: 0.6543
# Epoch [179/200], Loss: 7.3966,  Accuracy: 59.1145,  Precision: 0.5852,  Recall: 0.6645
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7047,  Precision: 0.5544,  Recall: 0.6543
# Epoch [180/200], Loss: 7.3966,  Accuracy: 59.1145,  Precision: 0.5852,  Recall: 0.6645
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7047,  Precision: 0.5544,  Recall: 0.6543
# Epoch [181/200], Loss: 7.3965,  Accuracy: 59.1145,  Precision: 0.5852,  Recall: 0.6645
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7047,  Precision: 0.5544,  Recall: 0.6543
# Epoch [182/200], Loss: 7.3965,  Accuracy: 59.1145,  Precision: 0.5852,  Recall: 0.6645
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7047,  Precision: 0.5544,  Recall: 0.6543
# Epoch [183/200], Loss: 7.3965,  Accuracy: 59.1145,  Precision: 0.5852,  Recall: 0.6645
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7046,  Precision: 0.5544,  Recall: 0.6543
# Epoch [184/200], Loss: 7.3965,  Accuracy: 59.1145,  Precision: 0.5852,  Recall: 0.6645
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7046,  Precision: 0.5544,  Recall: 0.6543
# Epoch [185/200], Loss: 7.3965,  Accuracy: 59.1145,  Precision: 0.5852,  Recall: 0.6645
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7046,  Precision: 0.5544,  Recall: 0.6543
# Epoch [186/200], Loss: 7.3965,  Accuracy: 59.1145,  Precision: 0.5852,  Recall: 0.6645
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7046,  Precision: 0.5544,  Recall: 0.6543
# Epoch [187/200], Loss: 7.3964,  Accuracy: 59.1145,  Precision: 0.5852,  Recall: 0.6645
# Accuracy of validation : 58.84928080050032 % ,  Loss: 7.7045,  Precision: 0.5544,  Recall: 0.6543
# Epoch [188/200], Loss: 7.3964,  Accuracy: 59.1145,  Precision: 0.5852,  Recall: 0.6645
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7045,  Precision: 0.5564,  Recall: 0.6530
# Epoch [189/200], Loss: 7.3964,  Accuracy: 59.3878,  Precision: 0.5882,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7045,  Precision: 0.5564,  Recall: 0.6530
# Epoch [190/200], Loss: 7.3964,  Accuracy: 59.3878,  Precision: 0.5882,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7045,  Precision: 0.5564,  Recall: 0.6530
# Epoch [191/200], Loss: 7.3964,  Accuracy: 59.3878,  Precision: 0.5882,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7044,  Precision: 0.5564,  Recall: 0.6530
# Epoch [192/200], Loss: 7.3964,  Accuracy: 59.3878,  Precision: 0.5882,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7044,  Precision: 0.5564,  Recall: 0.6530
# Epoch [193/200], Loss: 7.3963,  Accuracy: 59.3878,  Precision: 0.5882,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7044,  Precision: 0.5564,  Recall: 0.6530
# Epoch [194/200], Loss: 7.3963,  Accuracy: 59.3878,  Precision: 0.5882,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7044,  Precision: 0.5564,  Recall: 0.6530
# Epoch [195/200], Loss: 7.3963,  Accuracy: 59.3878,  Precision: 0.5882,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7044,  Precision: 0.5564,  Recall: 0.6530
# Epoch [196/200], Loss: 7.3963,  Accuracy: 59.3969,  Precision: 0.5883,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7043,  Precision: 0.5564,  Recall: 0.6530
# Epoch [197/200], Loss: 7.3963,  Accuracy: 59.3969,  Precision: 0.5883,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7043,  Precision: 0.5564,  Recall: 0.6530
# Epoch [198/200], Loss: 7.3963,  Accuracy: 59.3969,  Precision: 0.5883,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7043,  Precision: 0.5564,  Recall: 0.6530
# Epoch [199/200], Loss: 7.3962,  Accuracy: 59.3969,  Precision: 0.5883,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7043,  Precision: 0.5564,  Recall: 0.6530
# Epoch [200/200], Loss: 7.3962,  Accuracy: 59.3969,  Precision: 0.5883,  Recall: 0.6628
# Accuracy of validation : 59.0368980612883 % ,  Loss: 7.7042,  Precision: 0.5564,  Recall: 0.6530
# Test Results, Loss: 7.7161,  Accuracy: 58.2743,  Precision: 0.5640,  Recall: 0.6544
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_dpd</td><td>▁</td></tr><tr><td>test_dpr</td><td>▁</td></tr><tr><td>test_edd</td><td>▁</td></tr><tr><td>test_eoo</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▁▁▁▁▂▂▃▃▃▄▆▆▆▇▇▇▇██████████████████████</td></tr><tr><td>train_dpd</td><td>▅▅▅▄▅▅▆▆▅▇█▆▇▆▅▅▆▅▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂</td></tr><tr><td>train_dpr</td><td>▅▅▅▅▅▄▄▄▄▃▁▃▁▂▃▃▂▃▇▇▇██▇▇██████████▇██▇▇</td></tr><tr><td>train_edd</td><td>▁▁▁▁▁▁▂▂▃▄▅▆▇▆▆▇████▇▇██████████████████</td></tr><tr><td>train_eoo</td><td>██████▇▇▆▅▄▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▇▅▅▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_precision</td><td>▁▁▁▁▁▁▂▂▃▃▃▄▅▆▆▆▆▆▇▇████████████████████</td></tr><tr><td>train_recall</td><td>███████▇▇▇▆▅▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▁▁▂▂▂▃▃▄▅▅▆▇▇▇▇███████████████████████</td></tr><tr><td>val_dpd</td><td>▅▅▅▄▅▅▆▆▅▇█▆▇▆▅▅▆▅▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂</td></tr><tr><td>val_dpr</td><td>▅▅▅▅▅▄▄▄▄▃▁▃▁▂▃▃▂▃▇▇▇██▇▇██████████▇██▇▇</td></tr><tr><td>val_edd</td><td>▁▁▁▁▁▁▂▂▃▄▅▆▇▆▆▇████▇▇██████████████████</td></tr><tr><td>val_eoo</td><td>██████▇▇▆▅▄▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▆▅▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_precision</td><td>▁▁▁▁▁▂▂▂▃▃▄▅▅▆▆▇▇▇▇▇▇███████████████████</td></tr><tr><td>val_recall</td><td>███████▇▇▇▆▅▄▄▄▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>0.58274</td></tr><tr><td>test_dpd</td><td>0.01915</td></tr><tr><td>test_dpr</td><td>0.96712</td></tr><tr><td>test_edd</td><td>0.10071</td></tr><tr><td>test_eoo</td><td>0.86393</td></tr><tr><td>test_loss</td><td>7.7161</td></tr><tr><td>test_precision</td><td>0.56399</td></tr><tr><td>test_recall</td><td>0.6544</td></tr><tr><td>train_accuracy</td><td>0.59397</td></tr><tr><td>train_dpd</td><td>0.00738</td></tr><tr><td>train_dpr</td><td>0.98712</td></tr><tr><td>train_edd</td><td>0.10526</td></tr><tr><td>train_eoo</td><td>0.86004</td></tr><tr><td>train_loss</td><td>7.39622</td></tr><tr><td>train_precision</td><td>0.58829</td></tr><tr><td>train_recall</td><td>0.66283</td></tr><tr><td>val_accuracy</td><td>0.59037</td></tr><tr><td>val_dpd</td><td>0.00738</td></tr><tr><td>val_dpr</td><td>0.98712</td></tr><tr><td>val_edd</td><td>0.10526</td></tr><tr><td>val_eoo</td><td>0.86004</td></tr><tr><td>val_loss</td><td>7.70424</td></tr><tr><td>val_precision</td><td>0.55643</td></tr><tr><td>val_recall</td><td>0.65298</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bright-sea-1</strong> at: <a href='https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2/runs/umu8mpul' target="_blank">https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2/runs/umu8mpul</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230417_020958-umu8mpul/logs</code>
# wandb: WARNING Serializing object of type Series that is 250928 bytes
# 0 1
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230417_021136-g7kh8944</code>
# Syncing run <strong><a href='https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2/runs/g7kh8944' target="_blank">lemon-sun-2</a></strong> to <a href='https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2' target="_blank">https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2</a>
#  View run at <a href='https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2/runs/g7kh8944' target="_blank">https://wandb.ai/mie424/adult_balanced_nosched_seed8_v2/runs/g7kh8944</a>
# Epoch [1/200], Loss: 8.0896,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.4358,  Precision: 0.4541,  Recall: 0.8901
# Epoch [2/200], Loss: 8.0629,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.4081,  Precision: 0.4541,  Recall: 0.8901
# Epoch [3/200], Loss: 8.0367,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.3808,  Precision: 0.4541,  Recall: 0.8901
# Epoch [4/200], Loss: 8.0109,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.3540,  Precision: 0.4541,  Recall: 0.8901
# Epoch [5/200], Loss: 7.9856,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.3277,  Precision: 0.4541,  Recall: 0.8901
# Epoch [6/200], Loss: 7.9607,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.3019,  Precision: 0.4541,  Recall: 0.8901
# Epoch [7/200], Loss: 7.9364,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.2767,  Precision: 0.4541,  Recall: 0.8901
# Epoch [8/200], Loss: 7.9126,  Accuracy: 47.3809,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.27767354596623 % ,  Loss: 8.2520,  Precision: 0.4541,  Recall: 0.8901
# Epoch [9/200], Loss: 7.8894,  Accuracy: 47.3900,  Precision: 0.4897,  Recall: 0.9028
# Accuracy of validation : 44.34021263289556 % ,  Loss: 8.2279,  Precision: 0.4544,  Recall: 0.8901
# Epoch [10/200], Loss: 7.8667,  Accuracy: 47.4173,  Precision: 0.4899,  Recall: 0.9028
# Accuracy of validation : 44.34021263289556 % ,  Loss: 8.2045,  Precision: 0.4544,  Recall: 0.8901
# Epoch [11/200], Loss: 7.8446,  Accuracy: 47.4264,  Precision: 0.4899,  Recall: 0.9028
# Accuracy of validation : 44.34021263289556 % ,  Loss: 8.1817,  Precision: 0.4544,  Recall: 0.8901
# Epoch [12/200], Loss: 7.8232,  Accuracy: 47.4355,  Precision: 0.4900,  Recall: 0.9028
# Accuracy of validation : 44.40275171982489 % ,  Loss: 8.1595,  Precision: 0.4547,  Recall: 0.8901
# Epoch [13/200], Loss: 7.8023,  Accuracy: 47.4538,  Precision: 0.4900,  Recall: 0.9028
# Accuracy of validation : 44.40275171982489 % ,  Loss: 8.1380,  Precision: 0.4547,  Recall: 0.8901
# Epoch [14/200], Loss: 7.7821,  Accuracy: 47.4902,  Precision: 0.4902,  Recall: 0.9028
# Accuracy of validation : 44.46529080675422 % ,  Loss: 8.1171,  Precision: 0.4550,  Recall: 0.8901
# Epoch [15/200], Loss: 7.7626,  Accuracy: 47.5084,  Precision: 0.4903,  Recall: 0.9028
# Accuracy of validation : 44.46529080675422 % ,  Loss: 8.0969,  Precision: 0.4550,  Recall: 0.8901
# Epoch [16/200], Loss: 7.7437,  Accuracy: 47.5266,  Precision: 0.4904,  Recall: 0.9028
# Accuracy of validation : 44.46529080675422 % ,  Loss: 8.0775,  Precision: 0.4550,  Recall: 0.8901
# Epoch [17/200], Loss: 7.7255,  Accuracy: 47.5722,  Precision: 0.4907,  Recall: 0.9026
# Accuracy of validation : 44.652908067542214 % ,  Loss: 8.0587,  Precision: 0.4559,  Recall: 0.8901
# Epoch [18/200], Loss: 7.7079,  Accuracy: 47.6906,  Precision: 0.4913,  Recall: 0.9026
# Accuracy of validation : 44.71544715447154 % ,  Loss: 8.0406,  Precision: 0.4562,  Recall: 0.8901
# Epoch [19/200], Loss: 7.6911,  Accuracy: 47.7362,  Precision: 0.4915,  Recall: 0.9020
# Accuracy of validation : 44.777986241400875 % ,  Loss: 8.0232,  Precision: 0.4565,  Recall: 0.8901
# Epoch [20/200], Loss: 7.6749,  Accuracy: 47.7817,  Precision: 0.4918,  Recall: 0.9020
# Accuracy of validation : 44.96560350218887 % ,  Loss: 8.0066,  Precision: 0.4575,  Recall: 0.8901
# Epoch [21/200], Loss: 7.6594,  Accuracy: 47.8819,  Precision: 0.4923,  Recall: 0.9020
# Accuracy of validation : 45.15322076297686 % ,  Loss: 7.9906,  Precision: 0.4584,  Recall: 0.8901
# Epoch [22/200], Loss: 7.6446,  Accuracy: 47.9730,  Precision: 0.4928,  Recall: 0.9015
# Accuracy of validation : 45.34083802376485 % ,  Loss: 7.9753,  Precision: 0.4593,  Recall: 0.8901
# Epoch [23/200], Loss: 7.6304,  Accuracy: 48.0550,  Precision: 0.4932,  Recall: 0.9013
# Accuracy of validation : 45.40337711069418 % ,  Loss: 7.9607,  Precision: 0.4596,  Recall: 0.8901
# Epoch [24/200], Loss: 7.6169,  Accuracy: 48.1461,  Precision: 0.4937,  Recall: 0.9003
# Accuracy of validation : 45.716072545340836 % ,  Loss: 7.9468,  Precision: 0.4612,  Recall: 0.8901
# Epoch [25/200], Loss: 7.6041,  Accuracy: 48.2281,  Precision: 0.4941,  Recall: 0.8994
# Accuracy of validation : 46.02876797998749 % ,  Loss: 7.9335,  Precision: 0.4628,  Recall: 0.8887
# Epoch [26/200], Loss: 7.5919,  Accuracy: 48.4832,  Precision: 0.4955,  Recall: 0.8988
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9209,  Precision: 0.4634,  Recall: 0.8887
# Epoch [27/200], Loss: 7.5803,  Accuracy: 48.6016,  Precision: 0.4961,  Recall: 0.8981
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9089,  Precision: 0.4637,  Recall: 0.8887
# Epoch [28/200], Loss: 7.5693,  Accuracy: 48.6198,  Precision: 0.4962,  Recall: 0.8965
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.8975,  Precision: 0.4633,  Recall: 0.8861
# Epoch [29/200], Loss: 7.5589,  Accuracy: 48.7747,  Precision: 0.4971,  Recall: 0.8959
# Accuracy of validation : 46.34146341463415 % ,  Loss: 7.8867,  Precision: 0.4642,  Recall: 0.8848
# Epoch [30/200], Loss: 7.5490,  Accuracy: 48.9478,  Precision: 0.4980,  Recall: 0.8940
# Accuracy of validation : 46.59161976235147 % ,  Loss: 7.8765,  Precision: 0.4655,  Recall: 0.8848
# ...
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9385,  Precision: 0.4633,  Recall: 0.8874
# Epoch [67/200], Loss: 7.6894,  Accuracy: 48.7747,  Precision: 0.4971,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9378,  Precision: 0.4633,  Recall: 0.8874
# Epoch [68/200], Loss: 7.6887,  Accuracy: 48.7747,  Precision: 0.4971,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9371,  Precision: 0.4633,  Recall: 0.8874
# Epoch [69/200], Loss: 7.6881,  Accuracy: 48.7747,  Precision: 0.4971,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9363,  Precision: 0.4633,  Recall: 0.8874
# Epoch [70/200], Loss: 7.6874,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9356,  Precision: 0.4633,  Recall: 0.8874
# Epoch [71/200], Loss: 7.6868,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9349,  Precision: 0.4633,  Recall: 0.8874
# Epoch [72/200], Loss: 7.6862,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9342,  Precision: 0.4633,  Recall: 0.8874
# Epoch [73/200], Loss: 7.6855,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9336,  Precision: 0.4633,  Recall: 0.8874
# Epoch [74/200], Loss: 7.6849,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9329,  Precision: 0.4633,  Recall: 0.8874
# Epoch [75/200], Loss: 7.6843,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9322,  Precision: 0.4633,  Recall: 0.8861
# Epoch [76/200], Loss: 7.6837,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9315,  Precision: 0.4633,  Recall: 0.8861
# Epoch [77/200], Loss: 7.6830,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9308,  Precision: 0.4633,  Recall: 0.8861
# Epoch [78/200], Loss: 7.6824,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9301,  Precision: 0.4633,  Recall: 0.8861
# Epoch [79/200], Loss: 7.6818,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9295,  Precision: 0.4633,  Recall: 0.8861
# Epoch [80/200], Loss: 7.6811,  Accuracy: 48.8112,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9288,  Precision: 0.4633,  Recall: 0.8861
# Epoch [81/200], Loss: 7.6805,  Accuracy: 48.8112,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9281,  Precision: 0.4633,  Recall: 0.8861
# Epoch [82/200], Loss: 7.6799,  Accuracy: 48.8112,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9275,  Precision: 0.4633,  Recall: 0.8861
# Epoch [83/200], Loss: 7.6793,  Accuracy: 48.8112,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9268,  Precision: 0.4633,  Recall: 0.8861
# Epoch [84/200], Loss: 7.6787,  Accuracy: 48.8112,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9261,  Precision: 0.4633,  Recall: 0.8861
# Epoch [85/200], Loss: 7.6780,  Accuracy: 48.8112,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9255,  Precision: 0.4633,  Recall: 0.8861
# Epoch [86/200], Loss: 7.6774,  Accuracy: 48.8112,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9248,  Precision: 0.4633,  Recall: 0.8861
# Epoch [87/200], Loss: 7.6768,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9241,  Precision: 0.4633,  Recall: 0.8861
# Epoch [88/200], Loss: 7.6762,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9235,  Precision: 0.4633,  Recall: 0.8861
# Epoch [89/200], Loss: 7.6756,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9228,  Precision: 0.4633,  Recall: 0.8861
# Epoch [90/200], Loss: 7.6750,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9222,  Precision: 0.4633,  Recall: 0.8861
# Epoch [91/200], Loss: 7.6743,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8963
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9215,  Precision: 0.4633,  Recall: 0.8861
# Epoch [92/200], Loss: 7.6737,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8961
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9209,  Precision: 0.4633,  Recall: 0.8861
# Epoch [93/200], Loss: 7.6731,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8961
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9202,  Precision: 0.4633,  Recall: 0.8861
# Epoch [94/200], Loss: 7.6725,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8961
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9196,  Precision: 0.4633,  Recall: 0.8861
# Epoch [95/200], Loss: 7.6719,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8961
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9189,  Precision: 0.4633,  Recall: 0.8861
# Epoch [96/200], Loss: 7.6713,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8956
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9183,  Precision: 0.4633,  Recall: 0.8861
# Epoch [97/200], Loss: 7.6707,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8956
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9177,  Precision: 0.4633,  Recall: 0.8861
# Epoch [98/200], Loss: 7.6701,  Accuracy: 48.8112,  Precision: 0.4973,  Recall: 0.8956
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9170,  Precision: 0.4633,  Recall: 0.8861
# Epoch [99/200], Loss: 7.6695,  Accuracy: 48.8112,  Precision: 0.4973,  Recall: 0.8956
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9164,  Precision: 0.4633,  Recall: 0.8861
# Epoch [100/200], Loss: 7.6689,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8956
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9157,  Precision: 0.4633,  Recall: 0.8861
# Epoch [101/200], Loss: 7.6683,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8956
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9151,  Precision: 0.4633,  Recall: 0.8861
# Epoch [102/200], Loss: 7.6677,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8956
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9145,  Precision: 0.4633,  Recall: 0.8861
# Epoch [103/200], Loss: 7.6671,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8956
# Accuracy of validation : 46.15384615384615 % ,  Loss: 7.9138,  Precision: 0.4633,  Recall: 0.8861
# Epoch [104/200], Loss: 7.6665,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8956
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9132,  Precision: 0.4636,  Recall: 0.8861
# Epoch [105/200], Loss: 7.6659,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9126,  Precision: 0.4636,  Recall: 0.8861
# Epoch [106/200], Loss: 7.6653,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9119,  Precision: 0.4636,  Recall: 0.8861
# Epoch [107/200], Loss: 7.6647,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9113,  Precision: 0.4636,  Recall: 0.8861
# Epoch [108/200], Loss: 7.6641,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9107,  Precision: 0.4636,  Recall: 0.8861
# Epoch [109/200], Loss: 7.6635,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9100,  Precision: 0.4636,  Recall: 0.8861
# Epoch [110/200], Loss: 7.6629,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9094,  Precision: 0.4636,  Recall: 0.8861
# Epoch [111/200], Loss: 7.6623,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9088,  Precision: 0.4636,  Recall: 0.8861
# Epoch [112/200], Loss: 7.6617,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9082,  Precision: 0.4636,  Recall: 0.8861
# Epoch [113/200], Loss: 7.6611,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9075,  Precision: 0.4636,  Recall: 0.8861
# Epoch [114/200], Loss: 7.6605,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9069,  Precision: 0.4636,  Recall: 0.8861
# Epoch [115/200], Loss: 7.6599,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9063,  Precision: 0.4636,  Recall: 0.8861
# Epoch [116/200], Loss: 7.6594,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9057,  Precision: 0.4636,  Recall: 0.8861
# Epoch [117/200], Loss: 7.6588,  Accuracy: 48.8203,  Precision: 0.4973,  Recall: 0.8954
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9051,  Precision: 0.4636,  Recall: 0.8861
# Epoch [118/200], Loss: 7.6582,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9045,  Precision: 0.4636,  Recall: 0.8861
# Epoch [119/200], Loss: 7.6576,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9038,  Precision: 0.4636,  Recall: 0.8861
# Epoch [120/200], Loss: 7.6570,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9032,  Precision: 0.4636,  Recall: 0.8861
# Epoch [121/200], Loss: 7.6564,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9026,  Precision: 0.4636,  Recall: 0.8861
# Epoch [122/200], Loss: 7.6559,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9020,  Precision: 0.4636,  Recall: 0.8861
# Epoch [123/200], Loss: 7.6553,  Accuracy: 48.7929,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9014,  Precision: 0.4636,  Recall: 0.8861
# Epoch [124/200], Loss: 7.6547,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9008,  Precision: 0.4636,  Recall: 0.8861
# Epoch [125/200], Loss: 7.6541,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.9002,  Precision: 0.4636,  Recall: 0.8861
# Epoch [126/200], Loss: 7.6536,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8996,  Precision: 0.4636,  Recall: 0.8861
# Epoch [127/200], Loss: 7.6530,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8990,  Precision: 0.4636,  Recall: 0.8861
# Epoch [128/200], Loss: 7.6524,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8984,  Precision: 0.4636,  Recall: 0.8861
# Epoch [129/200], Loss: 7.6518,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8978,  Precision: 0.4636,  Recall: 0.8861
# Epoch [130/200], Loss: 7.6513,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8972,  Precision: 0.4636,  Recall: 0.8861
# Epoch [131/200], Loss: 7.6507,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8966,  Precision: 0.4636,  Recall: 0.8861
# Epoch [132/200], Loss: 7.6501,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8960,  Precision: 0.4636,  Recall: 0.8861
# Epoch [133/200], Loss: 7.6496,  Accuracy: 48.8112,  Precision: 0.4973,  Recall: 0.8947
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8954,  Precision: 0.4636,  Recall: 0.8861
# Epoch [134/200], Loss: 7.6490,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8948,  Precision: 0.4636,  Recall: 0.8861
# Epoch [135/200], Loss: 7.6484,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8942,  Precision: 0.4636,  Recall: 0.8861
# Epoch [136/200], Loss: 7.6479,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8936,  Precision: 0.4636,  Recall: 0.8861
# Epoch [137/200], Loss: 7.6473,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8930,  Precision: 0.4636,  Recall: 0.8861
# Epoch [138/200], Loss: 7.6467,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8924,  Precision: 0.4636,  Recall: 0.8861
# Epoch [139/200], Loss: 7.6462,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8918,  Precision: 0.4636,  Recall: 0.8861
# Epoch [140/200], Loss: 7.6456,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8912,  Precision: 0.4636,  Recall: 0.8861
# Epoch [141/200], Loss: 7.6451,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8906,  Precision: 0.4636,  Recall: 0.8861
# Epoch [142/200], Loss: 7.6445,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8901,  Precision: 0.4636,  Recall: 0.8861
# Epoch [143/200], Loss: 7.6440,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8895,  Precision: 0.4636,  Recall: 0.8861
# Epoch [144/200], Loss: 7.6434,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8889,  Precision: 0.4636,  Recall: 0.8861
# Epoch [145/200], Loss: 7.6428,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8883,  Precision: 0.4636,  Recall: 0.8861
# Epoch [146/200], Loss: 7.6423,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8877,  Precision: 0.4636,  Recall: 0.8861
# Epoch [147/200], Loss: 7.6417,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8871,  Precision: 0.4636,  Recall: 0.8861
# Epoch [148/200], Loss: 7.6412,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8866,  Precision: 0.4636,  Recall: 0.8861
# Epoch [149/200], Loss: 7.6406,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8860,  Precision: 0.4636,  Recall: 0.8861
# Epoch [150/200], Loss: 7.6401,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8854,  Precision: 0.4636,  Recall: 0.8861
# Epoch [151/200], Loss: 7.6396,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8848,  Precision: 0.4636,  Recall: 0.8861
# Epoch [152/200], Loss: 7.6390,  Accuracy: 48.8020,  Precision: 0.4972,  Recall: 0.8945
# Accuracy of validation : 46.21638524077549 % ,  Loss: 7.8843,  Precision: 0.4636,  Recall: 0.8861

# %% [markdown]
# ### Training Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm_train = confusion_matrix(ys_train.detach().numpy(), out_train.detach().numpy().round())
#cm_train = confusion_matrix(y_train.detach().numpy(), out_train.detach().numpy().round())


#sns.set(rc={'figure.figsize':(8,5)})
cm_train = pd.DataFrame(cm_train,index=['<$50K','>=$50K'],columns =['<$50K','>=$50K'])
sns.heatmap(cm_train,annot=True,fmt='g') #vmin=0,vmax=1,fmt=".1%"
plt.ylabel("True Label")
plt.xlabel("Prediction")
plt.title("Train Results")
plt.show()

# %% [markdown]
# ### Validation Confusion Matrix

# %%
cm_val = confusion_matrix(y_val.detach().numpy(), out_val.detach().numpy().round())
cm_val = pd.DataFrame(cm_val,index=['<$50K','>=$50K'],columns =['<$50K','>=$50K'])
sns.heatmap(cm_val,annot=True,fmt='g') #vmin=0,vmax=1,fmt=".1%"
plt.ylabel("True Label")
plt.xlabel("Prediction")
plt.title("Validation Results")
plt.show()

# %% [markdown]
# ### Test Confusion Matrix

# %%
cm_test = confusion_matrix(y_test.detach().numpy(), outputs_test.detach().numpy().round())
cm_test = pd.DataFrame(cm_test,index=['<$50K','>=$50K'],columns =['<$50K','>=$50K'])
sns.heatmap(cm_test,annot=True,fmt='g') #vmin=0,vmax=1,fmt=".1%"
plt.ylabel("True Label")
plt.xlabel("Prediction")
plt.title("Test Results")
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'juv_fel_count', 'juv_misd_count', 'juv_other_count',
#        'priors_count', 'race', 'two_year_recid', 'sex_Female', 'sex_Male',
#        'c_charge_degree_F', 'c_charge_degree_M'],
#       dtype='object')
